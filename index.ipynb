# %% [markdown]
# # Nearest Neighbors Lab

# %% [markdown]
# ### Introduction
#
# In this lab, you apply nearest neighbors technique to help a taxi company predict the length of their rides.  Imagine that we are hired to consult for LiftOff, a limo and taxi service that is just opening up in NYC.  Liftoff wants it's taxi drivers to target longer rides, as the longer the ride the more money it makes.  LiftOff has the following theory:
#
# * the pickup location of a taxi ride can help predict the length of the ride.
#
#
#
# LiftOff asks us to do some analysis to write a function that will allow it to **predict the length of a taxi ride for any given location **.
#
# Our technique will be the following:
#   * **Collect** Obtain the data containing all of the taxi information, and only select the attributes of taxi trips that we need
#   * ** Explore ** Examine the attributes of our data, and plot some of our data on a map
#   * ** Train ** Write our nearest neighbors formula, and change the number of nearby trips to predict the length of a new trip
#   * ** Predict ** Use our function to predict trip lengths of new locations

# %% [markdown]
# ### Collect and Explore the data

# %% [markdown]
# #### Collect the Data

# %% [markdown]
# Luckily for us, [NYC Open Data](https://opendata.cityofnewyork.us/) collects information about NYC taxi trips and provides this data on [its website](https://data.cityofnewyork.us/Transportation/2014-Yellow-Taxi-Trip-Data/gn7m-em8n).

# %% [markdown]
# ![](./nyc-taxi.png)

# %% [markdown]
# For your reading pleasure, the data has already been downloaded into the [trips.json](https://github.com/learn-co-curriculum/nearest-neighbors-lab/blob/master/trips.json) file in this lab which you can find here.  We'll use Python's `json` library to take the data from the `trips.json` file and store it as a variable in our notebook.

# %%
import json
# First, read the file
trips_file = open('trips.json')
# Then, convert contents to list of dictionaries 
trips = json.load(trips_file)

# %% [markdown]
# > Press shift + enter

# %% [markdown]
# #### Explore the data

# %% [markdown]
# The next step is to explore the data.  First, let's see how many trips we have.

# %%
len(trips)
# Out:
# 1000

# %% [markdown]
# Not bad at all.  Now let's see what each individual trip looks like.  Each trip is a dictionary, so we can see the attributes of each trip with the `keys` function.

# %%
print(trips[0].keys())
print("*** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *")
print(trips[0].values())
print("*** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *")
print(trips[0].items())
# Out:
# dict_keys(['dropoff_datetime', 'dropoff_latitude', 'dropoff_longitude', 'fare_amount', 'imp_surcharge', 'mta_tax', 'passenger_count', 'payment_type', 'pickup_datetime', 'pickup_latitude', 'pickup_longitude', 'rate_code', 'tip_amount', 'tolls_amount', 'total_amount', 'trip_distance', 'vendor_id'])
# *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *
# dict_values(['2014-11-26T22:31:00.000', '40.746769999999998', '-73.997450000000001', '52', '0', '0.5', '1', 'CSH', '2014-11-26T21:59:00.000', '40.64499', '-73.781149999999997', '2', '0', '5.3300000000000001', '57.829999999999998', '18.379999999999999', 'VTS'])
# *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *** *
# dict_items([('dropoff_datetime', '2014-11-26T22:31:00.000'), ('dropoff_latitude', '40.746769999999998'), ('dropoff_longitude', '-73.997450000000001'), ('fare_amount', '52'), ('imp_surcharge', '0'), ('mta_tax', '0.5'), ('passenger_count', '1'), ('payment_type', 'CSH'), ('pickup_datetime', '2014-11-26T21:59:00.000'), ('pickup_latitude', '40.64499'), ('pickup_longitude', '-73.781149999999997'), ('rate_code', '2'), ('tip_amount', '0'), ('tolls_amount', '5.3300000000000001'), ('total_amount', '57.829999999999998'), ('trip_distance', '18.379999999999999'), ('vendor_id', 'VTS')])

# %% [markdown]
# #### Limit our data

# %% [markdown]
# Ok, now that we have explored some of our data, let's begin to think through what data is relevant for our task.

# %% [markdown]
# Remember that our task is to **use the trip location to predict the length of a trip**.  So let's select the `pickup_latitude`, `pickup_longitude`, and `trip_distance` from each trip.  That will give us the trip location and related `trip_distance` for each trip.  Then based on these **actual** trip distances we can use nearest neighbors to predict an **expected** trip distance for a trip, provided an **actual** location.

# %% [markdown]
# ** Add in about trip distance **

# %% [markdown]
# Write a function called `parse_trips(trips)` that returns a list of the trips with only the following attributes:
# * `trip_distance`
# * `pickup_latitude`
# * `pickup_longitude`

# %%
def parse_trips(trips):
    trips_clone = trips.copy()
    A = []
    for i in range(0,len(trips_clone)):
        X = {}
        X = {k:v for k,v in trips_clone[i].items() if k == 'trip_distance' or k == 'pickup_latitude' or k == 'pickup_longitude'} 
        #print(X)
        A.append(X) 
    return A
    pass

parse_trips(trips)
#trips_clone
#for trip in trips_clone:
#print("distance:"+str(trip['trip_distance'])+", latitude:"+str(trip['pickup_latitude'])+", longitude:"+str(trip['pickup_longitude']))
#print("*** *** *** *** *** ***")
#for k,v in trip.items():
#if (k != 'trip_distance' and k != 'pickup_latitude' and k != 'pickup_longitude'): 
#del trip[k]
#print(k+":"+str(v))    
#A.setdefault(k, []).append(v)
#A
# Out:
# [{'pickup_latitude': '40.64499',
#   'pickup_longitude': '-73.781149999999997',
#   'trip_distance': '18.379999999999999'},
#  {'pickup_latitude': '40.766931',
#   'pickup_longitude': '-73.982097999999993',
#   'trip_distance': '1.3'},
#  {'pickup_latitude': '40.777729999999998',
#   'pickup_longitude': '-73.951902000000004',
#   'trip_distance': '4.5'},
#  {'pickup_latitude': '40.795678000000002',
#   'pickup_longitude': '-73.971048999999994',
#   'trip_distance': '2.3999999999999999'},
#  {'pickup_latitude': '40.762912',
#   'pickup_longitude': '-73.967782',
#   'trip_distance': '0.83999999999999997'},
#  {'pickup_latitude': '40.731175999999998',
#   'pickup_longitude': '-73.991572000000005',
#   'trip_distance': '0.80000000000000004'},
#  {'pickup_latitude': '40.800218999999998',
#   'pickup_longitude': '-73.968097999999998',
#   'trip_distance': '0.5'},
#  {'pickup_latitude': '40.648508999999997',
#   'pickup_longitude': '-73.783507999999998',
#   'trip_distance': '17.300000000000001'},
#  {'pickup_latitude': '40.721896999999998',
#   'pickup_longitude': '-73.983492999999996',
#   'trip_distance': '0.63'},
#  {'pickup_latitude': '40.791566000000003',
#   'pickup_longitude': '-73.972223999999997',
#   'trip_distance': '2.7999999999999998'},
#  {'pickup_latitude': '40.744895999999997',
#   'pickup_longitude': '-73.978618999999995',
#   'trip_distance': '0.59999999999999998'},
#  {'pickup_latitude': '40.721950999999997',
#   'pickup_longitude': '-73.844435000000004',
#   'trip_distance': '1.1000000000000001'},
#  {'pickup_latitude': '40.732382000000001',
#   'pickup_longitude': '-74.001682000000002',
#   'trip_distance': '4.2000000000000002'},
#  {'pickup_latitude': '40.768338999999997',
#   'pickup_longitude': '-73.961478',
#   'trip_distance': '0.40000000000000002'},
#  {'pickup_latitude': '40.775933000000002',
#   'pickup_longitude': '-73.962446',
#   'trip_distance': '0.59999999999999998'},
#  {'pickup_latitude': '40.794829',
#   'pickup_longitude': '-73.971475999999996',
#   'trip_distance': '9.8000000000000007'},
#  {'pickup_latitude': '40.758647000000003',
#   'pickup_longitude': '-73.964877999999999',
#   'trip_distance': '1.05'},
#  {'pickup_latitude': '40.713638000000003',
#   'pickup_longitude': '-74.011587000000006',
#   'trip_distance': '0.73999999999999999'},
#  {'pickup_latitude': '40.774030000000003',
#   'pickup_longitude': '-73.874596999999994',
#   'trip_distance': '8.4000000000000004'},
#  {'pickup_latitude': '40.728127000000001',
#   'pickup_longitude': '-73.998869999999997',
#   'trip_distance': '5.0999999999999996'},
#  {'pickup_latitude': '40.759670999999997',
#   'pickup_longitude': '-73.976687999999996',
#   'trip_distance': '1.3999999999999999'},
#  {'pickup_latitude': '40.772651000000003',
#   'pickup_longitude': '-73.967095',
#   'trip_distance': '2.7000000000000002'},
#  {'pickup_latitude': '40.770319000000001',
#   'pickup_longitude': '-73.960222000000002',
#   'trip_distance': '0.80000000000000004'},
#  {'pickup_latitude': '40.720457000000003',
#   'pickup_longitude': '-73.988065000000006',
#   'trip_distance': '1.1200000000000001'},
#  {'pickup_latitude': '40.754789000000002',
#   'pickup_longitude': '-73.973606000000004',
#   'trip_distance': '16'},
#  {'pickup_latitude': '40.755654',
#   'pickup_longitude': '-73.985845999999995',
#   'trip_distance': '1.3999999999999999'},
#  {'pickup_latitude': '40.741568000000001',
#   'pickup_longitude': '-73.978341',
#   'trip_distance': '0.90000000000000002'},
#  {'pickup_latitude': '40.736907000000002',
#   'pickup_longitude': '-73.988619999999997',
#   'trip_distance': '0.73999999999999999'},
#  {'pickup_latitude': '40.76003',
#   'pickup_longitude': '-73.964842000000004',
#   'trip_distance': '1.5'},
#  {'pickup_latitude': '40.721366000000003',
#   'pickup_longitude': '-74.008286999999996',
#   'trip_distance': '0.69999999999999996'},
#  {'pickup_latitude': '40.760147000000003',
#   'pickup_longitude': '-73.97627',
#   'trip_distance': '1.97'},
#  {'pickup_latitude': '40.745846999999998',
#   'pickup_longitude': '-74.001817000000003',
#   'trip_distance': '0.95999999999999996'},
#  {'pickup_latitude': '40.753014999999998',
#   'pickup_longitude': '-73.985247000000001',
#   'trip_distance': '0.73999999999999999'},
#  {'pickup_latitude': '40.644657000000002',
#   'pickup_longitude': '-73.782229000000001',
#   'trip_distance': '12.699999999999999'},
#  {'pickup_latitude': '40.738767000000003',
#   'pickup_longitude': '-74.008600000000001',
#   'trip_distance': '1.1699999999999999'},
#  {'pickup_latitude': '40.773797000000002',
#   'pickup_longitude': '-73.871065000000002',
#   'trip_distance': '22.800000000000001'},
#  {'pickup_latitude': '40.743411000000002',
#   'pickup_longitude': '-73.976860000000002',
#   'trip_distance': '1.5'},
#  {'pickup_latitude': '40.758904999999999',
#   'pickup_longitude': '-73.967896999999994',
#   'trip_distance': '1.5'},
#  {'pickup_latitude': '40.733877',
#   'pickup_longitude': '-73.989602000000005',
#   'trip_distance': '1.7'},
#  {'pickup_latitude': '40.726162000000002',
#   'pickup_longitude': '-73.983431999999993',
#   'trip_distance': '0.94999999999999996'},
#  {'pickup_latitude': '40.775122000000003',
#   'pickup_longitude': '-73.947765000000004',
#   'trip_distance': '5.8799999999999999'},
#  {'pickup_latitude': '40.759869999999999',
#   'pickup_longitude': '-73.978487000000001',
#   'trip_distance': '4.0999999999999996'},
#  {'pickup_latitude': '40.707087000000001',
#   'pickup_longitude': '-73.943280000000001',
#   'trip_distance': '1.0900000000000001'},
#  {'pickup_latitude': '40.741911999999999',
#   'pickup_longitude': '-74.003578000000005',
#   'trip_distance': '1.3899999999999999'},
#  {'pickup_latitude': '40.769112',
#   'pickup_longitude': '-73.862679',
#   'trip_distance': '11.199999999999999'},
#  {'pickup_latitude': '40.785806999999998',
#   'pickup_longitude': '-73.976387000000003',
#   'trip_distance': '2.5600000000000001'},
#  {'pickup_latitude': '40.751300000000001',
#   'pickup_longitude': '-73.986851999999999',
#   'trip_distance': '1.03'},
#  {'pickup_latitude': '40.733384999999998',
#   'pickup_longitude': '-73.987204000000006',
#   'trip_distance': '1.3'},
#  {'pickup_latitude': '40.760257000000003',
#   'pickup_longitude': '-73.976185999999998',
#   'trip_distance': '0.90000000000000002'},
#  {'pickup_latitude': '40.741249000000003',
#   'pickup_longitude': '-74.005201',
#   'trip_distance': '3.3999999999999999'},
#  {'pickup_latitude': '40.759794999999997',
#   'pickup_longitude': '-73.985352000000006',
#   'trip_distance': '0.80000000000000004'},
#  {'pickup_latitude': '40.756636',
#   'pickup_longitude': '-73.969700000000003',
#   'trip_distance': '0.80000000000000004'},
#  {'pickup_latitude': '40.739249999999998',
#   'pickup_longitude': '-74.000759000000002',
#   'trip_distance': '0.59999999999999998'},
#  {'pickup_latitude': '40.751055000000001',
#   'pickup_longitude': '-73.976070000000007',
#   'trip_distance': '1.0700000000000001'},
#  {'pickup_latitude': '40.723584000000002',
#   'pickup_longitude': '-73.995992000000001',
#   'trip_distance': '3.8999999999999999'},
#  {'pickup_latitude': '40.757036999999997',
#   'pickup_longitude': '-73.929485',
#   'trip_distance': '14.43'},
#  {'pickup_latitude': '40.743385000000004',
#   'pickup_longitude': '-73.981977999999998',
#   'trip_distance': '0.59999999999999998'},
#  {'pickup_latitude': '40.737485999999997',
#   'pickup_longitude': '-73.978153000000006',
#   'trip_distance': '2.1000000000000001'},
#  {'pickup_latitude': '40.77225',
#   'pickup_longitude': '-73.952849999999998',
#   'trip_distance': '1.76'},
#  {'pickup_latitude': '40.732881999999996',
#   'pickup_longitude': '-73.981975000000006',
#   'trip_distance': '2.4500000000000002'},
#  {'pickup_latitude': '40.774566999999998',
#   'pickup_longitude': '-73.988231999999996',
#   'trip_distance': '2.0299999999999998'},
#  {'pickup_latitude': '40.757437000000003',
#   'pickup_longitude': '-73.964735000000005',
#   'trip_distance': '0.80000000000000004'},
#  {'pickup_latitude': '40.789636999999999',
#   'pickup_longitude': '-73.975402000000003',
#   'trip_distance': '2.1400000000000001'},
#  {'pickup_latitude': '40.754317',
#   'pickup_longitude': '-73.992547999999999',
#   'trip_distance': '1.3'},
#  {'pickup_latitude': '40.745007000000001',
#   'pickup_longitude': '-73.998626999999999',
#   'trip_distance': '0.44'},
#  {'pickup_latitude': '40.734982000000002',
#   'pickup_longitude': '-73.990522999999996',
#   'trip_distance': '1'},
#  {'pickup_latitude': '0', 'pickup_longitude': '0', 'trip_distance': '1.95'},
#  {'pickup_latitude': '40.738616999999998',
#   'pickup_longitude': '-73.989671999999999',
#   'trip_distance': '1.48'},
#  {'pickup_latitude': '40.790711999999999',
#   'pickup_longitude': '-73.972808999999998',
#   'trip_distance': '0.5'},
#  {'pickup_latitude': '40.750166999999998',
#   'pickup_longitude': '-73.987397999999999',
#   'trip_distance': '1.5'},
#  {'pickup_latitude': '40.732140999999999',
#   'pickup_longitude': '-73.984470000000002',
#   'trip_distance': '12.699999999999999'},
#  {'pickup_latitude': '40.765757999999998',
#   'pickup_longitude': '-73.994846999999993',
#   'trip_distance': '1.1000000000000001'},
#  {'pickup_latitude': '40.792594000000001',
#   'pickup_longitude': '-73.964101999999997',
#   'trip_distance': '1'},
#  {'pickup_latitude': '40.762908000000003',
#   'pickup_longitude': '-73.969549000000001',
#   'trip_distance': '1.8'},
#  {'pickup_latitude': '40.750722000000003',
#   'pickup_longitude': '-73.968446999999998',
#   'trip_distance': '4.8499999999999996'},
#  {'pickup_latitude': '40.769886999999997',
#   'pickup_longitude': '-73.864429999999999',
#   'trip_distance': '5.0899999999999999'},
#  {'pickup_latitude': '40.772469999999998',
#   'pickup_longitude': '-73.982418999999993',
#   'trip_distance': '1.2'},
#  {'pickup_latitude': '40.764544999999998',
#   'pickup_longitude': '-73.982668000000004',
#   'trip_distance': '1.4399999999999999'},
#  {'pickup_latitude': '40.641804999999998',
#   'pickup_longitude': '-73.786410000000004',
#   'trip_distance': '16.629999999999999'},
#  {'pickup_latitude': '40.75224',
#   'pickup_longitude': '-73.978350000000006',
#   'trip_distance': '0.79000000000000004'},
#  {'pickup_latitude': '40.758834999999998',
#   'pickup_longitude': '-73.988555000000005',
#   'trip_distance': '1.3600000000000001'},
#  {'pickup_latitude': '40.722785000000002',
#   'pickup_longitude': '-73.988557999999998',
#   'trip_distance': '2.04'},
#  {'pickup_latitude': '40.720337999999998',
#   'pickup_longitude': '-73.993645000000001',
#   'trip_distance': '0.90000000000000002'},
#  {'pickup_latitude': '40.729730000000004',
#   'pickup_longitude': '-73.991628000000006',
#   'trip_distance': '1.6499999999999999'},
#  {'pickup_latitude': '40.760441999999998',
#   'pickup_longitude': '-73.958404999999999',
#   'trip_distance': '0.64000000000000001'},
#  {'pickup_latitude': '40.756227000000003',
#   'pickup_longitude': '-73.983140000000006',
#   'trip_distance': '1.3400000000000001'},
#  {'pickup_latitude': '40.751555000000003',
#   'pickup_longitude': '-73.992904999999993',
#   'trip_distance': '1.1299999999999999'},
#  {'pickup_latitude': '40.713329999999999',
#   'pickup_longitude': '-74.004105999999993',
#   'trip_distance': '1.3'},
#  {'pickup_latitude': '40.764761999999997',
#   'pickup_longitude': '-73.991849000000002',
#   'trip_distance': '1.1000000000000001'},
#  {'pickup_latitude': '40.763353000000002',
#   'pickup_longitude': '-73.985258999999999',
#   'trip_distance': '1.8999999999999999'},
#  {'pickup_latitude': '40.775292',
#   'pickup_longitude': '-73.982082000000005',
#   'trip_distance': '0.66000000000000003'},
#  {'pickup_latitude': '40.779515000000004',
#   'pickup_longitude': '-73.984852000000004',
#   'trip_distance': '0.90000000000000002'},
#  {'pickup_latitude': '40.768321999999998',
#   'pickup_longitude': '-73.982234000000005',
#   'trip_distance': '3.7999999999999998'},
#  {'pickup_latitude': '40.766601999999999',
#   'pickup_longitude': '-73.953879999999998',
#   'trip_distance': '6.5199999999999996'},
#  {'pickup_latitude': '40.763683999999998',
#   'pickup_longitude': '-73.981213999999994',
#   'trip_distance': '2.1000000000000001'},
#  {'pickup_latitude': '40.793086000000002',
#   'pickup_longitude': '-73.952091999999993',
#   'trip_distance': '0.69999999999999996'},
#  {'pickup_latitude': '40.773601999999997',
#   'pickup_longitude': '-73.871054999999998',
#   'trip_distance': '3.3999999999999999'},
#  {'pickup_latitude': '40.771909000000001',
#   'pickup_longitude': '-73.959023000000002',
#   'trip_distance': '0.80000000000000004'},
#  {'pickup_latitude': '40.774028999999999',
#   'pickup_longitude': '-73.961478',
#   'trip_distance': '4.0999999999999996'},
#  {'pickup_latitude': '40.749639999999999',
#   'pickup_longitude': '-73.972211999999999',
#   'trip_distance': '0.47999999999999998'},
#  {'pickup_latitude': '40.771541999999997',
#   'pickup_longitude': '-73.959532999999993',
#   'trip_distance': '1.2'},
#  {'pickup_latitude': '40.694094999999997',
#   'pickup_longitude': '-73.983900000000006',
#   'trip_distance': '3.8900000000000001'},
#  {'pickup_latitude': '40.756312000000001',
#   'pickup_longitude': '-73.994315',
#   'trip_distance': '6.9800000000000004'},
#  {'pickup_latitude': '40.730282000000003',
#   'pickup_longitude': '-74.006652000000003',
#   'trip_distance': '1.8'},
#  {'pickup_latitude': '40.777706999999999',
#   'pickup_longitude': '-73.955067999999997',
#   'trip_distance': '0.96999999999999997'},
#  {'pickup_latitude': '40.726087',
#   'pickup_longitude': '-73.994962000000001',
#   'trip_distance': '1.7'},
#  {'pickup_latitude': '40.738385000000001',
#   'pickup_longitude': '-73.999885000000006',
#   'trip_distance': '4.25'},
#  {'pickup_latitude': '40.767800000000001',
#   'pickup_longitude': '-73.961986999999993',
#   'trip_distance': '1.1000000000000001'},
#  {'pickup_latitude': '40.742682000000002',
#   'pickup_longitude': '-73.972513000000006',
#   'trip_distance': '0.12'},
#  {'pickup_latitude': '40.770601999999997',
#   'pickup_longitude': '-73.982262000000006',
#   'trip_distance': '1.02'},
#  {'pickup_latitude': '40.747967000000003',
#   'pickup_longitude': '-73.976726999999997',
#   'trip_distance': '2.3900000000000001'},
#  {'pickup_latitude': '40.742803000000002',
#   'pickup_longitude': '-74.004092999999997',
#   'trip_distance': '1.6000000000000001'},
#  {'pickup_latitude': '40.755521000000002',
#   'pickup_longitude': '-73.975459999999998',
#   'trip_distance': '1.7'},
#  {'pickup_latitude': '40.760528000000001',
#   'pickup_longitude': '-74.002757000000003',
#   'trip_distance': '1.5'},
#  {'pickup_latitude': '40.740732000000001',
#   'pickup_longitude': '-74.005512999999993',
#   'trip_distance': '1.3'},
#  {'pickup_latitude': '40.735497000000002',
#   'pickup_longitude': '-74.006010000000003',
#   'trip_distance': '1.1100000000000001'},
#  {'pickup_latitude': '40.715387',
#   'pickup_longitude': '-74.013518000000005',
#   'trip_distance': '6.0099999999999998'},
#  {'pickup_latitude': '40.721587',
#   'pickup_longitude': '-73.995427000000007',
#   'trip_distance': '1'},
#  {'pickup_latitude': '40.760057000000003',
#   'pickup_longitude': '-73.983502000000001',
#   'trip_distance': '1.26'},
#  {'pickup_latitude': '40.740332000000002',
#   'pickup_longitude': '-73.986288999999999',
#   'trip_distance': '1.2'},
#  {'pickup_latitude': '40.7455',
#   'pickup_longitude': '-73.977834000000001',
#   'trip_distance': '5.4000000000000004'},
#  {'pickup_latitude': '40.733125000000001',
#   'pickup_longitude': '-73.987273000000002',
#   'trip_distance': '1.2'},
#  {'pickup_latitude': '40.752091999999998',
#   'pickup_longitude': '-73.989948999999996',
#   'trip_distance': '3.2000000000000002'},
#  {'pickup_latitude': '40.72381',
#   'pickup_longitude': '-73.992616999999996',
#   'trip_distance': '0.80000000000000004'},
#  {'pickup_latitude': '40.767446',
#   'pickup_longitude': '-73.984105',
#   'trip_distance': '0.80000000000000004'},
#  {'pickup_latitude': '40.800479000000003',
#   'pickup_longitude': '-73.968082999999993',
#   'trip_distance': '2'},
#  {'pickup_latitude': '40.717055000000002',
#   'pickup_longitude': '-73.991325000000003',
#   'trip_distance': '0.88'},
#  {'pickup_latitude': '40.748863',
#   'pickup_longitude': '-73.992154999999997',
#   'trip_distance': '0.88'},
#  {'pickup_latitude': '40.804740000000002',
#   'pickup_longitude': '-73.947800000000001',
#   'trip_distance': '1.3'},
#  {'pickup_latitude': '40.762202000000002',
#   'pickup_longitude': '-73.969014999999999',
#   'trip_distance': '1.23'},
#  {'pickup_latitude': '0',
#   'pickup_longitude': '0',
#   'trip_distance': '5.1900000000000004'},
#  {'pickup_latitude': '40.740406999999998',
#   'pickup_longitude': '-73.987223',
#   'trip_distance': '0.90000000000000002'},
#  {'pickup_latitude': '40.722399000000003',
#   'pickup_longitude': '-73.997096999999997',
#   'trip_distance': '5.5999999999999996'},
#  {'pickup_latitude': '40.747571999999998',
#   'pickup_longitude': '-73.974091999999999',
#   'trip_distance': '1.1000000000000001'},
#  {'pickup_latitude': '40.794651000000002',
#   'pickup_longitude': '-73.972048000000001',
#   'trip_distance': '0.69999999999999996'},
#  {'pickup_latitude': '40.751086999999998',
#   'pickup_longitude': '-73.971599999999995',
#   'trip_distance': '0.059999999999999998'},
#  {'pickup_latitude': '40.719886000000002',
#   'pickup_longitude': '-74.009980999999996',
#   'trip_distance': '3.8999999999999999'},
#  {'pickup_latitude': '40.760886999999997',
#   'pickup_longitude': '-73.986959999999996',
#   'trip_distance': '0.72999999999999998'},
#  {'pickup_latitude': '40.727513999999999',
#   'pickup_longitude': '-74.007300000000001',
#   'trip_distance': '1.3999999999999999'},
#  {'pickup_latitude': '40.774453000000001',
#   'pickup_longitude': '-73.872166000000007',
#   'trip_distance': '1.2'},
#  {'pickup_latitude': '40.741906999999998',
#   'pickup_longitude': '-74.003545000000003',
#   'trip_distance': '4.9000000000000004'},
#  {'pickup_latitude': '40.735118',
#   'pickup_longitude': '-73.979789999999994',
#   'trip_distance': '1.3999999999999999'},
#  {'pickup_latitude': '40.773907000000001',
#   'pickup_longitude': '-73.871274999999997',
#   'trip_distance': '8.7300000000000004'},
#  {'pickup_latitude': '40.758937000000003',
#   'pickup_longitude': '-73.994231999999997',
#   'trip_distance': '1.48'},
#  {'pickup_latitude': '40.752144000000001',
#   'pickup_longitude': '-73.977198999999999',
#   'trip_distance': '0.40000000000000002'},
#  {'pickup_latitude': '40.745641999999997',
#   'pickup_longitude': '-73.990757000000002',
#   'trip_distance': '0.60999999999999999'},
#  {'pickup_latitude': '40.718789999999998',
#   'pickup_longitude': '-73.989840000000001',
#   'trip_distance': '1.9199999999999999'},
#  {'pickup_latitude': '40.739944999999999',
#   'pickup_longitude': '-74.006124',
#   'trip_distance': '1.8999999999999999'},
#  {'pickup_latitude': '40.777574999999999',
#   'pickup_longitude': '-73.986287000000004',
#   'trip_distance': '1.8500000000000001'},
#  {'pickup_latitude': '40.753632000000003',
#   'pickup_longitude': '-73.988899000000004',
#   'trip_distance': '1.6000000000000001'},
#  {'pickup_latitude': '40.747329999999998',
#   'pickup_longitude': '-73.977029999999999',
#   'trip_distance': '3.6099999999999999'},
#  {'pickup_latitude': '40.769821999999998',
#   'pickup_longitude': '-73.960595999999995',
#   'trip_distance': '0.40000000000000002'},
#  {'pickup_latitude': '40.724657999999998',
#   'pickup_longitude': '-73.997130999999996',
#   'trip_distance': '2.1000000000000001'},
#  {'pickup_latitude': '40.758344999999998',
#   'pickup_longitude': '-73.989397999999994',
#   'trip_distance': '1.21'},
#  {'pickup_latitude': '40.764806999999998',
#   'pickup_longitude': '-73.976690000000005',
#   'trip_distance': '0.55000000000000004'},
#  {'pickup_latitude': '40.772846999999999',
#   'pickup_longitude': '-73.962703000000005',
#   'trip_distance': '1.27'},
#  {'pickup_latitude': '40.793681999999997',
#   'pickup_longitude': '-73.966971999999998',
#   'trip_distance': '0.5'},
#  {'pickup_latitude': '40.760007000000002',
#   'pickup_longitude': '-73.978039999999993',
#   'trip_distance': '4.5'},
#  {'pickup_latitude': '40.747252000000003',
#   'pickup_longitude': '-73.888215000000002',
#   'trip_distance': '1.52'},
#  {'pickup_latitude': '40.756391999999998',
#   'pickup_longitude': '-73.967522000000002',
#   'trip_distance': '2.6000000000000001'},
#  {'pickup_latitude': '40.763685000000002',
#   'pickup_longitude': '-73.977714000000006',
#   'trip_distance': '0.59999999999999998'},
#  {'pickup_latitude': '40.767068000000002',
#   'pickup_longitude': '-73.982804999999999',
#   'trip_distance': '3.3999999999999999'},
#  {'pickup_latitude': '40.775959999999998',
#   'pickup_longitude': '-73.987279999999998',
#   'trip_distance': '2.2999999999999998'},
#  {'pickup_latitude': '40.739617000000003',
#   'pickup_longitude': '-73.984662999999998',
#   'trip_distance': '1.4399999999999999'},
#  {'pickup_latitude': '40.751953',
#   'pickup_longitude': '-73.976404000000002',
#   'trip_distance': '10.9'},
#  {'pickup_latitude': '40.718634999999999',
#   'pickup_longitude': '-74.000951999999998',
#   'trip_distance': '2.7999999999999998'},
#  {'pickup_latitude': '40.7331',
#   'pickup_longitude': '-73.981375',
#   'trip_distance': '2.6699999999999999'},
#  {'pickup_latitude': '40.774630000000002',
#   'pickup_longitude': '-73.963220000000007',
#   'trip_distance': '0.83999999999999997'},
#  {'pickup_latitude': '40.753675000000001',
#   'pickup_longitude': '-73.984942000000004',
#   'trip_distance': '1.8899999999999999'},
#  {'pickup_latitude': '40.763261999999997',
#   'pickup_longitude': '-73.959479999999999',
#   'trip_distance': '2.6099999999999999'},
#  {'pickup_latitude': '40.768895000000001',
#   'pickup_longitude': '-73.958236999999997',
#   'trip_distance': '1.29'},
#  {'pickup_latitude': '40.641374999999996',
#   'pickup_longitude': '-73.788934999999995',
#   'trip_distance': '11.5'},
#  {'pickup_latitude': '40.745471999999999',
#   'pickup_longitude': '-73.986660000000001',
#   'trip_distance': '1.21'},
#  {'pickup_latitude': '40.707562000000003',
#   'pickup_longitude': '-74.004372000000004',
#   'trip_distance': '2.3300000000000001'},
#  {'pickup_latitude': '40.753309999999999',
#   'pickup_longitude': '-73.968992',
#   'trip_distance': '1.05'},
#  {'pickup_latitude': '40.769545000000001',
#   'pickup_longitude': '-73.960554000000002',
#   'trip_distance': '1.2'},
#  {'pickup_latitude': '40.77411',
#   'pickup_longitude': '-73.874624999999995',
#   'trip_distance': '9.3699999999999992'},
#  {'pickup_latitude': '40.720615000000002',
#   'pickup_longitude': '-74.009874999999994',
#   'trip_distance': '1.77'},
#  {'pickup_latitude': '40.76305',
#   'pickup_longitude': '-73.969830999999999',
#   'trip_distance': '0.59999999999999998'},
#  {'pickup_latitude': '40.648605000000003',
#   'pickup_longitude': '-73.784819999999996',
#   'trip_distance': '18.199999999999999'},
#  {'pickup_latitude': '40.730874999999997',
#   'pickup_longitude': '-74.001526999999996',
#   'trip_distance': '2.29'},
#  {'pickup_latitude': '40.763843000000001',
#   'pickup_longitude': '-73.928025000000005',
#   'trip_distance': '3.1000000000000001'},
#  {'pickup_latitude': '40.759867',
#   'pickup_longitude': '-73.978350000000006',
#   'trip_distance': '1.8999999999999999'},
#  {'pickup_latitude': '40.773020000000002',
#   'pickup_longitude': '-73.981999999999999',
#   'trip_distance': '0.93999999999999995'},
#  {'pickup_latitude': '40.767437000000001',
#   'pickup_longitude': '-73.980957000000004',
#   'trip_distance': '2.7000000000000002'},
#  {'pickup_latitude': '40.795099999999998',
#   'pickup_longitude': '-73.97166',
#   'trip_distance': '0.20000000000000001'},
#  {'pickup_latitude': '40.780450000000002',
#   'pickup_longitude': '-73.980198000000001',
#   'trip_distance': '2.1000000000000001'},
#  {'pickup_latitude': '40.777608000000001',
#   'pickup_longitude': '-73.956815000000006',
#   'trip_distance': '1.3999999999999999'},
#  {'pickup_latitude': '40.783897000000003',
#   'pickup_longitude': '-73.952305999999993',
#   'trip_distance': '2.5'},
#  {'pickup_latitude': '40.738436999999998',
#   'pickup_longitude': '-73.999685999999997',
#   'trip_distance': '0.29999999999999999'},
#  {'pickup_latitude': '40.766227000000001',
#   'pickup_longitude': '-73.980152000000004',
#   'trip_distance': '2.6099999999999999'},
#  {'pickup_latitude': '40.747199999999999',
#   'pickup_longitude': '-74.007947000000001',
#   'trip_distance': '3.2000000000000002'},
#  {'pickup_latitude': '40.729602',
#   'pickup_longitude': '-73.987031999999999',
#   'trip_distance': '1.6299999999999999'},
#  {'pickup_latitude': '40.747295000000001',
#   'pickup_longitude': '-74.000877000000003',
#   'trip_distance': '1.8600000000000001'},
#  {'pickup_latitude': '40.764276000000002',
#   'pickup_longitude': '-73.954283000000004',
#   'trip_distance': '2.2999999999999998'},
#  {'pickup_latitude': '40.717463000000002',
#   'pickup_longitude': '-74.005493999999999',
#   'trip_distance': '2'},
#  {'pickup_latitude': '40.756667',
#   'pickup_longitude': '-73.967298',
#   'trip_distance': '3.0600000000000001'},
#  {'pickup_latitude': '40.723036',
#   'pickup_longitude': '-73.988782999999998',
#   'trip_distance': '3.3999999999999999'},
#  {'pickup_latitude': '40.742832',
#   'pickup_longitude': '-73.989063999999999',
#   'trip_distance': '1.3999999999999999'},
#  {'pickup_latitude': '40.759824999999999',
#   'pickup_longitude': '-73.970230999999998',
#   'trip_distance': '2.2999999999999998'},
#  {'pickup_latitude': '40.770567',
#   'pickup_longitude': '-73.954640999999995',
#   'trip_distance': '3.7999999999999998'},
#  {'pickup_latitude': '40.743564999999997',
#   'pickup_longitude': '-73.988827000000001',
#   'trip_distance': '0.72999999999999998'},
#  {'pickup_latitude': '40.761372000000001',
#   'pickup_longitude': '-73.982602',
#   'trip_distance': '0.57999999999999996'},
#  {'pickup_latitude': '40.725012',
#   'pickup_longitude': '-73.995491999999999',
#   'trip_distance': '0.059999999999999998'},
#  {'pickup_latitude': '40.751251000000003',
#   'pickup_longitude': '-73.975745000000003',
#   'trip_distance': '1.1000000000000001'},
#  {'pickup_latitude': '40.742522000000001',
#   'pickup_longitude': '-73.993291999999997',
#   'trip_distance': '0.64000000000000001'},
#  {'pickup_latitude': '40.762107',
#   'pickup_longitude': '-73.984790000000004',
#   'trip_distance': '1.72'},
#  {'pickup_latitude': '40.787171000000001',
#   'pickup_longitude': '-73.953967000000006',
#   'trip_distance': '0.20000000000000001'},
#  {'pickup_latitude': '40.739887000000003',
#   'pickup_longitude': '-74.004942',
#   'trip_distance': '0.87'},
#  {'pickup_latitude': '40.775297000000002',
#   'pickup_longitude': '-73.982005000000001',
#   'trip_distance': '2.4700000000000002'},
#  {'pickup_latitude': '40.743231999999999',
#   'pickup_longitude': '-73.983750999999998',
#   'trip_distance': '0.69999999999999996'},
#  {'pickup_latitude': '40.757385999999997',
#   'pickup_longitude': '-73.987252999999995',
#   'trip_distance': '1.8999999999999999'},
#  {'pickup_latitude': '40.749026999999998',
#   'pickup_longitude': '-73.983949999999993',
#   'trip_distance': '0.56999999999999995'},
#  {'pickup_latitude': '40.752384999999997',
#   'pickup_longitude': '-73.978313999999997',
#   'trip_distance': '2.1000000000000001'},
#  {'pickup_latitude': '40.721988000000003',
#   'pickup_longitude': '-73.986383000000004',
#   'trip_distance': '4'},
#  {'pickup_latitude': '40.742421999999998',
#   'pickup_longitude': '-73.991082000000006',
#   'trip_distance': '1.04'},
#  {'pickup_latitude': '40.735396000000001',
#   'pickup_longitude': '-73.993910999999997',
#   'trip_distance': '0.80000000000000004'},
#  {'pickup_latitude': '40.749873000000001',
#   'pickup_longitude': '-73.991592999999995',
#   'trip_distance': '3.2999999999999998'},
#  {'pickup_latitude': '40.779446999999998',
#   'pickup_longitude': '-73.962046999999998',
#   'trip_distance': '1.3500000000000001'},
#  {'pickup_latitude': '40.730843',
#   'pickup_longitude': '-74.006770000000003',
#   'trip_distance': '5'},
#  {'pickup_latitude': '40.750115999999998',
#   'pickup_longitude': '-73.987503000000004',
#   'trip_distance': '2'},
#  {'pickup_latitude': '40.701734000000002',
#   'pickup_longitude': '-74.011263',
#   'trip_distance': '5.2000000000000002'},
#  {'pickup_latitude': '40.726349999999996',
#   'pickup_longitude': '-73.977048999999994',
#   'trip_distance': '2.2000000000000002'},
#  {'pickup_latitude': '40.688701999999999',
#   'pickup_longitude': '-73.98921',
#   'trip_distance': '5.5'},
#  {'pickup_latitude': '40.771385000000002',
#   'pickup_longitude': '-73.964669999999998',
#   'trip_distance': '1.49'},
#  {'pickup_latitude': '40.715884000000003',
#   'pickup_longitude': '-73.959979000000004',
#   'trip_distance': '0.59999999999999998'},
#  {'pickup_latitude': '40.790045999999997',
#   'pickup_longitude': '-73.975065999999998',
#   'trip_distance': '1.3999999999999999'},
#  {'pickup_latitude': '40.764180000000003',
#   'pickup_longitude': '-73.978219999999993',
#   'trip_distance': '1.4399999999999999'},
#  {'pickup_latitude': '40.76041',
#   'pickup_longitude': '-73.987651999999997',
#   'trip_distance': '5.2999999999999998'},
#  {'pickup_latitude': '40.745646999999998',
#   'pickup_longitude': '-73.978274999999996',
#   'trip_distance': '0.42999999999999999'},
#  {'pickup_latitude': '40.793261000000001',
#   'pickup_longitude': '-73.940565000000007',
#   'trip_distance': '0.5'},
#  {'pickup_latitude': '40.762110999999997',
#   'pickup_longitude': '-73.968438000000006',
#   'trip_distance': '0.90000000000000002'},
#  {'pickup_latitude': '40.747329999999998',
#   'pickup_longitude': '-73.996899999999997',
#   'trip_distance': '1.6499999999999999'},
#  {'pickup_latitude': '40.748860000000001',
#   'pickup_longitude': '-73.988665999999995',
#   'trip_distance': '0.5'},
#  {'pickup_latitude': '40.730145',
#   'pickup_longitude': '-73.986395000000002',
#   'trip_distance': '2'},
#  {'pickup_latitude': '40.75318',
#   'pickup_longitude': '-73.973151999999999',
#   'trip_distance': '6.5999999999999996'},
#  {'pickup_latitude': '40.829557000000001',
#   'pickup_longitude': '-73.837699000000001',
#   'trip_distance': '1.8999999999999999'},
#  {'pickup_latitude': '40.743102',
#   'pickup_longitude': '-73.973988000000006',
#   'trip_distance': '2.2999999999999998'},
#  {'pickup_latitude': '40.750444999999999',
#   'pickup_longitude': '-73.986739999999998',
#   'trip_distance': '0.59999999999999998'},
#  {'pickup_latitude': '40.743474999999997',
#   'pickup_longitude': '-73.923154999999994',
#   'trip_distance': '8.2599999999999998'},
#  {'pickup_latitude': '40.762751999999999',
#   'pickup_longitude': '-73.993035000000006',
#   'trip_distance': '1.03'},
#  {'pickup_latitude': '40.765577',
#   'pickup_longitude': '-73.979713000000004',
#   'trip_distance': '3.02'},
#  {'pickup_latitude': '40.750027000000003',
#   'pickup_longitude': '-73.898759999999996',
#   'trip_distance': '0.97999999999999998'},
#  {'pickup_latitude': '40.751947000000001',
#   'pickup_longitude': '-73.986142000000001',
#   'trip_distance': '1.1299999999999999'},
#  {'pickup_latitude': '40.719720000000002',
#   'pickup_longitude': '-74.008841000000004',
#   'trip_distance': '1.3999999999999999'},
#  {'pickup_latitude': '40.780790000000003',
#   'pickup_longitude': '-73.946522000000002',
#   'trip_distance': '0.69999999999999996'},
#  {'pickup_latitude': '40.751607',
#   'pickup_longitude': '-73.993448999999998',
#   'trip_distance': '0.40000000000000002'},
#  {'pickup_latitude': '40.745595000000002',
#   'pickup_longitude': '-73.988398000000004',
#   'trip_distance': '1.3600000000000001'},
#  {'pickup_latitude': '40.722450000000002',
#   'pickup_longitude': '-73.987290000000002',
#   'trip_distance': '7.46'},
#  {'pickup_latitude': '40.702556999999999',
#   'pickup_longitude': '-73.934669999999997',
#   'trip_distance': '3.0299999999999998'},
#  {'pickup_latitude': '40.734659000000001',
#   'pickup_longitude': '-73.980040000000002',
#   'trip_distance': '2.1000000000000001'},
#  {'pickup_latitude': '40.764774000000003',
#   'pickup_longitude': '-73.992048999999994',
#   'trip_distance': '0.5'},
#  {'pickup_latitude': '40.723515999999996',
#   'pickup_longitude': '-73.985065000000006',
#   'trip_distance': '0.40000000000000002'},
#  {'pickup_latitude': '40.781072000000002',
#   'pickup_longitude': '-73.983537999999996',
#   'trip_distance': '1.8799999999999999'},
#  {'pickup_latitude': '40.793005000000001',
#   'pickup_longitude': '-73.973026000000004',
#   'trip_distance': '1.3'},
#  {'pickup_latitude': '40.721024999999997',
#   'pickup_longitude': '-73.993857000000006',
#   'trip_distance': '5.29'},
#  {'pickup_latitude': '40.768497000000004',
#   'pickup_longitude': '-73.899784999999994',
#   'trip_distance': '0.69999999999999996'},
#  {'pickup_latitude': '40.807259999999999',
#   'pickup_longitude': '-73.954178999999996',
#   'trip_distance': '0'},
#  {'pickup_latitude': '40.773715000000003',
#   'pickup_longitude': '-73.963908000000004',
#   'trip_distance': '1.72'},
#  {'pickup_latitude': '40.780082',
#   'pickup_longitude': '-73.956843000000006',
#   'trip_distance': '1.4199999999999999'},
#  {'pickup_latitude': '40.741824000000001',
#   'pickup_longitude': '-73.982933000000003',
#   'trip_distance': '7.4000000000000004'},
#  {'pickup_latitude': '40.742111999999999',
#   'pickup_longitude': '-74.004671999999999',
#   'trip_distance': '3.1200000000000001'},
#  {'pickup_latitude': '40.725924999999997',
#   'pickup_longitude': '-74.007585000000006',
#   'trip_distance': '5.4000000000000004'},
#  {'pickup_latitude': '40.645718000000002',
#   'pickup_longitude': '-73.776764999999997',
#   'trip_distance': '20.5'},
#  {'pickup_latitude': '40.718398000000001',
#   'pickup_longitude': '-73.994967000000003',
#   'trip_distance': '9.4000000000000004'},
#  {'pickup_latitude': '0',
#   'pickup_longitude': '0',
#   'trip_distance': '2.7999999999999998'},
#  {'pickup_latitude': '40.736342999999998',
#   'pickup_longitude': '-73.992890000000003',
#   'trip_distance': '0.69999999999999996'},
#  {'pickup_latitude': '40.753827000000001',
#   'pickup_longitude': '-73.994472000000002',
#   'trip_distance': '17.649999999999999'},
#  {'pickup_latitude': '40.750692999999998',
#   'pickup_longitude': '-73.971834000000001',
#   'trip_distance': '1.8'},
#  {'pickup_latitude': '40.745964000000001',
#   'pickup_longitude': '-73.991152',
#   'trip_distance': '0.80000000000000004'},
#  {'pickup_latitude': '40.740482',
#   'pickup_longitude': '-74.004041999999998',
#   'trip_distance': '1.9299999999999999'},
#  {'pickup_latitude': '0',
#   'pickup_longitude': '0',
#   'trip_distance': '0.29999999999999999'},
#  {'pickup_latitude': '40.803842000000003',
#   'pickup_longitude': '-73.966812000000004',
#   'trip_distance': '8.7400000000000002'},
#  {'pickup_latitude': '40.797632',
#   'pickup_longitude': '-73.969821999999994',
#   'trip_distance': '0.72999999999999998'},
#  {'pickup_latitude': '40.645322',
#   'pickup_longitude': '-73.776651999999999',
#   'trip_distance': '19.050000000000001'},
#  {'pickup_latitude': '40.749206999999998',
#   'pickup_longitude': '-74.003232999999994',
#   'trip_distance': '0.75'},
#  {'pickup_latitude': '40.765548000000003',
#   'pickup_longitude': '-73.983682999999999',
#   'trip_distance': '2.1000000000000001'},
#  {'pickup_latitude': '40.760289',
#   'pickup_longitude': '-73.931531000000007',
#   'trip_distance': '0.80000000000000004'},
#  {'pickup_latitude': '40.778967000000002',
#   'pickup_longitude': '-73.981767000000005',
#   'trip_distance': '3.6000000000000001'},
#  {'pickup_latitude': '40.758200000000002',
#   'pickup_longitude': '-73.973285000000004',
#   'trip_distance': '3.5899999999999999'},
#  {'pickup_latitude': '40.730708999999997',
#   'pickup_longitude': '-73.990504000000001',
#   'trip_distance': '2.5'},
#  {'pickup_latitude': '40.745600000000003',
#   'pickup_longitude': '-73.978139999999996',
#   'trip_distance': '1.29'},
#  {'pickup_latitude': '40.719470999999999',
#   'pickup_longitude': '-73.999779000000004',
#   'trip_distance': '1.3999999999999999'},
#  {'pickup_latitude': '40.756189999999997',
#   'pickup_longitude': '-73.974282000000002',
#   'trip_distance': '1.03'},
#  {'pickup_latitude': '40.639541999999999',
#   'pickup_longitude': '-73.967915000000005',
#   'trip_distance': '3.0800000000000001'},
#  {'pickup_latitude': '40.783659999999998',
#   'pickup_longitude': '-73.974270000000004',
#   'trip_distance': '1.77'},
#  {'pickup_latitude': '40.746400000000001',
#   'pickup_longitude': '-73.977710000000002',
#   'trip_distance': '0.73999999999999999'},
#  {'pickup_latitude': '40.727474999999998',
#   'pickup_longitude': '-73.985330000000005',
#   'trip_distance': '3.98'},
#  {'pickup_latitude': '40.735014999999997',
#   'pickup_longitude': '-74.006023999999996',
#   'trip_distance': '1.3'},
#  {'pickup_latitude': '0',
#   'pickup_longitude': '0',
#   'trip_distance': '1.1000000000000001'},
#  {'pickup_latitude': '0',
#   'pickup_longitude': '0',
#   'trip_distance': '1.3300000000000001'},
#  {'pickup_latitude': '40.754176000000001',
#   'pickup_longitude': '-74.044420000000002',
#   'trip_distance': '1.8'},
#  {'pickup_latitude': '40.740112000000003',
#   'pickup_longitude': '-73.994986999999995',
#   'trip_distance': '1.1000000000000001'},
#  {'pickup_latitude': '40.719971999999999',
#   'pickup_longitude': '-73.987553000000005',
#   'trip_distance': '2.0699999999999998'},
#  {'pickup_latitude': '40.705170000000003',
#   'pickup_longitude': '-74.006986999999995',
#   'trip_distance': '2.4300000000000002'},
#  {'pickup_latitude': '40.789141999999998',
#   'pickup_longitude': '-73.970472000000001',
#   'trip_distance': '2.1800000000000002'},
#  {'pickup_latitude': '40.749115000000003',
#   'pickup_longitude': '-73.984182000000004',
#   'trip_distance': '4.7199999999999998'},
#  {'pickup_latitude': '40.764429999999997',
#   'pickup_longitude': '-73.992036999999996',
#   'trip_distance': '2.1499999999999999'},
#  {'pickup_latitude': '40.756476999999997',
#   'pickup_longitude': '-73.990471999999997',
#   'trip_distance': '3.5'},
#  {'pickup_latitude': '40.746141999999999',
#   'pickup_longitude': '-73.984852000000004',
#   'trip_distance': '1.52'},
#  {'pickup_latitude': '40.747855999999999',
#   'pickup_longitude': '-73.989087999999995',
#   'trip_distance': '1.3999999999999999'},
#  {'pickup_latitude': '40.772615000000002',
#   'pickup_longitude': '-73.964788999999996',
#   'trip_distance': '1.3'},
#  {'pickup_latitude': '40.761912000000002',
#   'pickup_longitude': '-73.975274999999996',
#   'trip_distance': '0.59999999999999998'},
#  {'pickup_latitude': '40.740991000000001',
#   'pickup_longitude': '-74.005581000000006',
#   'trip_distance': '1'},
#  {'pickup_latitude': '40.764114999999997',
#   'pickup_longitude': '-73.977069999999998',
#   'trip_distance': '3.8399999999999999'},
#  {'pickup_latitude': '40.728808000000001',
#   'pickup_longitude': '-73.987538000000001',
#   'trip_distance': '16.399999999999999'},
#  {'pickup_latitude': '40.725510999999997',
#   'pickup_longitude': '-73.991952999999995',
#   'trip_distance': '4.2000000000000002'},
#  {'pickup_latitude': '40.768967000000004',
#   'pickup_longitude': '-73.954821999999993',
#   'trip_distance': '1.0900000000000001'},
#  {'pickup_latitude': '40.756520000000002',
#   'pickup_longitude': '-73.973926000000006',
#   'trip_distance': '2.7000000000000002'},
#  {'pickup_latitude': '40.751216999999997',
#   'pickup_longitude': '-73.970894999999999',
#   'trip_distance': '0.88'},
#  {'pickup_latitude': '40.779556999999997',
#   'pickup_longitude': '-73.977187000000001',
#   'trip_distance': '1.0900000000000001'},
#  {'pickup_latitude': '40.771472000000003',
#   'pickup_longitude': '-73.875500000000002',
#   'trip_distance': '12.06'},
#  {'pickup_latitude': '40.738320000000002',
#   'pickup_longitude': '-73.991799999999998',
#   'trip_distance': '0.45000000000000001'},
#  {'pickup_latitude': '40.643172',
#   'pickup_longitude': '-73.789034999999998',
#   'trip_distance': '19.030000000000001'},
#  {'pickup_latitude': '40.769387000000002',
#   'pickup_longitude': '-73.953622999999993',
#   'trip_distance': '0.45000000000000001'},
#  {'pickup_latitude': '40.731752',
#   'pickup_longitude': '-74.000932000000006',
#   'trip_distance': '1.28'},
#  {'pickup_latitude': '40.745874000000001',
#   'pickup_longitude': '-73.991095000000001',
#   'trip_distance': '16.100000000000001'},
#  {'pickup_latitude': '40.767867000000003',
#   'pickup_longitude': '-73.963892999999999',
#   'trip_distance': '0.20000000000000001'},
#  {'pickup_latitude': '40.766244999999998',
#   'pickup_longitude': '-73.983540000000005',
#   'trip_distance': '1.04'},
#  {'pickup_latitude': '40.753484999999998',
#   'pickup_longitude': '-73.973110000000005',
#   'trip_distance': '0.76000000000000001'},
#  {'pickup_latitude': '40.726596999999998',
#   'pickup_longitude': '-73.986165',
#   'trip_distance': '1.26'},
#  {'pickup_latitude': '40.744599999999998',
#   'pickup_longitude': '-73.985231999999996',
#   'trip_distance': '0.58999999999999997'},
#  {'pickup_latitude': '40.756805999999997',
#   'pickup_longitude': '-73.969385000000003',
#   'trip_distance': '2.7999999999999998'},
#  {'pickup_latitude': '40.783447000000002',
#   'pickup_longitude': '-73.947282999999999',
#   'trip_distance': '1.4199999999999999'},
#  {'pickup_latitude': '40.758985000000003',
#   'pickup_longitude': '-73.989435',
#   'trip_distance': '6.1299999999999999'},
#  {'pickup_latitude': '40.645316000000001',
#   'pickup_longitude': '-73.776808000000003',
#   'trip_distance': '17.5'},
#  {'pickup_latitude': '40.762867999999997',
#   'pickup_longitude': '-73.983232999999998',
#   'trip_distance': '8.3000000000000007'},
#  {'pickup_latitude': '40.761322',
#   'pickup_longitude': '-73.975755000000007',
#   'trip_distance': '0.65000000000000002'},
#  {'pickup_latitude': '40.771096999999997',
#   'pickup_longitude': '-73.865913000000006',
#   'trip_distance': '9.6099999999999994'},
#  {'pickup_latitude': '40.760195000000003',
#   'pickup_longitude': '-73.967307000000005',
#   'trip_distance': '2.2999999999999998'},
#  {'pickup_latitude': '40.732860000000002',
#   'pickup_longitude': '-74.000069999999994',
#   'trip_distance': '4.9199999999999999'},
#  {'pickup_latitude': '40.759520000000002',
#   'pickup_longitude': '-73.985488000000004',
#   'trip_distance': '2.3999999999999999'},
#  {'pickup_latitude': '40.821517',
#   'pickup_longitude': '-73.954177000000001',
#   'trip_distance': '0.59999999999999998'},
#  {'pickup_latitude': '40.734921999999997',
#   'pickup_longitude': '-73.990548000000004',
#   'trip_distance': '1.2'},
#  {'pickup_latitude': '40.757593999999997',
#   'pickup_longitude': '-73.989530999999999',
#   'trip_distance': '1.3'},
#  {'pickup_latitude': '40.748041999999998',
#   'pickup_longitude': '-73.880385000000004',
#   'trip_distance': '0.63'},
#  {'pickup_latitude': '40.749569999999999',
#   'pickup_longitude': '-73.992772000000002',
#   'trip_distance': '6.04'},
#  {'pickup_latitude': '40.759663000000003',
#   'pickup_longitude': '-73.981140999999994',
#   'trip_distance': '2.2000000000000002'},
#  {'pickup_latitude': '40.756397',
#   'pickup_longitude': '-73.966881999999998',
#   'trip_distance': '1.8500000000000001'},
#  {'pickup_latitude': '40.680779999999999',
#   'pickup_longitude': '-73.967735000000005',
#   'trip_distance': '1.5600000000000001'},
#  {'pickup_latitude': '40.749994000000001',
#   'pickup_longitude': '-73.994031000000007',
#   'trip_distance': '2.8999999999999999'},
#  {'pickup_latitude': '40.801350999999997',
#   'pickup_longitude': '-73.961518999999996',
#   'trip_distance': '0.69999999999999996'},
#  {'pickup_latitude': '40.766222999999997',
#   'pickup_longitude': '-73.981952000000007',
#   'trip_distance': '2.3999999999999999'},
#  {'pickup_latitude': '40.740045000000002',
#   'pickup_longitude': '-73.982178000000005',
#   'trip_distance': '2.0800000000000001'},
#  {'pickup_latitude': '40.801656999999999',
#   'pickup_longitude': '-73.934415000000001',
#   'trip_distance': '6.5800000000000001'},
#  {'pickup_latitude': '40.738722000000003',
#   'pickup_longitude': '-73.987026999999998',
#   'trip_distance': '5.25'},
#  {'pickup_latitude': '40.742171999999997',
#   'pickup_longitude': '-74.008089999999996',
#   'trip_distance': '1.3'},
#  {'pickup_latitude': '40.775632999999999',
#   'pickup_longitude': '-73.982330000000005',
#   'trip_distance': '2.7999999999999998'},
#  {'pickup_latitude': '40.792377000000002',
#   'pickup_longitude': '-73.967879999999994',
#   'trip_distance': '1.29'},
#  {'pickup_latitude': '40.659956000000001',
#   'pickup_longitude': '-73.998419999999996',
#   'trip_distance': '3.2000000000000002'},
#  {'pickup_latitude': '40.765500000000003',
#   'pickup_longitude': '-73.975849999999994',
#   'trip_distance': '0.78000000000000003'},
#  {'pickup_latitude': '40.737997',
#   'pickup_longitude': '-73.992069000000001',
#   'trip_distance': '7.4000000000000004'},
#  {'pickup_latitude': '40.711466999999999',
#   'pickup_longitude': '-73.945824999999999',
#   'trip_distance': '8.8000000000000007'},
#  {'pickup_latitude': '0',
#   'pickup_longitude': '0',
#   'trip_distance': '0.10000000000000001'},
#  {'pickup_latitude': '40.710822',
#   'pickup_longitude': '-74.015591999999998',
#   'trip_distance': '3.6299999999999999'},
#  {'pickup_latitude': '40.763596999999997',
#   'pickup_longitude': '-73.979680000000002',
#   'trip_distance': '1.51'},
#  {'pickup_latitude': '40.744276999999997',
#   'pickup_longitude': '-73.973006999999996',
#   'trip_distance': '1.5'},
#  {'pickup_latitude': '40.774152000000001',
#   'pickup_longitude': '-73.873092',
#   'trip_distance': '6.54'},
#  {'pickup_latitude': '40.773736',
#   'pickup_longitude': '-73.959905000000006',
#   'trip_distance': '0.20000000000000001'},
#  {'pickup_latitude': '40.740017999999999',
#   'pickup_longitude': '-74.005398999999997',
#   'trip_distance': '4.5'},
#  {'pickup_latitude': '40.750093999999997',
#   'pickup_longitude': '-73.979116000000005',
#   'trip_distance': '1'},
#  {'pickup_latitude': '40.741317000000002',
#   'pickup_longitude': '-73.983401999999998',
#   'trip_distance': '2.0600000000000001'},
#  {'pickup_latitude': '40.758850000000002',
#   'pickup_longitude': '-73.965817000000001',
#   'trip_distance': '1.8999999999999999'},
#  {'pickup_latitude': '40.687077000000002',
#   'pickup_longitude': '-73.990202999999994',
#   'trip_distance': '2.6000000000000001'},
#  {'pickup_latitude': '40.767049999999998',
#   'pickup_longitude': '-73.979221999999993',
#   'trip_distance': '0.71999999999999997'},
#  {'pickup_latitude': '40.722569999999997',
#   'pickup_longitude': '-73.997073',
#   'trip_distance': '1'},
#  {'pickup_latitude': '40.779580000000003',
#   'pickup_longitude': '-73.957862000000006',
#   'trip_distance': '0.25'},
#  {'pickup_latitude': '40.738500000000002',
#   'pickup_longitude': '-73.985299999999995',
#   'trip_distance': '1.3400000000000001'},
#  {'pickup_latitude': '40.770377000000003',
#   'pickup_longitude': '-73.982127000000006',
#   'trip_distance': '2.1000000000000001'},
#  {'pickup_latitude': '40.759059999999998',
#   'pickup_longitude': '-73.983681000000004',
#   'trip_distance': '3.2999999999999998'},
#  {'pickup_latitude': '40.689827000000001',
#   'pickup_longitude': '-73.992350000000002',
#   'trip_distance': '2.2400000000000002'},
#  {'pickup_latitude': '40.766367000000002',
#   'pickup_longitude': '-73.952442000000005',
#   'trip_distance': '17.550000000000001'},
#  {'pickup_latitude': '40.717301999999997',
#   'pickup_longitude': '-73.998980000000003',
#   'trip_distance': '3.0800000000000001'},
#  {'pickup_latitude': '40.642817000000001',
#   'pickup_longitude': '-73.788911999999996',
#   'trip_distance': '24.550000000000001'},
#  {'pickup_latitude': '40.766804',
#   'pickup_longitude': '-73.969071',
#   'trip_distance': '5.0999999999999996'},
#  {'pickup_latitude': '40.762317000000003',
#   'pickup_longitude': '-73.985929999999996',
#   'trip_distance': '1.1799999999999999'},
#  {'pickup_latitude': '40.734099000000001',
#   'pickup_longitude': '-73.999288000000007',
#   'trip_distance': '1.3'},
#  {'pickup_latitude': '40.770736999999997',
#   'pickup_longitude': '-73.957142000000005',
#   'trip_distance': '2.5800000000000001'},
#  {'pickup_latitude': '40.724919',
#   'pickup_longitude': '-73.998966999999993',
#   'trip_distance': '2.6000000000000001'},
#  {'pickup_latitude': '40.729686999999998',
#   'pickup_longitude': '-73.998357999999996',
#   'trip_distance': '1.2'},
#  {'pickup_latitude': '40.744083000000003',
#   'pickup_longitude': '-73.985686999999999',
#   'trip_distance': '0.90000000000000002'},
#  {'pickup_latitude': '40.726413000000001',
#   'pickup_longitude': '-73.977196000000006',
#   'trip_distance': '1.3'},
#  {'pickup_latitude': '40.794009000000003',
#   'pickup_longitude': '-73.966721000000007',
#   'trip_distance': '0.59999999999999998'},
#  {'pickup_latitude': '40.745890000000003',
#   'pickup_longitude': '-73.994388000000001',
#   'trip_distance': '1.3999999999999999'},
#  {'pickup_latitude': '40.752839999999999',
#   'pickup_longitude': '-73.989232000000001',
#   'trip_distance': '0.34999999999999998'},
#  {'pickup_latitude': '40.777652000000003',
#   'pickup_longitude': '-73.959298000000004',
#   'trip_distance': '1.1399999999999999'},
#  {'pickup_latitude': '40.726934999999997',
#   'pickup_longitude': '-73.991668000000004',
#   'trip_distance': '2.0600000000000001'},
#  {'pickup_latitude': '40.749690000000001',
#   'pickup_longitude': '-73.977509999999995',
#   'trip_distance': '1.01'},
#  {'pickup_latitude': '40.709355000000002',
#   'pickup_longitude': '-74.016717',
#   'trip_distance': '5.1399999999999997'},
#  {'pickup_latitude': '40.750098999999999',
#   'pickup_longitude': '-73.991249999999994',
#   'trip_distance': '3'},
# ...
#   'pickup_longitude': '-73.989909999999995',
#   'trip_distance': '1.5600000000000001'},
#  {'pickup_latitude': '40.763148000000001',
#   'pickup_longitude': '-73.979234000000005',
#   'trip_distance': '1.1000000000000001'},
#  {'pickup_latitude': '40.70626',
#   'pickup_longitude': '-74.004265000000004',
#   'trip_distance': '1.6200000000000001'},
#  {'pickup_latitude': '40.782010999999997',
#   'pickup_longitude': '-73.956252000000006',
#   'trip_distance': '3.6000000000000001'},
#  {'pickup_latitude': '40.671486999999999',
#   'pickup_longitude': '-73.984353999999996',
#   'trip_distance': '0.59999999999999998'},
#  {'pickup_latitude': '40.753034',
#   'pickup_longitude': '-73.989328999999998',
#   'trip_distance': '1.2'},
#  {'pickup_latitude': '40.744996999999998',
#   'pickup_longitude': '-73.981731999999994',
#   'trip_distance': '0.81000000000000005'},
#  {'pickup_latitude': '40.721882000000001',
#   'pickup_longitude': '-73.989213000000007',
#   'trip_distance': '4.1100000000000003'},
#  {'pickup_latitude': '40.752341999999999',
#   'pickup_longitude': '-73.974745999999996',
#   'trip_distance': '7.5999999999999996'},
#  {'pickup_latitude': '40.709415',
#   'pickup_longitude': '-74.008146999999994',
#   'trip_distance': '3.2999999999999998'},
#  {'pickup_latitude': '40.755637',
#   'pickup_longitude': '-73.964820000000003',
#   'trip_distance': '0.57999999999999996'},
#  {'pickup_latitude': '40.780847000000001',
#   'pickup_longitude': '-73.981521999999998',
#   'trip_distance': '1'},
#  {'pickup_latitude': '40.73668',
#   'pickup_longitude': '-73.995367999999999',
#   'trip_distance': '1.1000000000000001'},
#  {'pickup_latitude': '40.707517000000003',
#   'pickup_longitude': '-74.004445000000004',
#   'trip_distance': '7.7999999999999998'},
#  {'pickup_latitude': '40.73706',
#   'pickup_longitude': '-73.990120000000005',
#   'trip_distance': '1.0900000000000001'},
#  {'pickup_latitude': '40.769119000000003',
#   'pickup_longitude': '-73.987084999999993',
#   'trip_distance': '4.0999999999999996'},
#  {'pickup_latitude': '40.750492000000001',
#   'pickup_longitude': '-73.994649999999993',
#   'trip_distance': '2.6400000000000001'},
#  {'pickup_latitude': '40.779415999999998',
#   'pickup_longitude': '-73.957447999999999',
#   'trip_distance': '11.300000000000001'},
#  {'pickup_latitude': '40.779454000000001',
#   'pickup_longitude': '-73.961831000000004',
#   'trip_distance': '1.7'},
#  {'pickup_latitude': '40.773952000000001',
#   'pickup_longitude': '-73.871234999999999',
#   'trip_distance': '8.1199999999999992'},
#  {'pickup_latitude': '40.756805',
#   'pickup_longitude': '-73.990317000000005',
#   'trip_distance': '0.80000000000000004'},
#  {'pickup_latitude': '40.766250999999997',
#   'pickup_longitude': '-73.980109999999996',
#   'trip_distance': '0.20000000000000001'},
#  {'pickup_latitude': '40.747098000000001',
#   'pickup_longitude': '-73.986220000000003',
#   'trip_distance': '4.5999999999999996'},
#  {'pickup_latitude': '40.774346999999999',
#   'pickup_longitude': '-73.963485000000006',
#   'trip_distance': '0.90000000000000002'},
#  {'pickup_latitude': '40.737349999999999',
#   'pickup_longitude': '-73.988662000000005',
#   'trip_distance': '3.0499999999999998'},
#  {'pickup_latitude': '40.755507000000001',
#   'pickup_longitude': '-73.976157000000001',
#   'trip_distance': '1.03'},
#  {'pickup_latitude': '0',
#   'pickup_longitude': '0',
#   'trip_distance': '1.0900000000000001'},
#  {'pickup_latitude': '40.777340000000002',
#   'pickup_longitude': '-73.978577999999999',
#   'trip_distance': '2.2000000000000002'},
#  {'pickup_latitude': '40.730313000000002',
#   'pickup_longitude': '-74.000190000000003',
#   'trip_distance': '1.1000000000000001'},
#  {'pickup_latitude': '40.770964999999997',
#   'pickup_longitude': '-73.964001999999994',
#   'trip_distance': '0.78000000000000003'},
#  {'pickup_latitude': '40.747897000000002',
#   'pickup_longitude': '-74.003746000000007',
#   'trip_distance': '1.3'},
#  {'pickup_latitude': '40.743012999999998',
#   'pickup_longitude': '-73.992795999999998',
#   'trip_distance': '3.5'},
#  {'pickup_latitude': '40.757035999999999',
#   'pickup_longitude': '-73.976146',
#   'trip_distance': '2.5'},
#  {'pickup_latitude': '40.750830000000001',
#   'pickup_longitude': '-73.990808000000001',
#   'trip_distance': '1.27'},
#  {'pickup_latitude': '40.747864999999997',
#   'pickup_longitude': '-73.993219999999994',
#   'trip_distance': '0.63'},
#  {'pickup_latitude': '40.758215',
#   'pickup_longitude': '-73.937667000000005',
#   'trip_distance': '1.6599999999999999'},
#  {'pickup_latitude': '40.750686999999999',
#   'pickup_longitude': '-73.943522000000002',
#   'trip_distance': '2.3799999999999999'},
#  {'pickup_latitude': '40.734431999999998',
#   'pickup_longitude': '-73.999740000000003',
#   'trip_distance': '1.8200000000000001'},
#  {'pickup_latitude': '40.766798999999999',
#   'pickup_longitude': '-73.983306999999996',
#   'trip_distance': '2.1000000000000001'},
#  {'pickup_latitude': '40.752133000000001',
#   'pickup_longitude': '-74.004754000000005',
#   'trip_distance': '1.8999999999999999'},
#  {'pickup_latitude': '40.719627000000003',
#   'pickup_longitude': '-74.006889999999999',
#   'trip_distance': '1.3999999999999999'},
#  {'pickup_latitude': '40.770119999999999',
#   'pickup_longitude': '-73.863609999999994',
#   'trip_distance': '12.550000000000001'},
#  {'pickup_latitude': '40.753714000000002',
#   'pickup_longitude': '-73.992041999999998',
#   'trip_distance': '0.29999999999999999'},
#  {'pickup_latitude': '40.779378000000001',
#   'pickup_longitude': '-73.977469999999997',
#   'trip_distance': '1'},
#  {'pickup_latitude': '40.764966999999999',
#   'pickup_longitude': '-73.989046999999999',
#   'trip_distance': '1.5'},
#  {'pickup_latitude': '40.724772000000002',
#   'pickup_longitude': '-73.990509000000003',
#   'trip_distance': '3.8999999999999999'},
#  {'pickup_latitude': '40.734817',
#   'pickup_longitude': '-73.990454999999997',
#   'trip_distance': '2.1800000000000002'},
#  {'pickup_latitude': '40.751752000000003',
#   'pickup_longitude': '-73.990011999999993',
#   'trip_distance': '0.29999999999999999'},
#  {'pickup_latitude': '40.756563999999997',
#   'pickup_longitude': '-73.994045999999997',
#   'trip_distance': '1.2'},
#  {'pickup_latitude': '40.742736000000001',
#   'pickup_longitude': '-74.000354000000002',
#   'trip_distance': '1.5'},
#  {'pickup_latitude': '0',
#   'pickup_longitude': '0',
#   'trip_distance': '9.6999999999999993'},
#  {'pickup_latitude': '40.741672000000001',
#   'pickup_longitude': '-74.004626999999999',
#   'trip_distance': '1.28'},
#  {'pickup_latitude': '40.725969999999997',
#   'pickup_longitude': '-73.997380000000007',
#   'trip_distance': '1.3999999999999999'},
#  {'pickup_latitude': '40.743772',
#   'pickup_longitude': '-73.992388000000005',
#   'trip_distance': '1.2'},
#  {'pickup_latitude': '40.710320000000003',
#   'pickup_longitude': '-74.009676999999996',
#   'trip_distance': '0.90000000000000002'},
#  {'pickup_latitude': '40.710884999999998',
#   'pickup_longitude': '-74.010268999999994',
#   'trip_distance': '3.2000000000000002'},
#  {'pickup_latitude': '40.768566999999997',
#   'pickup_longitude': '-73.969684999999998',
#   'trip_distance': '1.46'},
#  {'pickup_latitude': '40.755322',
#   'pickup_longitude': '-73.987747999999996',
#   'trip_distance': '4.1900000000000004'},
#  {'pickup_latitude': '40.750872000000001',
#   'pickup_longitude': '-73.993015',
#   'trip_distance': '2.2999999999999998'},
#  {'pickup_latitude': '40.691887000000001',
#   'pickup_longitude': '-73.982321999999996',
#   'trip_distance': '5.7999999999999998'},
#  {'pickup_latitude': '40.753002000000002',
#   'pickup_longitude': '-73.996735000000001',
#   'trip_distance': '1.3300000000000001'},
#  {'pickup_latitude': '40.765656999999997',
#   'pickup_longitude': '-73.970444999999998',
#   'trip_distance': '0.34000000000000002'},
#  {'pickup_latitude': '40.718429',
#   'pickup_longitude': '-73.987264999999994',
#   'trip_distance': '2.2999999999999998'},
#  {'pickup_latitude': '40.752609999999997',
#   'pickup_longitude': '-73.978503000000003',
#   'trip_distance': '0.55000000000000004'},
#  {'pickup_latitude': '40.774841000000002',
#   'pickup_longitude': '-73.963199000000003',
#   'trip_distance': '0.40000000000000002'},
#  {'pickup_latitude': '40.820267000000001',
#   'pickup_longitude': '-73.955067999999997',
#   'trip_distance': '0.90000000000000002'},
#  {'pickup_latitude': '40.749904999999998',
#   'pickup_longitude': '-73.995244999999997',
#   'trip_distance': '1.98'},
#  {'pickup_latitude': '40.790222',
#   'pickup_longitude': '-73.976825000000005',
#   'trip_distance': '1.55'},
#  {'pickup_latitude': '40.751243000000002',
#   'pickup_longitude': '-73.993927999999997',
#   'trip_distance': '0.69999999999999996'},
#  {'pickup_latitude': '40.769371999999997',
#   'pickup_longitude': '-73.984836999999999',
#   'trip_distance': '0.5'},
#  {'pickup_latitude': '40.802452000000002',
#   'pickup_longitude': '-73.962299999999999',
#   'trip_distance': '2.8999999999999999'},
#  {'pickup_latitude': '40.740012',
#   'pickup_longitude': '-73.991209999999995',
#   'trip_distance': '1.1299999999999999'},
#  {'pickup_latitude': '40.724477',
#   'pickup_longitude': '-73.98706',
#   'trip_distance': '1.79'},
#  {'pickup_latitude': '40.649678999999999',
#   'pickup_longitude': '-73.804525999999996',
#   'trip_distance': '1.3999999999999999'},
#  {'pickup_latitude': '40.763433999999997',
#   'pickup_longitude': '-73.965213000000006',
#   'trip_distance': '1'},
#  {'pickup_latitude': '40.813836000000002',
#   'pickup_longitude': '-73.936919000000003',
#   'trip_distance': '0.80000000000000004'},
#  {'pickup_latitude': '40.748612999999999',
#   'pickup_longitude': '-73.983002999999997',
#   'trip_distance': '4.4000000000000004'},
#  {'pickup_latitude': '40.756067000000002',
#   'pickup_longitude': '-73.990296999999998',
#   'trip_distance': '1.51'},
#  {'pickup_latitude': '40.751126999999997',
#   'pickup_longitude': '-73.993904999999998',
#   'trip_distance': '0.95999999999999996'},
#  {'pickup_latitude': '40.757541000000003',
#   'pickup_longitude': '-73.974641000000005',
#   'trip_distance': '10.9'},
#  {'pickup_latitude': '40.783417',
#   'pickup_longitude': '-73.951312999999999',
#   'trip_distance': '1'},
#  {'pickup_latitude': '40.755617000000001',
#   'pickup_longitude': '-73.962447999999995',
#   'trip_distance': '0.90000000000000002'},
#  {'pickup_latitude': '40.770837',
#   'pickup_longitude': '-73.991015000000004',
#   'trip_distance': '1.5'},
#  {'pickup_latitude': '40.770932000000002',
#   'pickup_longitude': '-73.866219999999998',
#   'trip_distance': '2.5499999999999998'},
#  {'pickup_latitude': '40.742624999999997',
#   'pickup_longitude': '-73.995954999999995',
#   'trip_distance': '0.69999999999999996'},
#  {'pickup_latitude': '40.767386000000002',
#   'pickup_longitude': '-73.986149999999995',
#   'trip_distance': '4.9000000000000004'},
#  {'pickup_latitude': '40.729416999999998',
#   'pickup_longitude': '-73.98997',
#   'trip_distance': '1.6200000000000001'},
#  {'pickup_latitude': '0',
#   'pickup_longitude': '0',
#   'trip_distance': '1.3999999999999999'},
#  {'pickup_latitude': '40.760260000000002',
#   'pickup_longitude': '-73.976709999999997',
#   'trip_distance': '3.3799999999999999'},
#  {'pickup_latitude': '40.748452999999998',
#   'pickup_longitude': '-73.973208999999997',
#   'trip_distance': '1.6000000000000001'},
#  {'pickup_latitude': '40.763604999999998',
#   'pickup_longitude': '-73.988950000000003',
#   'trip_distance': '6.5'},
#  {'pickup_latitude': '40.735872000000001',
#   'pickup_longitude': '-74.006704999999997',
#   'trip_distance': '0.81000000000000005'},
#  {'pickup_latitude': '40.761363000000003',
#   'pickup_longitude': '-73.969672000000003',
#   'trip_distance': '0.25'},
#  {'pickup_latitude': '40.661144999999998',
#   'pickup_longitude': '-73.997122000000005',
#   'trip_distance': '2.8599999999999999'},
#  {'pickup_latitude': '40.748542',
#   'pickup_longitude': '-73.987952000000007',
#   'trip_distance': '1.05'},
#  {'pickup_latitude': '40.781112',
#   'pickup_longitude': '-73.954134999999994',
#   'trip_distance': '3.7000000000000002'},
#  {'pickup_latitude': '40.762464999999999',
#   'pickup_longitude': '-73.957121999999998',
#   'trip_distance': '1'},
#  {'pickup_latitude': '40.748049999999999',
#   'pickup_longitude': '-74.00412',
#   'trip_distance': '2.27'},
#  {'pickup_latitude': '40.780242000000001',
#   'pickup_longitude': '-73.959576999999996',
#   'trip_distance': '0.90000000000000002'},
#  {'pickup_latitude': '40.764726000000003',
#   'pickup_longitude': '-73.976782999999998',
#   'trip_distance': '3.1000000000000001'},
#  {'pickup_latitude': '40.733294000000001',
#   'pickup_longitude': '-74.002744000000007',
#   'trip_distance': '0.20000000000000001'},
#  {'pickup_latitude': '40.749760000000002',
#   'pickup_longitude': '-73.993847000000002',
#   'trip_distance': '1.0800000000000001'},
#  {'pickup_latitude': '40.753168000000002',
#   'pickup_longitude': '-73.969728000000003',
#   'trip_distance': '1.7'},
#  {'pickup_latitude': '40.764099000000002',
#   'pickup_longitude': '-73.973033000000001',
#   'trip_distance': '0.80000000000000004'},
#  {'pickup_latitude': '40.796756999999999',
#   'pickup_longitude': '-73.970536999999993',
#   'trip_distance': '6.7999999999999998'},
#  {'pickup_latitude': '40.765014999999998',
#   'pickup_longitude': '-73.976836000000006',
#   'trip_distance': '1.1000000000000001'},
#  {'pickup_latitude': '40.722397000000001',
#   'pickup_longitude': '-73.988933000000003',
#   'trip_distance': '0.59999999999999998'},
#  {'pickup_latitude': '40.784722000000002',
#   'pickup_longitude': '-73.958017999999996',
#   'trip_distance': '1.48'},
#  {'pickup_latitude': '40.734082000000001',
#   'pickup_longitude': '-74.006202000000002',
#   'trip_distance': '2.0299999999999998'},
#  {'pickup_latitude': '40.747720000000001',
#   'pickup_longitude': '-73.982740000000007',
#   'trip_distance': '0.56000000000000005'},
#  {'pickup_latitude': '40.774329000000002',
#   'pickup_longitude': '-73.988896999999994',
#   'trip_distance': '2.2999999999999998'},
#  {'pickup_latitude': '40.742365999999997',
#   'pickup_longitude': '-73.993170000000006',
#   'trip_distance': '0.59999999999999998'},
#  {'pickup_latitude': '40.739342000000001',
#   'pickup_longitude': '-74.001677000000001',
#   'trip_distance': '0.69999999999999996'},
#  {'pickup_latitude': '40.756363',
#   'pickup_longitude': '-73.985772999999995',
#   'trip_distance': '1.3999999999999999'},
#  {'pickup_latitude': '40.738253999999998',
#   'pickup_longitude': '-73.983498999999995',
#   'trip_distance': '3.7999999999999998'},
#  {'pickup_latitude': '40.735045999999997',
#   'pickup_longitude': '-73.990119000000007',
#   'trip_distance': '1.1000000000000001'},
#  {'pickup_latitude': '40.755856999999999',
#   'pickup_longitude': '-73.997045',
#   'trip_distance': '3.1000000000000001'},
#  {'pickup_latitude': '40.772357',
#   'pickup_longitude': '-73.960926999999998',
#   'trip_distance': '0.88'},
#  {'pickup_latitude': '40.775272000000001',
#   'pickup_longitude': '-73.950429999999997',
#   'trip_distance': '1.78'},
#  {'pickup_latitude': '40.763641999999997',
#   'pickup_longitude': '-73.988995000000003',
#   'trip_distance': '7.6799999999999997'},
#  {'pickup_latitude': '40.768787000000003',
#   'pickup_longitude': '-73.862844999999993',
#   'trip_distance': '12.15'},
#  {'pickup_latitude': '40.772326999999997',
#   'pickup_longitude': '-73.952635000000001',
#   'trip_distance': '0.82999999999999996'},
#  {'pickup_latitude': '40.750616999999998',
#   'pickup_longitude': '-73.973910000000004',
#   'trip_distance': '1.6000000000000001'},
#  {'pickup_latitude': '40.740490000000001',
#   'pickup_longitude': '-73.998152000000005',
#   'trip_distance': '4.2000000000000002'},
#  {'pickup_latitude': '40.759067000000002',
#   'pickup_longitude': '-73.977368999999996',
#   'trip_distance': '1.1000000000000001'},
#  {'pickup_latitude': '40.762444000000002',
#   'pickup_longitude': '-73.982439999999997',
#   'trip_distance': '0.80000000000000004'},
#  {'pickup_latitude': '40.774087000000002',
#   'pickup_longitude': '-73.874592000000007',
#   'trip_distance': '9.25'},
#  {'pickup_latitude': '40.781736000000002',
#   'pickup_longitude': '-73.981283000000005',
#   'trip_distance': '0.40000000000000002'},
#  {'pickup_latitude': '40.757812000000001',
#   'pickup_longitude': '-73.989041999999998',
#   'trip_distance': '1.46'},
#  {'pickup_latitude': '40.787171999999998',
#   'pickup_longitude': '-73.977630000000005',
#   'trip_distance': '0.53000000000000003'}]

# %%
parsed_trips = parse_trips(trips)
parsed_trips and parsed_trips[0]

# {'pickup_latitude': '40.64499',
#  'pickup_longitude': '-73.78115',
#  'trip_distance': '18.38'}
# Out:
# {'pickup_latitude': '40.64499',
#  'pickup_longitude': '-73.781149999999997',
#  'trip_distance': '18.379999999999999'}

# %% [markdown]
# Now, there's just one change to make.  If you look at one of the trips, all of the values are strings.  Let's change them to be floats.

# %%
def float_values(trips):   
    parsed_trips = parse_trips(trips)
    A = []
    for i in range(0,len(parsed_trips)):
        X = {k:float(v) for k,v in parsed_trips[i].items()}
        A.append(X)
        
    return A
    pass

#trips_clone = trips.copy()
#A = []
#for i in range(0,len(trips_clone)):
#X = {}
#X = {k:float(v) for k,v in trips_clone[i].items() if k == 'trip_distance' or k == 'pickup_latitude' or k == 'pickup_longitude'} 
#print(X)
#A.append(X) 
#return A
#pass

float_values(trips)
# Out:
# [{'pickup_latitude': 40.64499,
#   'pickup_longitude': -73.78115,
#   'trip_distance': 18.38},
#  {'pickup_latitude': 40.766931,
#   'pickup_longitude': -73.982098,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.77773,
#   'pickup_longitude': -73.951902,
#   'trip_distance': 4.5},
#  {'pickup_latitude': 40.795678,
#   'pickup_longitude': -73.971049,
#   'trip_distance': 2.4},
#  {'pickup_latitude': 40.762912,
#   'pickup_longitude': -73.967782,
#   'trip_distance': 0.84},
#  {'pickup_latitude': 40.731176,
#   'pickup_longitude': -73.991572,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.800219,
#   'pickup_longitude': -73.968098,
#   'trip_distance': 0.5},
#  {'pickup_latitude': 40.648509,
#   'pickup_longitude': -73.783508,
#   'trip_distance': 17.3},
#  {'pickup_latitude': 40.721897,
#   'pickup_longitude': -73.983493,
#   'trip_distance': 0.63},
#  {'pickup_latitude': 40.791566,
#   'pickup_longitude': -73.972224,
#   'trip_distance': 2.8},
#  {'pickup_latitude': 40.744896,
#   'pickup_longitude': -73.978619,
#   'trip_distance': 0.6},
#  {'pickup_latitude': 40.721951,
#   'pickup_longitude': -73.844435,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.732382,
#   'pickup_longitude': -74.001682,
#   'trip_distance': 4.2},
#  {'pickup_latitude': 40.768339,
#   'pickup_longitude': -73.961478,
#   'trip_distance': 0.4},
#  {'pickup_latitude': 40.775933,
#   'pickup_longitude': -73.962446,
#   'trip_distance': 0.6},
#  {'pickup_latitude': 40.794829,
#   'pickup_longitude': -73.971476,
#   'trip_distance': 9.8},
#  {'pickup_latitude': 40.758647,
#   'pickup_longitude': -73.964878,
#   'trip_distance': 1.05},
#  {'pickup_latitude': 40.713638,
#   'pickup_longitude': -74.011587,
#   'trip_distance': 0.74},
#  {'pickup_latitude': 40.77403,
#   'pickup_longitude': -73.874597,
#   'trip_distance': 8.4},
#  {'pickup_latitude': 40.728127,
#   'pickup_longitude': -73.99887,
#   'trip_distance': 5.1},
#  {'pickup_latitude': 40.759671,
#   'pickup_longitude': -73.976688,
#   'trip_distance': 1.4},
#  {'pickup_latitude': 40.772651,
#   'pickup_longitude': -73.967095,
#   'trip_distance': 2.7},
#  {'pickup_latitude': 40.770319,
#   'pickup_longitude': -73.960222,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.720457,
#   'pickup_longitude': -73.988065,
#   'trip_distance': 1.12},
#  {'pickup_latitude': 40.754789,
#   'pickup_longitude': -73.973606,
#   'trip_distance': 16.0},
#  {'pickup_latitude': 40.755654,
#   'pickup_longitude': -73.985846,
#   'trip_distance': 1.4},
#  {'pickup_latitude': 40.741568,
#   'pickup_longitude': -73.978341,
#   'trip_distance': 0.9},
#  {'pickup_latitude': 40.736907,
#   'pickup_longitude': -73.98862,
#   'trip_distance': 0.74},
#  {'pickup_latitude': 40.76003,
#   'pickup_longitude': -73.964842,
#   'trip_distance': 1.5},
#  {'pickup_latitude': 40.721366,
#   'pickup_longitude': -74.008287,
#   'trip_distance': 0.7},
#  {'pickup_latitude': 40.760147,
#   'pickup_longitude': -73.97627,
#   'trip_distance': 1.97},
#  {'pickup_latitude': 40.745847,
#   'pickup_longitude': -74.001817,
#   'trip_distance': 0.96},
#  {'pickup_latitude': 40.753015,
#   'pickup_longitude': -73.985247,
#   'trip_distance': 0.74},
#  {'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'trip_distance': 12.7},
#  {'pickup_latitude': 40.738767,
#   'pickup_longitude': -74.0086,
#   'trip_distance': 1.17},
#  {'pickup_latitude': 40.773797,
#   'pickup_longitude': -73.871065,
#   'trip_distance': 22.8},
#  {'pickup_latitude': 40.743411,
#   'pickup_longitude': -73.97686,
#   'trip_distance': 1.5},
#  {'pickup_latitude': 40.758905,
#   'pickup_longitude': -73.967897,
#   'trip_distance': 1.5},
#  {'pickup_latitude': 40.733877,
#   'pickup_longitude': -73.989602,
#   'trip_distance': 1.7},
#  {'pickup_latitude': 40.726162,
#   'pickup_longitude': -73.983432,
#   'trip_distance': 0.95},
#  {'pickup_latitude': 40.775122,
#   'pickup_longitude': -73.947765,
#   'trip_distance': 5.88},
#  {'pickup_latitude': 40.75987,
#   'pickup_longitude': -73.978487,
#   'trip_distance': 4.1},
#  {'pickup_latitude': 40.707087,
#   'pickup_longitude': -73.94328,
#   'trip_distance': 1.09},
#  {'pickup_latitude': 40.741912,
#   'pickup_longitude': -74.003578,
#   'trip_distance': 1.39},
#  {'pickup_latitude': 40.769112,
#   'pickup_longitude': -73.862679,
#   'trip_distance': 11.2},
#  {'pickup_latitude': 40.785807,
#   'pickup_longitude': -73.976387,
#   'trip_distance': 2.56},
#  {'pickup_latitude': 40.7513,
#   'pickup_longitude': -73.986852,
#   'trip_distance': 1.03},
#  {'pickup_latitude': 40.733385,
#   'pickup_longitude': -73.987204,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.760257,
#   'pickup_longitude': -73.976186,
#   'trip_distance': 0.9},
#  {'pickup_latitude': 40.741249,
#   'pickup_longitude': -74.005201,
#   'trip_distance': 3.4},
#  {'pickup_latitude': 40.759795,
#   'pickup_longitude': -73.985352,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.756636,
#   'pickup_longitude': -73.9697,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.73925,
#   'pickup_longitude': -74.000759,
#   'trip_distance': 0.6},
#  {'pickup_latitude': 40.751055,
#   'pickup_longitude': -73.97607,
#   'trip_distance': 1.07},
#  {'pickup_latitude': 40.723584,
#   'pickup_longitude': -73.995992,
#   'trip_distance': 3.9},
#  {'pickup_latitude': 40.757037,
#   'pickup_longitude': -73.929485,
#   'trip_distance': 14.43},
#  {'pickup_latitude': 40.743385,
#   'pickup_longitude': -73.981978,
#   'trip_distance': 0.6},
#  {'pickup_latitude': 40.737486,
#   'pickup_longitude': -73.978153,
#   'trip_distance': 2.1},
#  {'pickup_latitude': 40.77225,
#   'pickup_longitude': -73.95285,
#   'trip_distance': 1.76},
#  {'pickup_latitude': 40.732882,
#   'pickup_longitude': -73.981975,
#   'trip_distance': 2.45},
#  {'pickup_latitude': 40.774567,
#   'pickup_longitude': -73.988232,
#   'trip_distance': 2.03},
#  {'pickup_latitude': 40.757437,
#   'pickup_longitude': -73.964735,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.789637,
#   'pickup_longitude': -73.975402,
#   'trip_distance': 2.14},
#  {'pickup_latitude': 40.754317,
#   'pickup_longitude': -73.992548,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.745007,
#   'pickup_longitude': -73.998627,
#   'trip_distance': 0.44},
#  {'pickup_latitude': 40.734982,
#   'pickup_longitude': -73.990523,
#   'trip_distance': 1.0},
#  {'pickup_latitude': 0.0, 'pickup_longitude': 0.0, 'trip_distance': 1.95},
#  {'pickup_latitude': 40.738617,
#   'pickup_longitude': -73.989672,
#   'trip_distance': 1.48},
#  {'pickup_latitude': 40.790712,
#   'pickup_longitude': -73.972809,
#   'trip_distance': 0.5},
#  {'pickup_latitude': 40.750167,
#   'pickup_longitude': -73.987398,
#   'trip_distance': 1.5},
#  {'pickup_latitude': 40.732141,
#   'pickup_longitude': -73.98447,
#   'trip_distance': 12.7},
#  {'pickup_latitude': 40.765758,
#   'pickup_longitude': -73.994847,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.792594,
#   'pickup_longitude': -73.964102,
#   'trip_distance': 1.0},
#  {'pickup_latitude': 40.762908,
#   'pickup_longitude': -73.969549,
#   'trip_distance': 1.8},
#  {'pickup_latitude': 40.750722,
#   'pickup_longitude': -73.968447,
#   'trip_distance': 4.85},
#  {'pickup_latitude': 40.769887,
#   'pickup_longitude': -73.86443,
#   'trip_distance': 5.09},
#  {'pickup_latitude': 40.77247,
#   'pickup_longitude': -73.982419,
#   'trip_distance': 1.2},
#  {'pickup_latitude': 40.764545,
#   'pickup_longitude': -73.982668,
#   'trip_distance': 1.44},
#  {'pickup_latitude': 40.641805,
#   'pickup_longitude': -73.78641,
#   'trip_distance': 16.63},
#  {'pickup_latitude': 40.75224,
#   'pickup_longitude': -73.97835,
#   'trip_distance': 0.79},
#  {'pickup_latitude': 40.758835,
#   'pickup_longitude': -73.988555,
#   'trip_distance': 1.36},
#  {'pickup_latitude': 40.722785,
#   'pickup_longitude': -73.988558,
#   'trip_distance': 2.04},
#  {'pickup_latitude': 40.720338,
#   'pickup_longitude': -73.993645,
#   'trip_distance': 0.9},
#  {'pickup_latitude': 40.72973,
#   'pickup_longitude': -73.991628,
#   'trip_distance': 1.65},
#  {'pickup_latitude': 40.760442,
#   'pickup_longitude': -73.958405,
#   'trip_distance': 0.64},
#  {'pickup_latitude': 40.756227,
#   'pickup_longitude': -73.98314,
#   'trip_distance': 1.34},
#  {'pickup_latitude': 40.751555,
#   'pickup_longitude': -73.992905,
#   'trip_distance': 1.13},
#  {'pickup_latitude': 40.71333,
#   'pickup_longitude': -74.004106,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.764762,
#   'pickup_longitude': -73.991849,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.763353,
#   'pickup_longitude': -73.985259,
#   'trip_distance': 1.9},
#  {'pickup_latitude': 40.775292,
#   'pickup_longitude': -73.982082,
#   'trip_distance': 0.66},
#  {'pickup_latitude': 40.779515,
#   'pickup_longitude': -73.984852,
#   'trip_distance': 0.9},
#  {'pickup_latitude': 40.768322,
#   'pickup_longitude': -73.982234,
#   'trip_distance': 3.8},
#  {'pickup_latitude': 40.766602,
#   'pickup_longitude': -73.95388,
#   'trip_distance': 6.52},
#  {'pickup_latitude': 40.763684,
#   'pickup_longitude': -73.981214,
#   'trip_distance': 2.1},
#  {'pickup_latitude': 40.793086,
#   'pickup_longitude': -73.952092,
#   'trip_distance': 0.7},
#  {'pickup_latitude': 40.773602,
#   'pickup_longitude': -73.871055,
#   'trip_distance': 3.4},
#  {'pickup_latitude': 40.771909,
#   'pickup_longitude': -73.959023,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.774029,
#   'pickup_longitude': -73.961478,
#   'trip_distance': 4.1},
#  {'pickup_latitude': 40.74964,
#   'pickup_longitude': -73.972212,
#   'trip_distance': 0.48},
#  {'pickup_latitude': 40.771542,
#   'pickup_longitude': -73.959533,
#   'trip_distance': 1.2},
#  {'pickup_latitude': 40.694095,
#   'pickup_longitude': -73.9839,
#   'trip_distance': 3.89},
#  {'pickup_latitude': 40.756312,
#   'pickup_longitude': -73.994315,
#   'trip_distance': 6.98},
#  {'pickup_latitude': 40.730282,
#   'pickup_longitude': -74.006652,
#   'trip_distance': 1.8},
#  {'pickup_latitude': 40.777707,
#   'pickup_longitude': -73.955068,
#   'trip_distance': 0.97},
#  {'pickup_latitude': 40.726087,
#   'pickup_longitude': -73.994962,
#   'trip_distance': 1.7},
#  {'pickup_latitude': 40.738385,
#   'pickup_longitude': -73.999885,
#   'trip_distance': 4.25},
#  {'pickup_latitude': 40.7678,
#   'pickup_longitude': -73.961987,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.742682,
#   'pickup_longitude': -73.972513,
#   'trip_distance': 0.12},
#  {'pickup_latitude': 40.770602,
#   'pickup_longitude': -73.982262,
#   'trip_distance': 1.02},
#  {'pickup_latitude': 40.747967,
#   'pickup_longitude': -73.976727,
#   'trip_distance': 2.39},
#  {'pickup_latitude': 40.742803,
#   'pickup_longitude': -74.004093,
#   'trip_distance': 1.6},
#  {'pickup_latitude': 40.755521,
#   'pickup_longitude': -73.97546,
#   'trip_distance': 1.7},
#  {'pickup_latitude': 40.760528,
#   'pickup_longitude': -74.002757,
#   'trip_distance': 1.5},
#  {'pickup_latitude': 40.740732,
#   'pickup_longitude': -74.005513,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.735497,
#   'pickup_longitude': -74.00601,
#   'trip_distance': 1.11},
#  {'pickup_latitude': 40.715387,
#   'pickup_longitude': -74.013518,
#   'trip_distance': 6.01},
#  {'pickup_latitude': 40.721587,
#   'pickup_longitude': -73.995427,
#   'trip_distance': 1.0},
#  {'pickup_latitude': 40.760057,
#   'pickup_longitude': -73.983502,
#   'trip_distance': 1.26},
#  {'pickup_latitude': 40.740332,
#   'pickup_longitude': -73.986289,
#   'trip_distance': 1.2},
#  {'pickup_latitude': 40.7455,
#   'pickup_longitude': -73.977834,
#   'trip_distance': 5.4},
#  {'pickup_latitude': 40.733125,
#   'pickup_longitude': -73.987273,
#   'trip_distance': 1.2},
#  {'pickup_latitude': 40.752092,
#   'pickup_longitude': -73.989949,
#   'trip_distance': 3.2},
#  {'pickup_latitude': 40.72381,
#   'pickup_longitude': -73.992617,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.767446,
#   'pickup_longitude': -73.984105,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.800479,
#   'pickup_longitude': -73.968083,
#   'trip_distance': 2.0},
#  {'pickup_latitude': 40.717055,
#   'pickup_longitude': -73.991325,
#   'trip_distance': 0.88},
#  {'pickup_latitude': 40.748863,
#   'pickup_longitude': -73.992155,
#   'trip_distance': 0.88},
#  {'pickup_latitude': 40.80474,
#   'pickup_longitude': -73.9478,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.762202,
#   'pickup_longitude': -73.969015,
#   'trip_distance': 1.23},
#  {'pickup_latitude': 0.0, 'pickup_longitude': 0.0, 'trip_distance': 5.19},
#  {'pickup_latitude': 40.740407,
#   'pickup_longitude': -73.987223,
#   'trip_distance': 0.9},
#  {'pickup_latitude': 40.722399,
#   'pickup_longitude': -73.997097,
#   'trip_distance': 5.6},
#  {'pickup_latitude': 40.747572,
#   'pickup_longitude': -73.974092,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.794651,
#   'pickup_longitude': -73.972048,
#   'trip_distance': 0.7},
#  {'pickup_latitude': 40.751087,
#   'pickup_longitude': -73.9716,
#   'trip_distance': 0.06},
#  {'pickup_latitude': 40.719886,
#   'pickup_longitude': -74.009981,
#   'trip_distance': 3.9},
#  {'pickup_latitude': 40.760887,
#   'pickup_longitude': -73.98696,
#   'trip_distance': 0.73},
#  {'pickup_latitude': 40.727514,
#   'pickup_longitude': -74.0073,
#   'trip_distance': 1.4},
#  {'pickup_latitude': 40.774453,
#   'pickup_longitude': -73.872166,
#   'trip_distance': 1.2},
#  {'pickup_latitude': 40.741907,
#   'pickup_longitude': -74.003545,
#   'trip_distance': 4.9},
#  {'pickup_latitude': 40.735118,
#   'pickup_longitude': -73.97979,
#   'trip_distance': 1.4},
#  {'pickup_latitude': 40.773907,
#   'pickup_longitude': -73.871275,
#   'trip_distance': 8.73},
#  {'pickup_latitude': 40.758937,
#   'pickup_longitude': -73.994232,
#   'trip_distance': 1.48},
#  {'pickup_latitude': 40.752144,
#   'pickup_longitude': -73.977199,
#   'trip_distance': 0.4},
#  {'pickup_latitude': 40.745642,
#   'pickup_longitude': -73.990757,
#   'trip_distance': 0.61},
#  {'pickup_latitude': 40.71879,
#   'pickup_longitude': -73.98984,
#   'trip_distance': 1.92},
#  {'pickup_latitude': 40.739945,
#   'pickup_longitude': -74.006124,
#   'trip_distance': 1.9},
#  {'pickup_latitude': 40.777575,
#   'pickup_longitude': -73.986287,
#   'trip_distance': 1.85},
#  {'pickup_latitude': 40.753632,
#   'pickup_longitude': -73.988899,
#   'trip_distance': 1.6},
#  {'pickup_latitude': 40.74733,
#   'pickup_longitude': -73.97703,
#   'trip_distance': 3.61},
#  {'pickup_latitude': 40.769822,
#   'pickup_longitude': -73.960596,
#   'trip_distance': 0.4},
#  {'pickup_latitude': 40.724658,
#   'pickup_longitude': -73.997131,
#   'trip_distance': 2.1},
#  {'pickup_latitude': 40.758345,
#   'pickup_longitude': -73.989398,
#   'trip_distance': 1.21},
#  {'pickup_latitude': 40.764807,
#   'pickup_longitude': -73.97669,
#   'trip_distance': 0.55},
#  {'pickup_latitude': 40.772847,
#   'pickup_longitude': -73.962703,
#   'trip_distance': 1.27},
#  {'pickup_latitude': 40.793682,
#   'pickup_longitude': -73.966972,
#   'trip_distance': 0.5},
#  {'pickup_latitude': 40.760007,
#   'pickup_longitude': -73.97804,
#   'trip_distance': 4.5},
#  {'pickup_latitude': 40.747252,
#   'pickup_longitude': -73.888215,
#   'trip_distance': 1.52},
#  {'pickup_latitude': 40.756392,
#   'pickup_longitude': -73.967522,
#   'trip_distance': 2.6},
#  {'pickup_latitude': 40.763685,
#   'pickup_longitude': -73.977714,
#   'trip_distance': 0.6},
#  {'pickup_latitude': 40.767068,
#   'pickup_longitude': -73.982805,
#   'trip_distance': 3.4},
#  {'pickup_latitude': 40.77596,
#   'pickup_longitude': -73.98728,
#   'trip_distance': 2.3},
#  {'pickup_latitude': 40.739617,
#   'pickup_longitude': -73.984663,
#   'trip_distance': 1.44},
#  {'pickup_latitude': 40.751953,
#   'pickup_longitude': -73.976404,
#   'trip_distance': 10.9},
#  {'pickup_latitude': 40.718635,
#   'pickup_longitude': -74.000952,
#   'trip_distance': 2.8},
#  {'pickup_latitude': 40.7331,
#   'pickup_longitude': -73.981375,
#   'trip_distance': 2.67},
#  {'pickup_latitude': 40.77463,
#   'pickup_longitude': -73.96322,
#   'trip_distance': 0.84},
#  {'pickup_latitude': 40.753675,
#   'pickup_longitude': -73.984942,
#   'trip_distance': 1.89},
#  {'pickup_latitude': 40.763262,
#   'pickup_longitude': -73.95948,
#   'trip_distance': 2.61},
#  {'pickup_latitude': 40.768895,
#   'pickup_longitude': -73.958237,
#   'trip_distance': 1.29},
#  {'pickup_latitude': 40.641375,
#   'pickup_longitude': -73.788935,
#   'trip_distance': 11.5},
#  {'pickup_latitude': 40.745472,
#   'pickup_longitude': -73.98666,
#   'trip_distance': 1.21},
#  {'pickup_latitude': 40.707562,
#   'pickup_longitude': -74.004372,
#   'trip_distance': 2.33},
#  {'pickup_latitude': 40.75331,
#   'pickup_longitude': -73.968992,
#   'trip_distance': 1.05},
#  {'pickup_latitude': 40.769545,
#   'pickup_longitude': -73.960554,
#   'trip_distance': 1.2},
#  {'pickup_latitude': 40.77411,
#   'pickup_longitude': -73.874625,
#   'trip_distance': 9.37},
#  {'pickup_latitude': 40.720615,
#   'pickup_longitude': -74.009875,
#   'trip_distance': 1.77},
#  {'pickup_latitude': 40.76305,
#   'pickup_longitude': -73.969831,
#   'trip_distance': 0.6},
#  {'pickup_latitude': 40.648605,
#   'pickup_longitude': -73.78482,
#   'trip_distance': 18.2},
#  {'pickup_latitude': 40.730875,
#   'pickup_longitude': -74.001527,
#   'trip_distance': 2.29},
#  {'pickup_latitude': 40.763843,
#   'pickup_longitude': -73.928025,
#   'trip_distance': 3.1},
#  {'pickup_latitude': 40.759867,
#   'pickup_longitude': -73.97835,
#   'trip_distance': 1.9},
#  {'pickup_latitude': 40.77302,
#   'pickup_longitude': -73.982,
#   'trip_distance': 0.94},
#  {'pickup_latitude': 40.767437,
#   'pickup_longitude': -73.980957,
#   'trip_distance': 2.7},
#  {'pickup_latitude': 40.7951,
#   'pickup_longitude': -73.97166,
#   'trip_distance': 0.2},
#  {'pickup_latitude': 40.78045,
#   'pickup_longitude': -73.980198,
#   'trip_distance': 2.1},
#  {'pickup_latitude': 40.777608,
#   'pickup_longitude': -73.956815,
#   'trip_distance': 1.4},
#  {'pickup_latitude': 40.783897,
#   'pickup_longitude': -73.952306,
#   'trip_distance': 2.5},
#  {'pickup_latitude': 40.738437,
#   'pickup_longitude': -73.999686,
#   'trip_distance': 0.3},
#  {'pickup_latitude': 40.766227,
#   'pickup_longitude': -73.980152,
#   'trip_distance': 2.61},
#  {'pickup_latitude': 40.7472,
#   'pickup_longitude': -74.007947,
#   'trip_distance': 3.2},
#  {'pickup_latitude': 40.729602,
#   'pickup_longitude': -73.987032,
#   'trip_distance': 1.63},
#  {'pickup_latitude': 40.747295,
#   'pickup_longitude': -74.000877,
#   'trip_distance': 1.86},
#  {'pickup_latitude': 40.764276,
#   'pickup_longitude': -73.954283,
#   'trip_distance': 2.3},
#  {'pickup_latitude': 40.717463,
#   'pickup_longitude': -74.005494,
#   'trip_distance': 2.0},
#  {'pickup_latitude': 40.756667,
#   'pickup_longitude': -73.967298,
#   'trip_distance': 3.06},
#  {'pickup_latitude': 40.723036,
#   'pickup_longitude': -73.988783,
#   'trip_distance': 3.4},
#  {'pickup_latitude': 40.742832,
#   'pickup_longitude': -73.989064,
#   'trip_distance': 1.4},
#  {'pickup_latitude': 40.759825,
#   'pickup_longitude': -73.970231,
#   'trip_distance': 2.3},
#  {'pickup_latitude': 40.770567,
#   'pickup_longitude': -73.954641,
#   'trip_distance': 3.8},
#  {'pickup_latitude': 40.743565,
#   'pickup_longitude': -73.988827,
#   'trip_distance': 0.73},
#  {'pickup_latitude': 40.761372,
#   'pickup_longitude': -73.982602,
#   'trip_distance': 0.58},
#  {'pickup_latitude': 40.725012,
#   'pickup_longitude': -73.995492,
#   'trip_distance': 0.06},
#  {'pickup_latitude': 40.751251,
#   'pickup_longitude': -73.975745,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.742522,
#   'pickup_longitude': -73.993292,
#   'trip_distance': 0.64},
#  {'pickup_latitude': 40.762107,
#   'pickup_longitude': -73.98479,
#   'trip_distance': 1.72},
#  {'pickup_latitude': 40.787171,
#   'pickup_longitude': -73.953967,
#   'trip_distance': 0.2},
#  {'pickup_latitude': 40.739887,
#   'pickup_longitude': -74.004942,
#   'trip_distance': 0.87},
#  {'pickup_latitude': 40.775297,
#   'pickup_longitude': -73.982005,
#   'trip_distance': 2.47},
#  {'pickup_latitude': 40.743232,
#   'pickup_longitude': -73.983751,
#   'trip_distance': 0.7},
#  {'pickup_latitude': 40.757386,
#   'pickup_longitude': -73.987253,
#   'trip_distance': 1.9},
#  {'pickup_latitude': 40.749027,
#   'pickup_longitude': -73.98395,
#   'trip_distance': 0.57},
#  {'pickup_latitude': 40.752385,
#   'pickup_longitude': -73.978314,
#   'trip_distance': 2.1},
#  {'pickup_latitude': 40.721988,
#   'pickup_longitude': -73.986383,
#   'trip_distance': 4.0},
#  {'pickup_latitude': 40.742422,
#   'pickup_longitude': -73.991082,
#   'trip_distance': 1.04},
#  {'pickup_latitude': 40.735396,
#   'pickup_longitude': -73.993911,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.749873,
#   'pickup_longitude': -73.991593,
#   'trip_distance': 3.3},
#  {'pickup_latitude': 40.779447,
#   'pickup_longitude': -73.962047,
#   'trip_distance': 1.35},
#  {'pickup_latitude': 40.730843,
#   'pickup_longitude': -74.00677,
#   'trip_distance': 5.0},
#  {'pickup_latitude': 40.750116,
#   'pickup_longitude': -73.987503,
#   'trip_distance': 2.0},
#  {'pickup_latitude': 40.701734,
#   'pickup_longitude': -74.011263,
#   'trip_distance': 5.2},
#  {'pickup_latitude': 40.72635,
#   'pickup_longitude': -73.977049,
#   'trip_distance': 2.2},
#  {'pickup_latitude': 40.688702,
#   'pickup_longitude': -73.98921,
#   'trip_distance': 5.5},
#  {'pickup_latitude': 40.771385,
#   'pickup_longitude': -73.96467,
#   'trip_distance': 1.49},
#  {'pickup_latitude': 40.715884,
#   'pickup_longitude': -73.959979,
#   'trip_distance': 0.6},
#  {'pickup_latitude': 40.790046,
#   'pickup_longitude': -73.975066,
#   'trip_distance': 1.4},
#  {'pickup_latitude': 40.76418,
#   'pickup_longitude': -73.97822,
#   'trip_distance': 1.44},
#  {'pickup_latitude': 40.76041,
#   'pickup_longitude': -73.987652,
#   'trip_distance': 5.3},
#  {'pickup_latitude': 40.745647,
#   'pickup_longitude': -73.978275,
#   'trip_distance': 0.43},
#  {'pickup_latitude': 40.793261,
#   'pickup_longitude': -73.940565,
#   'trip_distance': 0.5},
#  {'pickup_latitude': 40.762111,
#   'pickup_longitude': -73.968438,
#   'trip_distance': 0.9},
#  {'pickup_latitude': 40.74733,
#   'pickup_longitude': -73.9969,
#   'trip_distance': 1.65},
#  {'pickup_latitude': 40.74886,
#   'pickup_longitude': -73.988666,
#   'trip_distance': 0.5},
#  {'pickup_latitude': 40.730145,
#   'pickup_longitude': -73.986395,
#   'trip_distance': 2.0},
#  {'pickup_latitude': 40.75318,
#   'pickup_longitude': -73.973152,
#   'trip_distance': 6.6},
#  {'pickup_latitude': 40.829557,
#   'pickup_longitude': -73.837699,
#   'trip_distance': 1.9},
#  {'pickup_latitude': 40.743102,
#   'pickup_longitude': -73.973988,
#   'trip_distance': 2.3},
#  {'pickup_latitude': 40.750445,
#   'pickup_longitude': -73.98674,
#   'trip_distance': 0.6},
#  {'pickup_latitude': 40.743475,
#   'pickup_longitude': -73.923155,
#   'trip_distance': 8.26},
#  {'pickup_latitude': 40.762752,
#   'pickup_longitude': -73.993035,
#   'trip_distance': 1.03},
#  {'pickup_latitude': 40.765577,
#   'pickup_longitude': -73.979713,
#   'trip_distance': 3.02},
#  {'pickup_latitude': 40.750027,
#   'pickup_longitude': -73.89876,
#   'trip_distance': 0.98},
#  {'pickup_latitude': 40.751947,
#   'pickup_longitude': -73.986142,
#   'trip_distance': 1.13},
#  {'pickup_latitude': 40.71972,
#   'pickup_longitude': -74.008841,
#   'trip_distance': 1.4},
#  {'pickup_latitude': 40.78079,
#   'pickup_longitude': -73.946522,
#   'trip_distance': 0.7},
#  {'pickup_latitude': 40.751607,
#   'pickup_longitude': -73.993449,
#   'trip_distance': 0.4},
#  {'pickup_latitude': 40.745595,
#   'pickup_longitude': -73.988398,
#   'trip_distance': 1.36},
#  {'pickup_latitude': 40.72245,
#   'pickup_longitude': -73.98729,
#   'trip_distance': 7.46},
#  {'pickup_latitude': 40.702557,
#   'pickup_longitude': -73.93467,
#   'trip_distance': 3.03},
#  {'pickup_latitude': 40.734659,
#   'pickup_longitude': -73.98004,
#   'trip_distance': 2.1},
#  {'pickup_latitude': 40.764774,
#   'pickup_longitude': -73.992049,
#   'trip_distance': 0.5},
#  {'pickup_latitude': 40.723516,
#   'pickup_longitude': -73.985065,
#   'trip_distance': 0.4},
#  {'pickup_latitude': 40.781072,
#   'pickup_longitude': -73.983538,
#   'trip_distance': 1.88},
#  {'pickup_latitude': 40.793005,
#   'pickup_longitude': -73.973026,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.721025,
#   'pickup_longitude': -73.993857,
#   'trip_distance': 5.29},
#  {'pickup_latitude': 40.768497,
#   'pickup_longitude': -73.899785,
#   'trip_distance': 0.7},
#  {'pickup_latitude': 40.80726,
#   'pickup_longitude': -73.954179,
#   'trip_distance': 0.0},
#  {'pickup_latitude': 40.773715,
#   'pickup_longitude': -73.963908,
#   'trip_distance': 1.72},
#  {'pickup_latitude': 40.780082,
#   'pickup_longitude': -73.956843,
#   'trip_distance': 1.42},
#  {'pickup_latitude': 40.741824,
#   'pickup_longitude': -73.982933,
#   'trip_distance': 7.4},
#  {'pickup_latitude': 40.742112,
#   'pickup_longitude': -74.004672,
#   'trip_distance': 3.12},
#  {'pickup_latitude': 40.725925,
#   'pickup_longitude': -74.007585,
#   'trip_distance': 5.4},
#  {'pickup_latitude': 40.645718,
#   'pickup_longitude': -73.776765,
#   'trip_distance': 20.5},
#  {'pickup_latitude': 40.718398,
#   'pickup_longitude': -73.994967,
#   'trip_distance': 9.4},
#  {'pickup_latitude': 0.0, 'pickup_longitude': 0.0, 'trip_distance': 2.8},
#  {'pickup_latitude': 40.736343,
#   'pickup_longitude': -73.99289,
#   'trip_distance': 0.7},
#  {'pickup_latitude': 40.753827,
#   'pickup_longitude': -73.994472,
#   'trip_distance': 17.65},
#  {'pickup_latitude': 40.750693,
#   'pickup_longitude': -73.971834,
#   'trip_distance': 1.8},
#  {'pickup_latitude': 40.745964,
#   'pickup_longitude': -73.991152,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.740482,
#   'pickup_longitude': -74.004042,
#   'trip_distance': 1.93},
#  {'pickup_latitude': 0.0, 'pickup_longitude': 0.0, 'trip_distance': 0.3},
#  {'pickup_latitude': 40.803842,
#   'pickup_longitude': -73.966812,
#   'trip_distance': 8.74},
#  {'pickup_latitude': 40.797632,
#   'pickup_longitude': -73.969822,
#   'trip_distance': 0.73},
#  {'pickup_latitude': 40.645322,
#   'pickup_longitude': -73.776652,
#   'trip_distance': 19.05},
#  {'pickup_latitude': 40.749207,
#   'pickup_longitude': -74.003233,
#   'trip_distance': 0.75},
#  {'pickup_latitude': 40.765548,
#   'pickup_longitude': -73.983683,
#   'trip_distance': 2.1},
#  {'pickup_latitude': 40.760289,
#   'pickup_longitude': -73.931531,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.778967,
#   'pickup_longitude': -73.981767,
#   'trip_distance': 3.6},
#  {'pickup_latitude': 40.7582,
#   'pickup_longitude': -73.973285,
#   'trip_distance': 3.59},
#  {'pickup_latitude': 40.730709,
#   'pickup_longitude': -73.990504,
#   'trip_distance': 2.5},
#  {'pickup_latitude': 40.7456,
#   'pickup_longitude': -73.97814,
#   'trip_distance': 1.29},
#  {'pickup_latitude': 40.719471,
#   'pickup_longitude': -73.999779,
#   'trip_distance': 1.4},
#  {'pickup_latitude': 40.75619,
#   'pickup_longitude': -73.974282,
#   'trip_distance': 1.03},
#  {'pickup_latitude': 40.639542,
#   'pickup_longitude': -73.967915,
#   'trip_distance': 3.08},
#  {'pickup_latitude': 40.78366,
#   'pickup_longitude': -73.97427,
#   'trip_distance': 1.77},
#  {'pickup_latitude': 40.7464,
#   'pickup_longitude': -73.97771,
#   'trip_distance': 0.74},
#  {'pickup_latitude': 40.727475,
#   'pickup_longitude': -73.98533,
#   'trip_distance': 3.98},
#  {'pickup_latitude': 40.735015,
#   'pickup_longitude': -74.006024,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 0.0, 'pickup_longitude': 0.0, 'trip_distance': 1.1},
#  {'pickup_latitude': 0.0, 'pickup_longitude': 0.0, 'trip_distance': 1.33},
#  {'pickup_latitude': 40.754176,
#   'pickup_longitude': -74.04442,
#   'trip_distance': 1.8},
#  {'pickup_latitude': 40.740112,
#   'pickup_longitude': -73.994987,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.719972,
#   'pickup_longitude': -73.987553,
#   'trip_distance': 2.07},
#  {'pickup_latitude': 40.70517,
#   'pickup_longitude': -74.006987,
#   'trip_distance': 2.43},
#  {'pickup_latitude': 40.789142,
#   'pickup_longitude': -73.970472,
#   'trip_distance': 2.18},
#  {'pickup_latitude': 40.749115,
#   'pickup_longitude': -73.984182,
#   'trip_distance': 4.72},
#  {'pickup_latitude': 40.76443,
#   'pickup_longitude': -73.992037,
#   'trip_distance': 2.15},
#  {'pickup_latitude': 40.756477,
#   'pickup_longitude': -73.990472,
#   'trip_distance': 3.5},
#  {'pickup_latitude': 40.746142,
#   'pickup_longitude': -73.984852,
#   'trip_distance': 1.52},
#  {'pickup_latitude': 40.747856,
#   'pickup_longitude': -73.989088,
#   'trip_distance': 1.4},
#  {'pickup_latitude': 40.772615,
#   'pickup_longitude': -73.964789,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.761912,
#   'pickup_longitude': -73.975275,
#   'trip_distance': 0.6},
#  {'pickup_latitude': 40.740991,
#   'pickup_longitude': -74.005581,
#   'trip_distance': 1.0},
#  {'pickup_latitude': 40.764115,
#   'pickup_longitude': -73.97707,
#   'trip_distance': 3.84},
#  {'pickup_latitude': 40.728808,
#   'pickup_longitude': -73.987538,
#   'trip_distance': 16.4},
#  {'pickup_latitude': 40.725511,
#   'pickup_longitude': -73.991953,
#   'trip_distance': 4.2},
#  {'pickup_latitude': 40.768967,
#   'pickup_longitude': -73.954822,
#   'trip_distance': 1.09},
#  {'pickup_latitude': 40.75652,
#   'pickup_longitude': -73.973926,
#   'trip_distance': 2.7},
#  {'pickup_latitude': 40.751217,
#   'pickup_longitude': -73.970895,
#   'trip_distance': 0.88},
#  {'pickup_latitude': 40.779557,
#   'pickup_longitude': -73.977187,
#   'trip_distance': 1.09},
#  {'pickup_latitude': 40.771472,
#   'pickup_longitude': -73.8755,
#   'trip_distance': 12.06},
#  {'pickup_latitude': 40.73832,
#   'pickup_longitude': -73.9918,
#   'trip_distance': 0.45},
#  {'pickup_latitude': 40.643172,
#   'pickup_longitude': -73.789035,
#   'trip_distance': 19.03},
#  {'pickup_latitude': 40.769387,
#   'pickup_longitude': -73.953623,
#   'trip_distance': 0.45},
#  {'pickup_latitude': 40.731752,
#   'pickup_longitude': -74.000932,
#   'trip_distance': 1.28},
#  {'pickup_latitude': 40.745874,
#   'pickup_longitude': -73.991095,
#   'trip_distance': 16.1},
#  {'pickup_latitude': 40.767867,
#   'pickup_longitude': -73.963893,
#   'trip_distance': 0.2},
#  {'pickup_latitude': 40.766245,
#   'pickup_longitude': -73.98354,
#   'trip_distance': 1.04},
#  {'pickup_latitude': 40.753485,
#   'pickup_longitude': -73.97311,
#   'trip_distance': 0.76},
#  {'pickup_latitude': 40.726597,
#   'pickup_longitude': -73.986165,
#   'trip_distance': 1.26},
#  {'pickup_latitude': 40.7446,
#   'pickup_longitude': -73.985232,
#   'trip_distance': 0.59},
#  {'pickup_latitude': 40.756806,
#   'pickup_longitude': -73.969385,
#   'trip_distance': 2.8},
#  {'pickup_latitude': 40.783447,
#   'pickup_longitude': -73.947283,
#   'trip_distance': 1.42},
#  {'pickup_latitude': 40.758985,
#   'pickup_longitude': -73.989435,
#   'trip_distance': 6.13},
#  {'pickup_latitude': 40.645316,
#   'pickup_longitude': -73.776808,
#   'trip_distance': 17.5},
#  {'pickup_latitude': 40.762868,
#   'pickup_longitude': -73.983233,
#   'trip_distance': 8.3},
#  {'pickup_latitude': 40.761322,
#   'pickup_longitude': -73.975755,
#   'trip_distance': 0.65},
#  {'pickup_latitude': 40.771097,
#   'pickup_longitude': -73.865913,
#   'trip_distance': 9.61},
#  {'pickup_latitude': 40.760195,
#   'pickup_longitude': -73.967307,
#   'trip_distance': 2.3},
#  {'pickup_latitude': 40.73286,
#   'pickup_longitude': -74.00007,
#   'trip_distance': 4.92},
#  {'pickup_latitude': 40.75952,
#   'pickup_longitude': -73.985488,
#   'trip_distance': 2.4},
#  {'pickup_latitude': 40.821517,
#   'pickup_longitude': -73.954177,
#   'trip_distance': 0.6},
#  {'pickup_latitude': 40.734922,
#   'pickup_longitude': -73.990548,
#   'trip_distance': 1.2},
#  {'pickup_latitude': 40.757594,
#   'pickup_longitude': -73.989531,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.748042,
#   'pickup_longitude': -73.880385,
#   'trip_distance': 0.63},
#  {'pickup_latitude': 40.74957,
#   'pickup_longitude': -73.992772,
#   'trip_distance': 6.04},
#  {'pickup_latitude': 40.759663,
#   'pickup_longitude': -73.981141,
#   'trip_distance': 2.2},
#  {'pickup_latitude': 40.756397,
#   'pickup_longitude': -73.966882,
#   'trip_distance': 1.85},
#  {'pickup_latitude': 40.68078,
#   'pickup_longitude': -73.967735,
#   'trip_distance': 1.56},
#  {'pickup_latitude': 40.749994,
#   'pickup_longitude': -73.994031,
#   'trip_distance': 2.9},
#  {'pickup_latitude': 40.801351,
#   'pickup_longitude': -73.961519,
#   'trip_distance': 0.7},
#  {'pickup_latitude': 40.766223,
#   'pickup_longitude': -73.981952,
#   'trip_distance': 2.4},
#  {'pickup_latitude': 40.740045,
#   'pickup_longitude': -73.982178,
#   'trip_distance': 2.08},
#  {'pickup_latitude': 40.801657,
#   'pickup_longitude': -73.934415,
#   'trip_distance': 6.58},
#  {'pickup_latitude': 40.738722,
#   'pickup_longitude': -73.987027,
#   'trip_distance': 5.25},
#  {'pickup_latitude': 40.742172,
#   'pickup_longitude': -74.00809,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.775633,
#   'pickup_longitude': -73.98233,
#   'trip_distance': 2.8},
#  {'pickup_latitude': 40.792377,
#   'pickup_longitude': -73.96788,
#   'trip_distance': 1.29},
#  {'pickup_latitude': 40.659956,
#   'pickup_longitude': -73.99842,
#   'trip_distance': 3.2},
#  {'pickup_latitude': 40.7655,
#   'pickup_longitude': -73.97585,
#   'trip_distance': 0.78},
#  {'pickup_latitude': 40.737997,
#   'pickup_longitude': -73.992069,
#   'trip_distance': 7.4},
#  {'pickup_latitude': 40.711467,
#   'pickup_longitude': -73.945825,
#   'trip_distance': 8.8},
#  {'pickup_latitude': 0.0, 'pickup_longitude': 0.0, 'trip_distance': 0.1},
#  {'pickup_latitude': 40.710822,
#   'pickup_longitude': -74.015592,
#   'trip_distance': 3.63},
#  {'pickup_latitude': 40.763597,
#   'pickup_longitude': -73.97968,
#   'trip_distance': 1.51},
#  {'pickup_latitude': 40.744277,
#   'pickup_longitude': -73.973007,
#   'trip_distance': 1.5},
#  {'pickup_latitude': 40.774152,
#   'pickup_longitude': -73.873092,
#   'trip_distance': 6.54},
#  {'pickup_latitude': 40.773736,
#   'pickup_longitude': -73.959905,
#   'trip_distance': 0.2},
#  {'pickup_latitude': 40.740018,
#   'pickup_longitude': -74.005399,
#   'trip_distance': 4.5},
#  {'pickup_latitude': 40.750094,
#   'pickup_longitude': -73.979116,
#   'trip_distance': 1.0},
#  {'pickup_latitude': 40.741317,
#   'pickup_longitude': -73.983402,
#   'trip_distance': 2.06},
#  {'pickup_latitude': 40.75885,
#   'pickup_longitude': -73.965817,
#   'trip_distance': 1.9},
#  {'pickup_latitude': 40.687077,
#   'pickup_longitude': -73.990203,
#   'trip_distance': 2.6},
#  {'pickup_latitude': 40.76705,
#   'pickup_longitude': -73.979222,
#   'trip_distance': 0.72},
#  {'pickup_latitude': 40.72257,
#   'pickup_longitude': -73.997073,
#   'trip_distance': 1.0},
#  {'pickup_latitude': 40.77958,
#   'pickup_longitude': -73.957862,
#   'trip_distance': 0.25},
#  {'pickup_latitude': 40.7385,
#   'pickup_longitude': -73.9853,
#   'trip_distance': 1.34},
#  {'pickup_latitude': 40.770377,
#   'pickup_longitude': -73.982127,
#   'trip_distance': 2.1},
#  {'pickup_latitude': 40.75906,
#   'pickup_longitude': -73.983681,
#   'trip_distance': 3.3},
#  {'pickup_latitude': 40.689827,
#   'pickup_longitude': -73.99235,
#   'trip_distance': 2.24},
#  {'pickup_latitude': 40.766367,
#   'pickup_longitude': -73.952442,
#   'trip_distance': 17.55},
#  {'pickup_latitude': 40.717302,
#   'pickup_longitude': -73.99898,
#   'trip_distance': 3.08},
#  {'pickup_latitude': 40.642817,
#   'pickup_longitude': -73.788912,
#   'trip_distance': 24.55},
#  {'pickup_latitude': 40.766804,
#   'pickup_longitude': -73.969071,
#   'trip_distance': 5.1},
#  {'pickup_latitude': 40.762317,
#   'pickup_longitude': -73.98593,
#   'trip_distance': 1.18},
#  {'pickup_latitude': 40.734099,
#   'pickup_longitude': -73.999288,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.770737,
#   'pickup_longitude': -73.957142,
#   'trip_distance': 2.58},
#  {'pickup_latitude': 40.724919,
#   'pickup_longitude': -73.998967,
#   'trip_distance': 2.6},
#  {'pickup_latitude': 40.729687,
#   'pickup_longitude': -73.998358,
#   'trip_distance': 1.2},
#  {'pickup_latitude': 40.744083,
#   'pickup_longitude': -73.985687,
#   'trip_distance': 0.9},
#  {'pickup_latitude': 40.726413,
#   'pickup_longitude': -73.977196,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.794009,
#   'pickup_longitude': -73.966721,
#   'trip_distance': 0.6},
#  {'pickup_latitude': 40.74589,
#   'pickup_longitude': -73.994388,
#   'trip_distance': 1.4},
#  {'pickup_latitude': 40.75284,
#   'pickup_longitude': -73.989232,
#   'trip_distance': 0.35},
#  {'pickup_latitude': 40.777652,
#   'pickup_longitude': -73.959298,
#   'trip_distance': 1.14},
#  {'pickup_latitude': 40.726935,
#   'pickup_longitude': -73.991668,
#   'trip_distance': 2.06},
#  {'pickup_latitude': 40.74969,
#   'pickup_longitude': -73.97751,
#   'trip_distance': 1.01},
#  {'pickup_latitude': 40.709355,
#   'pickup_longitude': -74.016717,
#   'trip_distance': 5.14},
#  {'pickup_latitude': 40.750099,
#   'pickup_longitude': -73.99125,
#   'trip_distance': 3.0},
#  {'pickup_latitude': 40.777513,
#   'pickup_longitude': -73.948801,
#   'trip_distance': 0.5},
#  {'pickup_latitude': 40.64534,
#   'pickup_longitude': -73.77668,
#   'trip_distance': 21.44},
#  {'pickup_latitude': 40.794572,
#   'pickup_longitude': -73.97205,
#   'trip_distance': 0.76},
#  {'pickup_latitude': 40.76084,
#   'pickup_longitude': -73.971439,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.758902,
#   'pickup_longitude': -73.979668,
#   'trip_distance': 0.2},
#  {'pickup_latitude': 40.756082,
#   'pickup_longitude': -73.976395,
#   'trip_distance': 1.12},
#  {'pickup_latitude': 40.746631,
#   'pickup_longitude': -73.9819,
#   'trip_distance': 0.6},
#  {'pickup_latitude': 40.787612,
#   'pickup_longitude': -73.977033,
#   'trip_distance': 1.06},
#  {'pickup_latitude': 40.748875,
#   'pickup_longitude': -73.982345,
#   'trip_distance': 1.44},
#  {'pickup_latitude': 0.0, 'pickup_longitude': 0.0, 'trip_distance': 1.18},
#  {'pickup_latitude': 40.734924,
#   'pickup_longitude': -73.989973,
#   'trip_distance': 3.3},
#  {'pickup_latitude': 40.755682,
#   'pickup_longitude': -73.979288,
#   'trip_distance': 1.24},
#  {'pickup_latitude': 40.757465,
#   'pickup_longitude': -73.963752,
#   'trip_distance': 1.05},
#  {'pickup_latitude': 40.751163,
#   'pickup_longitude': -73.994115,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.754707,
#   'pickup_longitude': -73.986173,
#   'trip_distance': 5.64},
#  {'pickup_latitude': 40.768512,
#   'pickup_longitude': -73.965495,
#   'trip_distance': 1.14},
#  {'pickup_latitude': 40.770792,
#   'pickup_longitude': -73.961915,
#   'trip_distance': 0.37},
#  {'pickup_latitude': 40.780672,
#   'pickup_longitude': -73.952653,
#   'trip_distance': 1.21},
#  {'pickup_latitude': 40.733568,
#   'pickup_longitude': -73.995547,
#   'trip_distance': 2.3},
#  {'pickup_latitude': 40.74998,
#   'pickup_longitude': -73.99179,
#   'trip_distance': 1.42},
#  {'pickup_latitude': 40.72235,
#   'pickup_longitude': -73.986202,
#   'trip_distance': 3.2},
#  {'pickup_latitude': 40.77081,
#   'pickup_longitude': -73.956903,
#   'trip_distance': 2.9},
#  {'pickup_latitude': 40.771152,
#   'pickup_longitude': -73.95672,
#   'trip_distance': 4.33},
#  {'pickup_latitude': 40.790777,
#   'pickup_longitude': -73.973482,
#   'trip_distance': 19.6},
#  {'pickup_latitude': 40.716232,
#   'pickup_longitude': -74.013591,
#   'trip_distance': 4.0},
#  {'pickup_latitude': 40.74277,
#   'pickup_longitude': -73.984523,
#   'trip_distance': 0.4},
#  {'pickup_latitude': 40.726791,
#   'pickup_longitude': -73.999842,
#   'trip_distance': 1.4},
#  {'pickup_latitude': 40.774935,
#   'pickup_longitude': -73.963839,
#   'trip_distance': 0.4},
#  {'pickup_latitude': 40.752832,
#   'pickup_longitude': -73.979423,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.732783,
#   'pickup_longitude': -73.985831,
#   'trip_distance': 0.7},
#  {'pickup_latitude': 40.75176,
#   'pickup_longitude': -73.986138,
#   'trip_distance': 1.76},
#  {'pickup_latitude': 40.772827,
#   'pickup_longitude': -73.981567,
#   'trip_distance': 2.03},
#  {'pickup_latitude': 40.786305,
#   'pickup_longitude': -73.977741,
#   'trip_distance': 6.2},
#  {'pickup_latitude': 40.71986,
#   'pickup_longitude': -74.01021,
#   'trip_distance': 5.53},
#  {'pickup_latitude': 40.748193,
#   'pickup_longitude': -73.984715,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.734642,
#   'pickup_longitude': -73.992515,
#   'trip_distance': 4.7},
#  {'pickup_latitude': 40.758495,
#   'pickup_longitude': -73.98159,
#   'trip_distance': 2.79},
#  {'pickup_latitude': 40.750711,
#   'pickup_longitude': -73.991913,
#   'trip_distance': 2.5},
#  {'pickup_latitude': 40.751085,
#   'pickup_longitude': -73.990382,
#   'trip_distance': 1.05},
#  {'pickup_latitude': 40.696647,
#   'pickup_longitude': -73.99152,
#   'trip_distance': 8.44},
#  {'pickup_latitude': 40.766092,
#   'pickup_longitude': -73.982632,
#   'trip_distance': 1.25},
#  {'pickup_latitude': 40.77293,
#   'pickup_longitude': -73.88525,
#   'trip_distance': 9.41},
#  {'pickup_latitude': 40.644032,
#   'pickup_longitude': -73.790294,
#   'trip_distance': 23.7},
#  {'pickup_latitude': 40.758261,
#   'pickup_longitude': -73.970859,
#   'trip_distance': 2.1},
#  {'pickup_latitude': 40.778392,
#   'pickup_longitude': -73.985658,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.758372,
#   'pickup_longitude': -73.963047,
#   'trip_distance': 0.72},
#  {'pickup_latitude': 40.752788,
#   'pickup_longitude': -73.975128,
#   'trip_distance': 6.2},
#  {'pickup_latitude': 40.741972,
#   'pickup_longitude': -74.007642,
#   'trip_distance': 3.05},
#  {'pickup_latitude': 40.764972,
#   'pickup_longitude': -73.977855,
#   'trip_distance': 0.4},
#  {'pickup_latitude': 40.742227,
#   'pickup_longitude': -73.982747,
#   'trip_distance': 0.72},
#  {'pickup_latitude': 40.743594,
#   'pickup_longitude': -73.979374,
#   'trip_distance': 3.2},
#  {'pickup_latitude': 40.774852,
#   'pickup_longitude': -73.961215,
#   'trip_distance': 4.83},
#  {'pickup_latitude': 40.786657,
#   'pickup_longitude': -73.975743,
#   'trip_distance': 13.75},
#  {'pickup_latitude': 40.731236,
#   'pickup_longitude': -74.001455,
#   'trip_distance': 1.7},
#  {'pickup_latitude': 40.724197,
#   'pickup_longitude': -73.978797,
#   'trip_distance': 4.8},
#  {'pickup_latitude': 40.735687,
#   'pickup_longitude': -74.005065,
#   'trip_distance': 1.51},
#  {'pickup_latitude': 40.724007,
#   'pickup_longitude': -73.978812,
#   'trip_distance': 3.2},
#  {'pickup_latitude': 40.751962,
#   'pickup_longitude': -73.993918,
#   'trip_distance': 1.7},
#  {'pickup_latitude': 40.744422,
#   'pickup_longitude': -73.976127,
#   'trip_distance': 2.03},
#  {'pickup_latitude': 40.76944,
#   'pickup_longitude': -73.952025,
#   'trip_distance': 2.11},
#  {'pickup_latitude': 40.755972,
#   'pickup_longitude': -73.972347,
#   'trip_distance': 2.54},
#  {'pickup_latitude': 40.782482,
#   'pickup_longitude': -73.957812,
#   'trip_distance': 8.47},
#  {'pickup_latitude': 40.739142,
#   'pickup_longitude': -74.00807,
#   'trip_distance': 1.98},
#  {'pickup_latitude': 40.752412,
#   'pickup_longitude': -73.977267,
#   'trip_distance': 1.31},
#  {'pickup_latitude': 0.0, 'pickup_longitude': 0.0, 'trip_distance': 3.2},
#  {'pickup_latitude': 40.771168,
#   'pickup_longitude': -73.963929,
#   'trip_distance': 1.5},
#  {'pickup_latitude': 40.756005,
#   'pickup_longitude': -73.973294,
#   'trip_distance': 6.7},
#  {'pickup_latitude': 40.778415,
#   'pickup_longitude': -73.945392,
#   'trip_distance': 1.0},
#  {'pickup_latitude': 40.766653,
#   'pickup_longitude': -73.957138,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.746032,
#   'pickup_longitude': -73.97976,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.763352,
#   'pickup_longitude': -73.996385,
#   'trip_distance': 2.1},
#  {'pickup_latitude': 40.755782,
#   'pickup_longitude': -73.983322,
#   'trip_distance': 6.89},
#  {'pickup_latitude': 40.769837,
#   'pickup_longitude': -73.982025,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.773009,
#   'pickup_longitude': -73.885269,
#   'trip_distance': 8.2},
#  {'pickup_latitude': 40.799458,
#   'pickup_longitude': -73.968139,
#   'trip_distance': 4.2},
#  {'pickup_latitude': 40.777555,
#   'pickup_longitude': -73.961237,
#   'trip_distance': 1.18},
#  {'pickup_latitude': 40.80409,
#   'pickup_longitude': -73.966942,
#   'trip_distance': 0.68},
#  {'pickup_latitude': 40.713948,
#   'pickup_longitude': -73.951672,
#   'trip_distance': 2.8},
#  {'pickup_latitude': 40.741453,
#   'pickup_longitude': -74.006441,
#   'trip_distance': 1.6},
#  {'pickup_latitude': 40.79858,
#   'pickup_longitude': -73.969018,
#   'trip_distance': 0.3},
#  {'pickup_latitude': 40.721519,
#   'pickup_longitude': -73.956165,
#   'trip_distance': 7.1},
#  {'pickup_latitude': 40.744341,
#   'pickup_longitude': -74.006568,
#   'trip_distance': 2.1},
#  {'pickup_latitude': 40.750106,
#   'pickup_longitude': -73.991395,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.815817,
#   'pickup_longitude': -73.958397,
#   'trip_distance': 4.59},
#  {'pickup_latitude': 40.772255,
#   'pickup_longitude': -73.982507,
#   'trip_distance': 2.5},
#  {'pickup_latitude': 40.756412,
#   'pickup_longitude': -73.967363,
#   'trip_distance': 1.0},
#  {'pickup_latitude': 40.729556,
#   'pickup_longitude': -73.99331,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.774627,
#   'pickup_longitude': -73.957909,
#   'trip_distance': 2.2},
#  {'pickup_latitude': 40.744418,
#   'pickup_longitude': -73.983521,
#   'trip_distance': 6.8},
#  {'pickup_latitude': 40.795953,
#   'pickup_longitude': -73.970739,
#   'trip_distance': 6.4},
#  {'pickup_latitude': 40.735785,
#   'pickup_longitude': -74.006038,
#   'trip_distance': 8.3},
#  {'pickup_latitude': 40.741275,
#   'pickup_longitude': -73.981362,
#   'trip_distance': 1.51},
#  {'pickup_latitude': 40.759037,
#   'pickup_longitude': -73.968693,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.7642,
#   'pickup_longitude': -73.954807,
#   'trip_distance': 3.8},
#  {'pickup_latitude': 40.779383,
#   'pickup_longitude': -73.95955,
#   'trip_distance': 1.0},
#  {'pickup_latitude': 40.72638,
#   'pickup_longitude': -74.002,
#   'trip_distance': 3.42},
#  {'pickup_latitude': 40.716736,
#   'pickup_longitude': -73.997696,
#   'trip_distance': 1.8},
#  {'pickup_latitude': 40.751872,
#   'pickup_longitude': -73.987503,
#   'trip_distance': 10.74},
#  {'pickup_latitude': 40.774462,
#   'pickup_longitude': -73.988552,
#   'trip_distance': 1.36},
#  {'pickup_latitude': 40.748208,
#   'pickup_longitude': -74.005309,
#   'trip_distance': 4.3},
#  {'pickup_latitude': 40.756054,
#   'pickup_longitude': -74.005378,
#   'trip_distance': 0.9},
#  {'pickup_latitude': 40.759193,
#   'pickup_longitude': -73.97723,
#   'trip_distance': 1.0},
#  {'pickup_latitude': 40.7439,
#   'pickup_longitude': -73.999577,
#   'trip_distance': 0.95},
#  {'pickup_latitude': 40.712612,
#   'pickup_longitude': -73.95882,
#   'trip_distance': 7.04},
#  {'pickup_latitude': 40.751285,
#   'pickup_longitude': -73.9712,
#   'trip_distance': 1.71},
#  {'pickup_latitude': 40.75262,
#   'pickup_longitude': -73.98631,
#   'trip_distance': 0.79},
#  {'pickup_latitude': 40.728885,
#   'pickup_longitude': -74.000534,
#   'trip_distance': 2.1},
#  {'pickup_latitude': 40.753302,
#   'pickup_longitude': -73.979382,
#   'trip_distance': 0.5},
#  {'pickup_latitude': 40.759795,
#   'pickup_longitude': -73.968202,
#   'trip_distance': 0.7},
#  {'pickup_latitude': 40.727368,
#   'pickup_longitude': -74.0062,
#   'trip_distance': 5.1},
#  {'pickup_latitude': 40.7595,
#   'pickup_longitude': -73.96904,
#   'trip_distance': 0.62},
#  {'pickup_latitude': 40.751837,
#   'pickup_longitude': -73.970865,
#   'trip_distance': 2.5},
#  {'pickup_latitude': 40.742032,
#   'pickup_longitude': -73.97492,
#   'trip_distance': 1.71},
#  {'pickup_latitude': 40.755123,
#   'pickup_longitude': -73.97283,
#   'trip_distance': 0.2},
#  {'pickup_latitude': 40.726783,
#   'pickup_longitude': -73.980283,
#   'trip_distance': 1.8},
#  {'pickup_latitude': 40.768924,
#   'pickup_longitude': -73.952227,
#   'trip_distance': 2.2},
#  {'pickup_latitude': 40.748232,
#   'pickup_longitude': -73.988848,
#   'trip_distance': 1.2},
#  {'pickup_latitude': 40.70205,
#   'pickup_longitude': -74.011423,
#   'trip_distance': 3.93},
#  {'pickup_latitude': 40.763197,
#   'pickup_longitude': -73.989376,
#   'trip_distance': 0.5},
#  {'pickup_latitude': 40.720794,
#   'pickup_longitude': -74.008509,
#   'trip_distance': 4.3},
#  {'pickup_latitude': 40.760644,
#   'pickup_longitude': -73.984531,
#   'trip_distance': 0.0},
#  {'pickup_latitude': 40.743367,
#   'pickup_longitude': -73.98406,
#   'trip_distance': 1.2},
#  {'pickup_latitude': 40.749792,
#   'pickup_longitude': -74.00267,
#   'trip_distance': 8.7},
#  {'pickup_latitude': 40.754807,
#   'pickup_longitude': -73.97379,
#   'trip_distance': 2.63},
#  {'pickup_latitude': 40.64483,
#   'pickup_longitude': -73.781578,
#   'trip_distance': 7.78},
#  {'pickup_latitude': 40.767759,
#   'pickup_longitude': -73.989694,
#   'trip_distance': 0.4},
#  {'pickup_latitude': 40.762243,
#   'pickup_longitude': -73.96815,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.730735,
#   'pickup_longitude': -73.992072,
#   'trip_distance': 4.62},
#  {'pickup_latitude': 40.738672,
#   'pickup_longitude': -73.999515,
#   'trip_distance': 1.21},
#  {'pickup_latitude': 40.774752,
#   'pickup_longitude': -73.980465,
#   'trip_distance': 1.53},
#  {'pickup_latitude': 40.777867,
#   'pickup_longitude': -73.945725,
#   'trip_distance': 7.1},
#  {'pickup_latitude': 40.742502,
#   'pickup_longitude': -74.00424,
#   'trip_distance': 2.6},
#  {'pickup_latitude': 40.76532,
#   'pickup_longitude': -73.97557,
#   'trip_distance': 2.96},
#  {'pickup_latitude': 40.722856,
#   'pickup_longitude': -73.979826,
#   'trip_distance': 3.2},
#  {'pickup_latitude': 40.777252,
#   'pickup_longitude': -73.982625,
#   'trip_distance': 2.28},
#  {'pickup_latitude': 40.740912,
#   'pickup_longitude': -73.985925,
#   'trip_distance': 3.59},
#  {'pickup_latitude': 40.798562,
#   'pickup_longitude': -73.969052,
#   'trip_distance': 5.17},
#  {'pickup_latitude': 40.71422,
#   'pickup_longitude': -74.013452,
#   'trip_distance': 3.7},
#  {'pickup_latitude': 40.748567,
# ...
#   'trip_distance': 2.11},
#  {'pickup_latitude': 40.75781,
#   'pickup_longitude': -73.975233,
#   'trip_distance': 2.1},
#  {'pickup_latitude': 40.745593,
#   'pickup_longitude': -73.986817,
#   'trip_distance': 1.9},
#  {'pickup_latitude': 40.783545,
#   'pickup_longitude': -73.954963,
#   'trip_distance': 1.26},
#  {'pickup_latitude': 40.757605,
#   'pickup_longitude': -73.97543,
#   'trip_distance': 0.77},
#  {'pickup_latitude': 40.75899,
#   'pickup_longitude': -73.973248,
#   'trip_distance': 1.02},
#  {'pickup_latitude': 40.713662,
#   'pickup_longitude': -74.008577,
#   'trip_distance': 2.3},
#  {'pickup_latitude': 40.776252,
#   'pickup_longitude': -73.958072,
#   'trip_distance': 0.74},
#  {'pickup_latitude': 40.764,
#   'pickup_longitude': -73.97666,
#   'trip_distance': 2.56},
#  {'pickup_latitude': 40.74787,
#   'pickup_longitude': -74.003975,
#   'trip_distance': 1.27},
#  {'pickup_latitude': 40.748717,
#   'pickup_longitude': -73.992417,
#   'trip_distance': 2.18},
#  {'pickup_latitude': 40.771905,
#   'pickup_longitude': -73.965624,
#   'trip_distance': 2.7},
#  {'pickup_latitude': 40.783138,
#   'pickup_longitude': -73.947885,
#   'trip_distance': 3.01},
#  {'pickup_latitude': 40.75708,
#   'pickup_longitude': -73.96923,
#   'trip_distance': 0.72},
#  {'pickup_latitude': 40.848462,
#   'pickup_longitude': -73.937645,
#   'trip_distance': 1.0},
#  {'pickup_latitude': 40.744697,
#   'pickup_longitude': -73.98626,
#   'trip_distance': 0.49},
#  {'pickup_latitude': 40.768147,
#   'pickup_longitude': -73.968142,
#   'trip_distance': 6.52},
#  {'pickup_latitude': 40.741328,
#   'pickup_longitude': -73.989642,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.77847,
#   'pickup_longitude': -73.98185,
#   'trip_distance': 2.07},
#  {'pickup_latitude': 40.782873,
#   'pickup_longitude': -73.948122,
#   'trip_distance': 4.8},
#  {'pickup_latitude': 40.78711,
#   'pickup_longitude': -73.954356,
#   'trip_distance': 2.6},
#  {'pickup_latitude': 40.762862,
#   'pickup_longitude': -73.985855,
#   'trip_distance': 1.93},
#  {'pickup_latitude': 40.78579,
#   'pickup_longitude': -73.976302,
#   'trip_distance': 5.79},
#  {'pickup_latitude': 40.782512,
#   'pickup_longitude': -73.95305,
#   'trip_distance': 2.62},
#  {'pickup_latitude': 40.771552,
#   'pickup_longitude': -73.953405,
#   'trip_distance': 4.9},
#  {'pickup_latitude': 40.759172,
#   'pickup_longitude': -73.968517,
#   'trip_distance': 5.37},
#  {'pickup_latitude': 40.740622,
#   'pickup_longitude': -74.007735,
#   'trip_distance': 2.46},
#  {'pickup_latitude': 40.750938,
#   'pickup_longitude': -73.974878,
#   'trip_distance': 1.5},
#  {'pickup_latitude': 40.77435,
#   'pickup_longitude': -73.963497,
#   'trip_distance': 1.8},
#  {'pickup_latitude': 40.77831,
#   'pickup_longitude': -73.9454,
#   'trip_distance': 1.33},
#  {'pickup_latitude': 40.760477,
#   'pickup_longitude': -73.998625,
#   'trip_distance': 2.48},
#  {'pickup_latitude': 40.77338,
#   'pickup_longitude': -73.954888,
#   'trip_distance': 0.53},
#  {'pickup_latitude': 40.760643,
#   'pickup_longitude': -73.962616,
#   'trip_distance': 0.5},
#  {'pickup_latitude': 40.68703,
#   'pickup_longitude': -73.98489,
#   'trip_distance': 6.07},
#  {'pickup_latitude': 40.77164,
#   'pickup_longitude': -73.98298,
#   'trip_distance': 2.27},
#  {'pickup_latitude': 40.764902,
#   'pickup_longitude': -73.97692,
#   'trip_distance': 1.67},
#  {'pickup_latitude': 40.767331,
#   'pickup_longitude': -73.962998,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.77919,
#   'pickup_longitude': -73.954987,
#   'trip_distance': 0.5},
#  {'pickup_latitude': 40.763407,
#   'pickup_longitude': -73.974485,
#   'trip_distance': 4.52},
#  {'pickup_latitude': 40.751124,
#   'pickup_longitude': -73.975967,
#   'trip_distance': 3.9},
#  {'pickup_latitude': 40.73599,
#   'pickup_longitude': -74.000955,
#   'trip_distance': 1.5},
#  {'pickup_latitude': 40.761058,
#   'pickup_longitude': -73.985524,
#   'trip_distance': 2.2},
#  {'pickup_latitude': 40.745909,
#   'pickup_longitude': -73.998101,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.744849,
#   'pickup_longitude': -73.991395,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.750342,
#   'pickup_longitude': -73.994657,
#   'trip_distance': 4.28},
#  {'pickup_latitude': 40.763665,
#   'pickup_longitude': -73.986105,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.765862,
#   'pickup_longitude': -73.9606,
#   'trip_distance': 2.65},
#  {'pickup_latitude': 40.75729,
#   'pickup_longitude': -73.98991,
#   'trip_distance': 1.56},
#  {'pickup_latitude': 40.763148,
#   'pickup_longitude': -73.979234,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.70626,
#   'pickup_longitude': -74.004265,
#   'trip_distance': 1.62},
#  {'pickup_latitude': 40.782011,
#   'pickup_longitude': -73.956252,
#   'trip_distance': 3.6},
#  {'pickup_latitude': 40.671487,
#   'pickup_longitude': -73.984354,
#   'trip_distance': 0.6},
#  {'pickup_latitude': 40.753034,
#   'pickup_longitude': -73.989329,
#   'trip_distance': 1.2},
#  {'pickup_latitude': 40.744997,
#   'pickup_longitude': -73.981732,
#   'trip_distance': 0.81},
#  {'pickup_latitude': 40.721882,
#   'pickup_longitude': -73.989213,
#   'trip_distance': 4.11},
#  {'pickup_latitude': 40.752342,
#   'pickup_longitude': -73.974746,
#   'trip_distance': 7.6},
#  {'pickup_latitude': 40.709415,
#   'pickup_longitude': -74.008147,
#   'trip_distance': 3.3},
#  {'pickup_latitude': 40.755637,
#   'pickup_longitude': -73.96482,
#   'trip_distance': 0.58},
#  {'pickup_latitude': 40.780847,
#   'pickup_longitude': -73.981522,
#   'trip_distance': 1.0},
#  {'pickup_latitude': 40.73668,
#   'pickup_longitude': -73.995368,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.707517,
#   'pickup_longitude': -74.004445,
#   'trip_distance': 7.8},
#  {'pickup_latitude': 40.73706,
#   'pickup_longitude': -73.99012,
#   'trip_distance': 1.09},
#  {'pickup_latitude': 40.769119,
#   'pickup_longitude': -73.987085,
#   'trip_distance': 4.1},
#  {'pickup_latitude': 40.750492,
#   'pickup_longitude': -73.99465,
#   'trip_distance': 2.64},
#  {'pickup_latitude': 40.779416,
#   'pickup_longitude': -73.957448,
#   'trip_distance': 11.3},
#  {'pickup_latitude': 40.779454,
#   'pickup_longitude': -73.961831,
#   'trip_distance': 1.7},
#  {'pickup_latitude': 40.773952,
#   'pickup_longitude': -73.871235,
#   'trip_distance': 8.12},
#  {'pickup_latitude': 40.756805,
#   'pickup_longitude': -73.990317,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.766251,
#   'pickup_longitude': -73.98011,
#   'trip_distance': 0.2},
#  {'pickup_latitude': 40.747098,
#   'pickup_longitude': -73.98622,
#   'trip_distance': 4.6},
#  {'pickup_latitude': 40.774347,
#   'pickup_longitude': -73.963485,
#   'trip_distance': 0.9},
#  {'pickup_latitude': 40.73735,
#   'pickup_longitude': -73.988662,
#   'trip_distance': 3.05},
#  {'pickup_latitude': 40.755507,
#   'pickup_longitude': -73.976157,
#   'trip_distance': 1.03},
#  {'pickup_latitude': 0.0, 'pickup_longitude': 0.0, 'trip_distance': 1.09},
#  {'pickup_latitude': 40.77734,
#   'pickup_longitude': -73.978578,
#   'trip_distance': 2.2},
#  {'pickup_latitude': 40.730313,
#   'pickup_longitude': -74.00019,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.770965,
#   'pickup_longitude': -73.964002,
#   'trip_distance': 0.78},
#  {'pickup_latitude': 40.747897,
#   'pickup_longitude': -74.003746,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.743013,
#   'pickup_longitude': -73.992796,
#   'trip_distance': 3.5},
#  {'pickup_latitude': 40.757036,
#   'pickup_longitude': -73.976146,
#   'trip_distance': 2.5},
#  {'pickup_latitude': 40.75083,
#   'pickup_longitude': -73.990808,
#   'trip_distance': 1.27},
#  {'pickup_latitude': 40.747865,
#   'pickup_longitude': -73.99322,
#   'trip_distance': 0.63},
#  {'pickup_latitude': 40.758215,
#   'pickup_longitude': -73.937667,
#   'trip_distance': 1.66},
#  {'pickup_latitude': 40.750687,
#   'pickup_longitude': -73.943522,
#   'trip_distance': 2.38},
#  {'pickup_latitude': 40.734432,
#   'pickup_longitude': -73.99974,
#   'trip_distance': 1.82},
#  {'pickup_latitude': 40.766799,
#   'pickup_longitude': -73.983307,
#   'trip_distance': 2.1},
#  {'pickup_latitude': 40.752133,
#   'pickup_longitude': -74.004754,
#   'trip_distance': 1.9},
#  {'pickup_latitude': 40.719627,
#   'pickup_longitude': -74.00689,
#   'trip_distance': 1.4},
#  {'pickup_latitude': 40.77012,
#   'pickup_longitude': -73.86361,
#   'trip_distance': 12.55},
#  {'pickup_latitude': 40.753714,
#   'pickup_longitude': -73.992042,
#   'trip_distance': 0.3},
#  {'pickup_latitude': 40.779378,
#   'pickup_longitude': -73.97747,
#   'trip_distance': 1.0},
#  {'pickup_latitude': 40.764967,
#   'pickup_longitude': -73.989047,
#   'trip_distance': 1.5},
#  {'pickup_latitude': 40.724772,
#   'pickup_longitude': -73.990509,
#   'trip_distance': 3.9},
#  {'pickup_latitude': 40.734817,
#   'pickup_longitude': -73.990455,
#   'trip_distance': 2.18},
#  {'pickup_latitude': 40.751752,
#   'pickup_longitude': -73.990012,
#   'trip_distance': 0.3},
#  {'pickup_latitude': 40.756564,
#   'pickup_longitude': -73.994046,
#   'trip_distance': 1.2},
#  {'pickup_latitude': 40.742736,
#   'pickup_longitude': -74.000354,
#   'trip_distance': 1.5},
#  {'pickup_latitude': 0.0, 'pickup_longitude': 0.0, 'trip_distance': 9.7},
#  {'pickup_latitude': 40.741672,
#   'pickup_longitude': -74.004627,
#   'trip_distance': 1.28},
#  {'pickup_latitude': 40.72597,
#   'pickup_longitude': -73.99738,
#   'trip_distance': 1.4},
#  {'pickup_latitude': 40.743772,
#   'pickup_longitude': -73.992388,
#   'trip_distance': 1.2},
#  {'pickup_latitude': 40.71032,
#   'pickup_longitude': -74.009677,
#   'trip_distance': 0.9},
#  {'pickup_latitude': 40.710885,
#   'pickup_longitude': -74.010269,
#   'trip_distance': 3.2},
#  {'pickup_latitude': 40.768567,
#   'pickup_longitude': -73.969685,
#   'trip_distance': 1.46},
#  {'pickup_latitude': 40.755322,
#   'pickup_longitude': -73.987748,
#   'trip_distance': 4.19},
#  {'pickup_latitude': 40.750872,
#   'pickup_longitude': -73.993015,
#   'trip_distance': 2.3},
#  {'pickup_latitude': 40.691887,
#   'pickup_longitude': -73.982322,
#   'trip_distance': 5.8},
#  {'pickup_latitude': 40.753002,
#   'pickup_longitude': -73.996735,
#   'trip_distance': 1.33},
#  {'pickup_latitude': 40.765657,
#   'pickup_longitude': -73.970445,
#   'trip_distance': 0.34},
#  {'pickup_latitude': 40.718429,
#   'pickup_longitude': -73.987265,
#   'trip_distance': 2.3},
#  {'pickup_latitude': 40.75261,
#   'pickup_longitude': -73.978503,
#   'trip_distance': 0.55},
#  {'pickup_latitude': 40.774841,
#   'pickup_longitude': -73.963199,
#   'trip_distance': 0.4},
#  {'pickup_latitude': 40.820267,
#   'pickup_longitude': -73.955068,
#   'trip_distance': 0.9},
#  {'pickup_latitude': 40.749905,
#   'pickup_longitude': -73.995245,
#   'trip_distance': 1.98},
#  {'pickup_latitude': 40.790222,
#   'pickup_longitude': -73.976825,
#   'trip_distance': 1.55},
#  {'pickup_latitude': 40.751243,
#   'pickup_longitude': -73.993928,
#   'trip_distance': 0.7},
#  {'pickup_latitude': 40.769372,
#   'pickup_longitude': -73.984837,
#   'trip_distance': 0.5},
#  {'pickup_latitude': 40.802452,
#   'pickup_longitude': -73.9623,
#   'trip_distance': 2.9},
#  {'pickup_latitude': 40.740012,
#   'pickup_longitude': -73.99121,
#   'trip_distance': 1.13},
#  {'pickup_latitude': 40.724477,
#   'pickup_longitude': -73.98706,
#   'trip_distance': 1.79},
#  {'pickup_latitude': 40.649679,
#   'pickup_longitude': -73.804526,
#   'trip_distance': 1.4},
#  {'pickup_latitude': 40.763434,
#   'pickup_longitude': -73.965213,
#   'trip_distance': 1.0},
#  {'pickup_latitude': 40.813836,
#   'pickup_longitude': -73.936919,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.748613,
#   'pickup_longitude': -73.983003,
#   'trip_distance': 4.4},
#  {'pickup_latitude': 40.756067,
#   'pickup_longitude': -73.990297,
#   'trip_distance': 1.51},
#  {'pickup_latitude': 40.751127,
#   'pickup_longitude': -73.993905,
#   'trip_distance': 0.96},
#  {'pickup_latitude': 40.757541,
#   'pickup_longitude': -73.974641,
#   'trip_distance': 10.9},
#  {'pickup_latitude': 40.783417,
#   'pickup_longitude': -73.951313,
#   'trip_distance': 1.0},
#  {'pickup_latitude': 40.755617,
#   'pickup_longitude': -73.962448,
#   'trip_distance': 0.9},
#  {'pickup_latitude': 40.770837,
#   'pickup_longitude': -73.991015,
#   'trip_distance': 1.5},
#  {'pickup_latitude': 40.770932,
#   'pickup_longitude': -73.86622,
#   'trip_distance': 2.55},
#  {'pickup_latitude': 40.742625,
#   'pickup_longitude': -73.995955,
#   'trip_distance': 0.7},
#  {'pickup_latitude': 40.767386,
#   'pickup_longitude': -73.98615,
#   'trip_distance': 4.9},
#  {'pickup_latitude': 40.729417,
#   'pickup_longitude': -73.98997,
#   'trip_distance': 1.62},
#  {'pickup_latitude': 0.0, 'pickup_longitude': 0.0, 'trip_distance': 1.4},
#  {'pickup_latitude': 40.76026,
#   'pickup_longitude': -73.97671,
#   'trip_distance': 3.38},
#  {'pickup_latitude': 40.748453,
#   'pickup_longitude': -73.973209,
#   'trip_distance': 1.6},
#  {'pickup_latitude': 40.763605,
#   'pickup_longitude': -73.98895,
#   'trip_distance': 6.5},
#  {'pickup_latitude': 40.735872,
#   'pickup_longitude': -74.006705,
#   'trip_distance': 0.81},
#  {'pickup_latitude': 40.761363,
#   'pickup_longitude': -73.969672,
#   'trip_distance': 0.25},
#  {'pickup_latitude': 40.661145,
#   'pickup_longitude': -73.997122,
#   'trip_distance': 2.86},
#  {'pickup_latitude': 40.748542,
#   'pickup_longitude': -73.987952,
#   'trip_distance': 1.05},
#  {'pickup_latitude': 40.781112,
#   'pickup_longitude': -73.954135,
#   'trip_distance': 3.7},
#  {'pickup_latitude': 40.762465,
#   'pickup_longitude': -73.957122,
#   'trip_distance': 1.0},
#  {'pickup_latitude': 40.74805,
#   'pickup_longitude': -74.00412,
#   'trip_distance': 2.27},
#  {'pickup_latitude': 40.780242,
#   'pickup_longitude': -73.959577,
#   'trip_distance': 0.9},
#  {'pickup_latitude': 40.764726,
#   'pickup_longitude': -73.976783,
#   'trip_distance': 3.1},
#  {'pickup_latitude': 40.733294,
#   'pickup_longitude': -74.002744,
#   'trip_distance': 0.2},
#  {'pickup_latitude': 40.74976,
#   'pickup_longitude': -73.993847,
#   'trip_distance': 1.08},
#  {'pickup_latitude': 40.753168,
#   'pickup_longitude': -73.969728,
#   'trip_distance': 1.7},
#  {'pickup_latitude': 40.764099,
#   'pickup_longitude': -73.973033,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.796757,
#   'pickup_longitude': -73.970537,
#   'trip_distance': 6.8},
#  {'pickup_latitude': 40.765015,
#   'pickup_longitude': -73.976836,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.722397,
#   'pickup_longitude': -73.988933,
#   'trip_distance': 0.6},
#  {'pickup_latitude': 40.784722,
#   'pickup_longitude': -73.958018,
#   'trip_distance': 1.48},
#  {'pickup_latitude': 40.734082,
#   'pickup_longitude': -74.006202,
#   'trip_distance': 2.03},
#  {'pickup_latitude': 40.74772,
#   'pickup_longitude': -73.98274,
#   'trip_distance': 0.56},
#  {'pickup_latitude': 40.774329,
#   'pickup_longitude': -73.988897,
#   'trip_distance': 2.3},
#  {'pickup_latitude': 40.742366,
#   'pickup_longitude': -73.99317,
#   'trip_distance': 0.6},
#  {'pickup_latitude': 40.739342,
#   'pickup_longitude': -74.001677,
#   'trip_distance': 0.7},
#  {'pickup_latitude': 40.756363,
#   'pickup_longitude': -73.985773,
#   'trip_distance': 1.4},
#  {'pickup_latitude': 40.738254,
#   'pickup_longitude': -73.983499,
#   'trip_distance': 3.8},
#  {'pickup_latitude': 40.735046,
#   'pickup_longitude': -73.990119,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.755857,
#   'pickup_longitude': -73.997045,
#   'trip_distance': 3.1},
#  {'pickup_latitude': 40.772357,
#   'pickup_longitude': -73.960927,
#   'trip_distance': 0.88},
#  {'pickup_latitude': 40.775272,
#   'pickup_longitude': -73.95043,
#   'trip_distance': 1.78},
#  {'pickup_latitude': 40.763642,
#   'pickup_longitude': -73.988995,
#   'trip_distance': 7.68},
#  {'pickup_latitude': 40.768787,
#   'pickup_longitude': -73.862845,
#   'trip_distance': 12.15},
#  {'pickup_latitude': 40.772327,
#   'pickup_longitude': -73.952635,
#   'trip_distance': 0.83},
#  {'pickup_latitude': 40.750617,
#   'pickup_longitude': -73.97391,
#   'trip_distance': 1.6},
#  {'pickup_latitude': 40.74049,
#   'pickup_longitude': -73.998152,
#   'trip_distance': 4.2},
#  {'pickup_latitude': 40.759067,
#   'pickup_longitude': -73.977369,
#   'trip_distance': 1.1},
#  {'pickup_latitude': 40.762444,
#   'pickup_longitude': -73.98244,
#   'trip_distance': 0.8},
#  {'pickup_latitude': 40.774087,
#   'pickup_longitude': -73.874592,
#   'trip_distance': 9.25},
#  {'pickup_latitude': 40.781736,
#   'pickup_longitude': -73.981283,
#   'trip_distance': 0.4},
#  {'pickup_latitude': 40.757812,
#   'pickup_longitude': -73.989042,
#   'trip_distance': 1.46},
#  {'pickup_latitude': 40.787172,
#   'pickup_longitude': -73.97763,
#   'trip_distance': 0.53}]

# %%
cleaned_trips = float_values(parsed_trips)

# %%
cleaned_trips[0]

# {'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115,
#  'trip_distance': 18.38}
# Out:
# {'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115,
#  'trip_distance': 18.38}

# %% [markdown]
# ### Exploring the Data

# %% [markdown]
# Now that we have paired down our data, let's get a sense of our trip data.  We can use the `folium` Python library to plot a map of Manhattan, and our data.  First we must import `folium`, and then use the `Map` function to pass through a `location`, and `zoom_start`.  If a map isn't showing up below, copy and paste the command `pip install -r requirements.txt` into your terminal to install `folium` then try again.

# %%
# !pip install folium
# !pip install -r requirements.txt
import folium
manhattan_map = folium.Map(location=[40.7589, -73.9851], zoom_start=11)
manhattan_map.location
# Out:
# Requirement already satisfied: folium in /opt/conda/envs/learn-env/lib/python3.6/site-packages (0.10.0)
# Requirement already satisfied: numpy in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from folium) (1.17.2)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from folium) (2.10.3)
# Requirement already satisfied: requests in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from folium) (2.22.0)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from folium) (0.3.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from requests->folium) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from requests->folium) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: six in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: folium in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from -r requirements.txt (line 1)) (0.10.0)
# Requirement already satisfied: requests in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from folium->-r requirements.txt (line 1)) (2.22.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from folium->-r requirements.txt (line 1)) (2.10.3)
# Requirement already satisfied: numpy in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from folium->-r requirements.txt (line 1)) (1.17.2)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from folium->-r requirements.txt (line 1)) (0.3.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from requests->folium->-r requirements.txt (line 1)) (1.24.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from requests->folium->-r requirements.txt (line 1)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from requests->folium->-r requirements.txt (line 1)) (2019.9.11)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from requests->folium->-r requirements.txt (line 1)) (2.8)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from jinja2>=2.9->folium->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: six in /opt/conda/envs/learn-env/lib/python3.6/site-packages (from branca>=0.3.0->folium->-r requirements.txt (line 1)) (1.12.0)
# [40.7589, -73.9851]

# %%
manhattan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ok, now let's see how we could add a dot to mark a specific location.  We'll start with Times Square.

# %%
marker = folium.CircleMarker(location = [40.7589, -73.9851], radius=6)
marker.add_to(manhattan_map)
print("location="+str(marker.location)) 
print("radius="+str(marker.options['radius']))
marker.options
# Out:
# location=[40.7589, -73.9851]
# radius=6
# {'stroke': True,
#  'color': '#3388ff',
#  'weight': 3,
#  'opacity': 1.0,
#  'lineCap': 'round',
#  'lineJoin': 'round',
#  'dashArray': None,
#  'dashOffset': None,
#  'fill': False,
#  'fillColor': '#3388ff',
#  'fillOpacity': 0.2,
#  'fillRule': 'evenodd',
#  'bubblingMouseEvents': True,
#  'radius': 6}

# %% [markdown]
# Above, we first create a marker.  Then we add that circle marker to the `manhattan_map` we created earlier.

# %%
manhattan_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Do you see that blue dot near Time's Square?  That is our marker.
#
# So now that we can plot one marker on a map, we should have a sense of how we can plot many markers on a map to display our taxi ride data.  We simply plot a map, and then we add a marker for each location of a taxi trip.
#
# Now let's write some functions to allow us to plot maps and add markers a little more easily.

# %% [markdown]
# #### Writing some map plotting functions

# %% [markdown]
# As a first step towards this, note that the functions to create both a marker and map each take in a location as two element list, representing the latitude and longitude values.  Take another look:
#
# ```python
# marker = folium.CircleMarker(location = [40.7589, -73.9851])
# manhattan_map = folium.Map(location=[40.7589, -73.9851])
# ```
#
# So let's write a function called to create this two element list from a trip.  Write a function called `location` that  takes in a trip as an argument and returns a list where the first element is the latitude and the second is the longitude.  Remember that a location looks like the following:

# %%
first_trip = {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115,  'trip_distance': 18.38}
first_trip
# Out:
# {'pickup_latitude': 40.64499,
#  'pickup_longitude': -73.78115,
#  'trip_distance': 18.38}

# %%
def location(trip):
    return list(v for k,v in trip.items() if k == 'pickup_latitude' or k == 'pickup_longitude')
pass

# %%
first_location = location(first_trip) # [40.64499, -73.78115]
first_location # [40.64499, -73.78115]
# Out:
# [40.64499, -73.78115]

# %% [markdown]
# Ok, now that we can turn a trip into a location, let's turn a location into a marker.  Write a function called `to_marker` that takes in a location (in the form of a list) as an argument, and returns a folium `circleMarker` for that location.  The radius of the marker should always equal 6.

# %%
def to_marker(location):
    circle_marker = folium.CircleMarker(location, radius=6)
    circle_marker.add_to(manhattan_map)
    return circle_marker
    pass

# %%
import json
times_square_marker = to_marker([40.7589, -73.9851])

times_square_marker and times_square_marker.location # [40.7589, -73.9851]
print(times_square_marker.location)
print(times_square_marker.options['radius'])
#times_square_marker and json.loads(times_square_marker.options)['radius'] # 6
# Out:
# [40.7589, -73.9851]
# 6

# %% [markdown]
# Ok, now that we know how to produce a single marker, let's write a function to produce lots.  We can write a function called `markers_from_trips` that takes in a list of trips, and returns a marker object for each trip.

# %%
def markers_from_trips(trips):
    X = []
    for trip in trips:
        #X.append(location(trip))
        X.append(to_marker(location(trip)))
    return X
    pass

markers_from_trips(trips)
# Out:
# [<folium.vector_layers.CircleMarker at 0x7ff1f377e5c0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e2b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e630>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e5f8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e588>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e198>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e7b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e4e0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e400>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e550>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e828>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e978>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e748>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e358>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377eac8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e6a0>,
#  <folium.vector_layers.CircleMarker at 0x7ff2186f7710>,
#  <folium.vector_layers.CircleMarker at 0x7ff228267438>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3782438>,
#  <folium.vector_layers.CircleMarker at 0x7ff2186f7860>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3782550>,
#  <folium.vector_layers.CircleMarker at 0x7ff228267240>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3782710>,
#  <folium.vector_layers.CircleMarker at 0x7ff228267208>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3782dd8>,
#  <folium.vector_layers.CircleMarker at 0x7ff2282671d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3782c18>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37825f8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377ea90>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e908>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377ec18>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377eb38>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377eb70>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e668>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377ecc0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e3c8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377ea20>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377ec50>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e898>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e8d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377ea58>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377ecf8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377eba8>,
#  <folium.vector_layers.CircleMarker at 0x7ff22ae428d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377ec88>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e860>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e940>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e780>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377ed68>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377eb00>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377edd8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e6d8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e9b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e710>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e9e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377eda0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377e7f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377ee10>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377ee48>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377ee80>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377eeb8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377ef28>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377efd0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377ef60>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377eef0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377ebe0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f377ef98>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723048>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37230f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723160>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37231d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723208>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723278>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37232e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37230b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723128>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723198>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723240>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37232b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723320>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723358>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723390>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37233c8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723400>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723438>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723470>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37234a8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37234e0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723518>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723550>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723588>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37235c0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37235f8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723630>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723668>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37236a0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37236d8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723710>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723748>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723780>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37237b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37237f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723828>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723860>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723898>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37238d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723908>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723940>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723978>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37239b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37239e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723a20>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723a58>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723a90>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723ac8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723b00>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723b38>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723b70>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723ba8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723be0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723c18>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723c50>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723c88>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723cc0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723cf8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723d30>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723d68>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723da0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723dd8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723e10>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723e48>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723e80>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723eb8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723f28>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723fd0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723f60>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723ef0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723080>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3723f98>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37380b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738128>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37381d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738160>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738240>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37382b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738048>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37380f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738198>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738208>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738278>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37382e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738320>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738358>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738390>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37383c8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738400>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738438>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738470>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37384a8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37384e0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738518>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738550>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738588>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37385c0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37385f8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738630>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738668>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37386a0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37386d8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738710>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738748>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738780>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37387b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37387f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738828>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738860>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738898>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37388d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738908>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738940>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738978>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37389b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37389e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738a20>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738a58>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738a90>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738ac8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738b00>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738b38>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738b70>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738ba8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738be0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738c18>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738c50>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738c88>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738cc0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738cf8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738d30>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738d68>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738da0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738dd8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738e10>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738e48>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738e80>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738eb8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738f28>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738fd0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738f60>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738ef0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738080>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3738f98>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37490b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749128>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37491d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749160>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749240>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37492b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749048>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37490f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749198>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749208>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749278>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37492e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749320>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749358>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749390>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37493c8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749400>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749438>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749470>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37494a8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37494e0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749518>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749550>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749588>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37495c0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37495f8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749630>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749668>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37496a0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37496d8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749710>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749748>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749780>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37497b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37497f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749828>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749860>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749898>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37498d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749908>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749940>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749978>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37499b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f37499e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749a20>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749a58>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749a90>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749ac8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749b00>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749b38>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749b70>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749ba8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749be0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749c18>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749c50>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749c88>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749cc0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749cf8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749d30>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749d68>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749da0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749dd8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749e10>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749e48>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749e80>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749eb8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749f28>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749fd0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749f60>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749ef0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749080>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3749f98>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da0b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da128>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da1d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da160>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da240>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da2b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da048>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da0f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da198>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da208>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da278>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da2e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da320>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da358>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da390>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da3c8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da400>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da438>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da470>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da4a8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da4e0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da518>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da550>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da588>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da5c0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da5f8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da630>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da668>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da6a0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da6d8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da710>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da748>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da780>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da7b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da7f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da828>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da860>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da898>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da8d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da908>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da940>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da978>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da9b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da9e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36daa20>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36daa58>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36daa90>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36daac8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dab00>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dab38>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dab70>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36daba8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dabe0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dac18>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dac50>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dac88>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dacc0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dacf8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dad30>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dad68>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dada0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dadd8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dae10>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dae48>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dae80>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36daeb8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36daf28>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36dafd0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36daf60>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36daef0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36da080>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36daf98>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea0b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea128>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea1d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea198>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea240>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea2b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea048>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea0f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea160>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea208>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea278>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea2e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea320>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea358>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea390>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea3c8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea400>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea438>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea470>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea4a8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea4e0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea518>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea550>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea588>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea5c0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea5f8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea630>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea668>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea6a0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea6d8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea710>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea748>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea780>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea7b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea7f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea828>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea860>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea898>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea8d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea908>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea940>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea978>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea9b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea9e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eaa20>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eaa58>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eaa90>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eaac8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eab00>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eab38>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eab70>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eaba8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eabe0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eac18>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eac50>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eac88>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eacc0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eacf8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ead30>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ead68>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eada0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eadd8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eae10>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eae48>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eae80>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eaeb8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eaf28>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eafd0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eaf60>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eaef0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36ea080>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36eaf98>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa0b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa128>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa1d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa160>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa240>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa2b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa048>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa0f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa198>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa208>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa278>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa2e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa320>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa358>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa390>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa3c8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa400>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa438>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa470>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa4a8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa4e0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa518>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa550>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa588>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa5c0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa5f8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa630>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa668>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa6a0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa6d8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa710>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa748>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa780>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa7b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa7f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa828>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa860>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa898>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa8d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa908>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa940>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa978>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa9b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa9e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36faa20>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36faa58>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36faa90>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36faac8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fab00>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fab38>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fab70>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36faba8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fabe0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fac18>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fac50>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fac88>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36facc0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36facf8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fad30>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fad68>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fada0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fadd8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fae10>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fae48>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fae80>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36faeb8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36faf28>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fafd0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36faf60>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36faef0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36fa080>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36faf98>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d0b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d128>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d198>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d1d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d240>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d2b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d048>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d0f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d160>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d208>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d278>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d2e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d320>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d358>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d390>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d3c8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d400>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d438>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d470>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d4a8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d4e0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d518>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d550>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d588>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d5c0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d5f8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d630>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d668>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d6a0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d6d8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d710>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d748>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d780>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d7b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d7f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d828>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d860>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d898>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d8d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d908>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d940>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d978>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d9b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d9e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370da20>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370da58>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370da90>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370dac8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370db00>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370db38>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370db70>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370dba8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370dbe0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370dc18>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370dc50>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370dc88>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370dcc0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370dcf8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370dd30>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370dd68>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370dda0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370ddd8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370de10>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370de48>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370de80>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370deb8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370df28>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370dfd0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370df60>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370def0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370d080>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f370df98>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c0b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c128>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c1d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c160>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c240>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c2b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c048>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c0f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c198>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c208>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c278>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c2e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c320>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c358>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c390>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c3c8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c400>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c438>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c470>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c4a8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c4e0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c518>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c550>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c588>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c5c0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c5f8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c630>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c668>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c6a0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c6d8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c710>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c748>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c780>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c7b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c7f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c828>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c860>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c898>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c8d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c908>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c940>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c978>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c9b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c9e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369ca20>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369ca58>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369ca90>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cac8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cb00>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cb38>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cb70>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cba8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cbe0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cc18>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cc50>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cc88>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369ccc0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369ccf8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cd30>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cd68>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cda0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cdd8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369ce10>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369ce48>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369ce80>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369ceb8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cf28>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cfd0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cf60>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cef0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369c080>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f369cf98>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af048>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af0f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af160>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af1d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af208>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af278>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af2e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af0b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af128>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af198>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af240>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af2b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af320>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af358>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af390>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af3c8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af400>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af438>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af470>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af4a8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af4e0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af518>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af550>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af588>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af5c0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af5f8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af630>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af668>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af6a0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af6d8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af710>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af748>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af780>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af7b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af7f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af828>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af860>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af898>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af8d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af908>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af940>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af978>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af9b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af9e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afa20>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afa58>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afa90>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afac8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afb00>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afb38>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afb70>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afba8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afbe0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afc18>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afc50>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afc88>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afcc0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afcf8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afd30>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afd68>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afda0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afdd8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afe10>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afe48>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afe80>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afeb8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36aff28>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36affd0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36aff60>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36afef0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36af080>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36aff98>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf0b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf128>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf1d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf160>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf240>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf2b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf048>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf0f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf198>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf208>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf278>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf2e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf320>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf358>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf390>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf3c8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf400>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf438>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf470>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf4a8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf4e0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf518>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf550>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf588>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf5c0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf5f8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf630>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf668>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf6a0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf6d8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf710>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf748>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf780>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf7b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf7f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf828>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf860>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf898>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf8d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf908>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf940>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf978>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf9b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf9e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfa20>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfa58>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfa90>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfac8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfb00>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfb38>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfb70>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfba8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfbe0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfc18>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfc50>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfc88>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfcc0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfcf8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfd30>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfd68>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfda0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfdd8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfe10>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfe48>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfe80>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfeb8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bff28>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bffd0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bff60>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bfef0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bf080>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36bff98>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d00b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0128>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d01d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0160>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0240>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d02b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0048>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d00f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0198>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0208>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0278>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d02e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0320>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0358>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0390>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d03c8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0400>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0438>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0470>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d04a8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d04e0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0518>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0550>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0588>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d05c0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d05f8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0630>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0668>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d06a0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d06d8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0710>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0748>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0780>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d07b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d07f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0828>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0860>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0898>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d08d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0908>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0940>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0978>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d09b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d09e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0a20>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0a58>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0a90>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0ac8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0b00>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0b38>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0b70>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0ba8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0be0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0c18>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0c50>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0c88>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0cc0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0cf8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0d30>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0d68>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0da0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0dd8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0e10>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0e48>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0e80>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0eb8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0f28>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0fd0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0f60>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0ef0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0080>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36d0f98>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36600b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660128>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36601d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660160>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660240>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36602b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660048>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36600f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660198>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660208>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660278>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36602e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660320>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660358>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660390>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36603c8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660400>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660438>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660470>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36604a8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36604e0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660518>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660550>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660588>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36605c0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36605f8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660630>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660668>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36606a0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36606d8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660710>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660748>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660780>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36607b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36607f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660828>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660860>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660898>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36608d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660908>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660940>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660978>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36609b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36609e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660a20>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660a58>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660a90>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660ac8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660b00>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660b38>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660b70>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660ba8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660be0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660c18>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660c50>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660c88>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660cc0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660cf8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660d30>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660d68>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660da0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660dd8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660e10>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660e48>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660e80>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660eb8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660f28>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660fd0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660f60>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660ef0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660080>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3660f98>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36710b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671128>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36711d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671198>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671240>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36712b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671048>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36710f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671160>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671208>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671278>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36712e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671320>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671358>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671390>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36713c8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671400>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671438>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671470>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36714a8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36714e0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671518>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671550>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671588>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36715c0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36715f8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671630>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671668>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36716a0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36716d8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671710>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671748>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671780>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36717b8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36717f0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671828>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671860>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671898>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36718d0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671908>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671940>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671978>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36719b0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f36719e8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671a20>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671a58>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671a90>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671ac8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671b00>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671b38>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671b70>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671ba8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671be0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671c18>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671c50>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671c88>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671cc0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671cf8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671d30>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671d68>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671da0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671dd8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671e10>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671e48>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671e80>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671eb8>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671f28>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671fd0>,
#  <folium.vector_layers.CircleMarker at 0x7ff1f3671f60>]

# %%
trip_markers = markers_from_trips(cleaned_trips)
counter = 0
for trip_marker in trip_markers:
    counter += 1
    print(str(counter)+" location[latitude,longitude]:"+str(trip_marker.location))
# Out:
# 1 location[latitude,longitude]:[40.64499, -73.78115]
# 2 location[latitude,longitude]:[40.766931, -73.982098]
# 3 location[latitude,longitude]:[40.77773, -73.951902]
# 4 location[latitude,longitude]:[40.795678, -73.971049]
# 5 location[latitude,longitude]:[40.762912, -73.967782]
# 6 location[latitude,longitude]:[40.731176, -73.991572]
# 7 location[latitude,longitude]:[40.800219, -73.968098]
# 8 location[latitude,longitude]:[40.648509, -73.783508]
# 9 location[latitude,longitude]:[40.721897, -73.983493]
# 10 location[latitude,longitude]:[40.791566, -73.972224]
# 11 location[latitude,longitude]:[40.744896, -73.978619]
# 12 location[latitude,longitude]:[40.721951, -73.844435]
# 13 location[latitude,longitude]:[40.732382, -74.001682]
# 14 location[latitude,longitude]:[40.768339, -73.961478]
# 15 location[latitude,longitude]:[40.775933, -73.962446]
# 16 location[latitude,longitude]:[40.794829, -73.971476]
# 17 location[latitude,longitude]:[40.758647, -73.964878]
# 18 location[latitude,longitude]:[40.713638, -74.011587]
# 19 location[latitude,longitude]:[40.77403, -73.874597]
# 20 location[latitude,longitude]:[40.728127, -73.99887]
# 21 location[latitude,longitude]:[40.759671, -73.976688]
# 22 location[latitude,longitude]:[40.772651, -73.967095]
# 23 location[latitude,longitude]:[40.770319, -73.960222]
# 24 location[latitude,longitude]:[40.720457, -73.988065]
# 25 location[latitude,longitude]:[40.754789, -73.973606]
# 26 location[latitude,longitude]:[40.755654, -73.985846]
# 27 location[latitude,longitude]:[40.741568, -73.978341]
# 28 location[latitude,longitude]:[40.736907, -73.98862]
# 29 location[latitude,longitude]:[40.76003, -73.964842]
# 30 location[latitude,longitude]:[40.721366, -74.008287]
# 31 location[latitude,longitude]:[40.760147, -73.97627]
# 32 location[latitude,longitude]:[40.745847, -74.001817]
# 33 location[latitude,longitude]:[40.753015, -73.985247]
# 34 location[latitude,longitude]:[40.644657, -73.782229]
# 35 location[latitude,longitude]:[40.738767, -74.0086]
# 36 location[latitude,longitude]:[40.773797, -73.871065]
# 37 location[latitude,longitude]:[40.743411, -73.97686]
# 38 location[latitude,longitude]:[40.758905, -73.967897]
# 39 location[latitude,longitude]:[40.733877, -73.989602]
# 40 location[latitude,longitude]:[40.726162, -73.983432]
# 41 location[latitude,longitude]:[40.775122, -73.947765]
# 42 location[latitude,longitude]:[40.75987, -73.978487]
# 43 location[latitude,longitude]:[40.707087, -73.94328]
# 44 location[latitude,longitude]:[40.741912, -74.003578]
# 45 location[latitude,longitude]:[40.769112, -73.862679]
# 46 location[latitude,longitude]:[40.785807, -73.976387]
# 47 location[latitude,longitude]:[40.7513, -73.986852]
# 48 location[latitude,longitude]:[40.733385, -73.987204]
# 49 location[latitude,longitude]:[40.760257, -73.976186]
# 50 location[latitude,longitude]:[40.741249, -74.005201]
# 51 location[latitude,longitude]:[40.759795, -73.985352]
# 52 location[latitude,longitude]:[40.756636, -73.9697]
# 53 location[latitude,longitude]:[40.73925, -74.000759]
# 54 location[latitude,longitude]:[40.751055, -73.97607]
# 55 location[latitude,longitude]:[40.723584, -73.995992]
# 56 location[latitude,longitude]:[40.757037, -73.929485]
# 57 location[latitude,longitude]:[40.743385, -73.981978]
# 58 location[latitude,longitude]:[40.737486, -73.978153]
# 59 location[latitude,longitude]:[40.77225, -73.95285]
# 60 location[latitude,longitude]:[40.732882, -73.981975]
# 61 location[latitude,longitude]:[40.774567, -73.988232]
# 62 location[latitude,longitude]:[40.757437, -73.964735]
# 63 location[latitude,longitude]:[40.789637, -73.975402]
# 64 location[latitude,longitude]:[40.754317, -73.992548]
# 65 location[latitude,longitude]:[40.745007, -73.998627]
# 66 location[latitude,longitude]:[40.734982, -73.990523]
# 67 location[latitude,longitude]:[0.0, 0.0]
# 68 location[latitude,longitude]:[40.738617, -73.989672]
# 69 location[latitude,longitude]:[40.790712, -73.972809]
# 70 location[latitude,longitude]:[40.750167, -73.987398]
# 71 location[latitude,longitude]:[40.732141, -73.98447]
# 72 location[latitude,longitude]:[40.765758, -73.994847]
# 73 location[latitude,longitude]:[40.792594, -73.964102]
# 74 location[latitude,longitude]:[40.762908, -73.969549]
# 75 location[latitude,longitude]:[40.750722, -73.968447]
# 76 location[latitude,longitude]:[40.769887, -73.86443]
# 77 location[latitude,longitude]:[40.77247, -73.982419]
# 78 location[latitude,longitude]:[40.764545, -73.982668]
# 79 location[latitude,longitude]:[40.641805, -73.78641]
# 80 location[latitude,longitude]:[40.75224, -73.97835]
# 81 location[latitude,longitude]:[40.758835, -73.988555]
# 82 location[latitude,longitude]:[40.722785, -73.988558]
# 83 location[latitude,longitude]:[40.720338, -73.993645]
# 84 location[latitude,longitude]:[40.72973, -73.991628]
# 85 location[latitude,longitude]:[40.760442, -73.958405]
# 86 location[latitude,longitude]:[40.756227, -73.98314]
# 87 location[latitude,longitude]:[40.751555, -73.992905]
# 88 location[latitude,longitude]:[40.71333, -74.004106]
# 89 location[latitude,longitude]:[40.764762, -73.991849]
# 90 location[latitude,longitude]:[40.763353, -73.985259]
# 91 location[latitude,longitude]:[40.775292, -73.982082]
# 92 location[latitude,longitude]:[40.779515, -73.984852]
# 93 location[latitude,longitude]:[40.768322, -73.982234]
# 94 location[latitude,longitude]:[40.766602, -73.95388]
# 95 location[latitude,longitude]:[40.763684, -73.981214]
# 96 location[latitude,longitude]:[40.793086, -73.952092]
# 97 location[latitude,longitude]:[40.773602, -73.871055]
# 98 location[latitude,longitude]:[40.771909, -73.959023]
# 99 location[latitude,longitude]:[40.774029, -73.961478]
# 100 location[latitude,longitude]:[40.74964, -73.972212]
# 101 location[latitude,longitude]:[40.771542, -73.959533]
# 102 location[latitude,longitude]:[40.694095, -73.9839]
# 103 location[latitude,longitude]:[40.756312, -73.994315]
# 104 location[latitude,longitude]:[40.730282, -74.006652]
# 105 location[latitude,longitude]:[40.777707, -73.955068]
# 106 location[latitude,longitude]:[40.726087, -73.994962]
# 107 location[latitude,longitude]:[40.738385, -73.999885]
# 108 location[latitude,longitude]:[40.7678, -73.961987]
# 109 location[latitude,longitude]:[40.742682, -73.972513]
# 110 location[latitude,longitude]:[40.770602, -73.982262]
# 111 location[latitude,longitude]:[40.747967, -73.976727]
# 112 location[latitude,longitude]:[40.742803, -74.004093]
# 113 location[latitude,longitude]:[40.755521, -73.97546]
# 114 location[latitude,longitude]:[40.760528, -74.002757]
# 115 location[latitude,longitude]:[40.740732, -74.005513]
# 116 location[latitude,longitude]:[40.735497, -74.00601]
# 117 location[latitude,longitude]:[40.715387, -74.013518]
# 118 location[latitude,longitude]:[40.721587, -73.995427]
# 119 location[latitude,longitude]:[40.760057, -73.983502]
# 120 location[latitude,longitude]:[40.740332, -73.986289]
# 121 location[latitude,longitude]:[40.7455, -73.977834]
# 122 location[latitude,longitude]:[40.733125, -73.987273]
# 123 location[latitude,longitude]:[40.752092, -73.989949]
# 124 location[latitude,longitude]:[40.72381, -73.992617]
# 125 location[latitude,longitude]:[40.767446, -73.984105]
# 126 location[latitude,longitude]:[40.800479, -73.968083]
# 127 location[latitude,longitude]:[40.717055, -73.991325]
# 128 location[latitude,longitude]:[40.748863, -73.992155]
# 129 location[latitude,longitude]:[40.80474, -73.9478]
# 130 location[latitude,longitude]:[40.762202, -73.969015]
# 131 location[latitude,longitude]:[0.0, 0.0]
# 132 location[latitude,longitude]:[40.740407, -73.987223]
# 133 location[latitude,longitude]:[40.722399, -73.997097]
# 134 location[latitude,longitude]:[40.747572, -73.974092]
# 135 location[latitude,longitude]:[40.794651, -73.972048]
# 136 location[latitude,longitude]:[40.751087, -73.9716]
# 137 location[latitude,longitude]:[40.719886, -74.009981]
# 138 location[latitude,longitude]:[40.760887, -73.98696]
# 139 location[latitude,longitude]:[40.727514, -74.0073]
# 140 location[latitude,longitude]:[40.774453, -73.872166]
# 141 location[latitude,longitude]:[40.741907, -74.003545]
# 142 location[latitude,longitude]:[40.735118, -73.97979]
# 143 location[latitude,longitude]:[40.773907, -73.871275]
# 144 location[latitude,longitude]:[40.758937, -73.994232]
# 145 location[latitude,longitude]:[40.752144, -73.977199]
# 146 location[latitude,longitude]:[40.745642, -73.990757]
# 147 location[latitude,longitude]:[40.71879, -73.98984]
# 148 location[latitude,longitude]:[40.739945, -74.006124]
# 149 location[latitude,longitude]:[40.777575, -73.986287]
# 150 location[latitude,longitude]:[40.753632, -73.988899]
# 151 location[latitude,longitude]:[40.74733, -73.97703]
# 152 location[latitude,longitude]:[40.769822, -73.960596]
# 153 location[latitude,longitude]:[40.724658, -73.997131]
# 154 location[latitude,longitude]:[40.758345, -73.989398]
# 155 location[latitude,longitude]:[40.764807, -73.97669]
# 156 location[latitude,longitude]:[40.772847, -73.962703]
# 157 location[latitude,longitude]:[40.793682, -73.966972]
# 158 location[latitude,longitude]:[40.760007, -73.97804]
# 159 location[latitude,longitude]:[40.747252, -73.888215]
# 160 location[latitude,longitude]:[40.756392, -73.967522]
# 161 location[latitude,longitude]:[40.763685, -73.977714]
# 162 location[latitude,longitude]:[40.767068, -73.982805]
# 163 location[latitude,longitude]:[40.77596, -73.98728]
# 164 location[latitude,longitude]:[40.739617, -73.984663]
# 165 location[latitude,longitude]:[40.751953, -73.976404]
# 166 location[latitude,longitude]:[40.718635, -74.000952]
# 167 location[latitude,longitude]:[40.7331, -73.981375]
# 168 location[latitude,longitude]:[40.77463, -73.96322]
# 169 location[latitude,longitude]:[40.753675, -73.984942]
# 170 location[latitude,longitude]:[40.763262, -73.95948]
# 171 location[latitude,longitude]:[40.768895, -73.958237]
# 172 location[latitude,longitude]:[40.641375, -73.788935]
# 173 location[latitude,longitude]:[40.745472, -73.98666]
# 174 location[latitude,longitude]:[40.707562, -74.004372]
# 175 location[latitude,longitude]:[40.75331, -73.968992]
# 176 location[latitude,longitude]:[40.769545, -73.960554]
# 177 location[latitude,longitude]:[40.77411, -73.874625]
# 178 location[latitude,longitude]:[40.720615, -74.009875]
# 179 location[latitude,longitude]:[40.76305, -73.969831]
# 180 location[latitude,longitude]:[40.648605, -73.78482]
# 181 location[latitude,longitude]:[40.730875, -74.001527]
# 182 location[latitude,longitude]:[40.763843, -73.928025]
# 183 location[latitude,longitude]:[40.759867, -73.97835]
# 184 location[latitude,longitude]:[40.77302, -73.982]
# 185 location[latitude,longitude]:[40.767437, -73.980957]
# 186 location[latitude,longitude]:[40.7951, -73.97166]
# 187 location[latitude,longitude]:[40.78045, -73.980198]
# 188 location[latitude,longitude]:[40.777608, -73.956815]
# 189 location[latitude,longitude]:[40.783897, -73.952306]
# 190 location[latitude,longitude]:[40.738437, -73.999686]
# 191 location[latitude,longitude]:[40.766227, -73.980152]
# 192 location[latitude,longitude]:[40.7472, -74.007947]
# 193 location[latitude,longitude]:[40.729602, -73.987032]
# 194 location[latitude,longitude]:[40.747295, -74.000877]
# 195 location[latitude,longitude]:[40.764276, -73.954283]
# 196 location[latitude,longitude]:[40.717463, -74.005494]
# 197 location[latitude,longitude]:[40.756667, -73.967298]
# 198 location[latitude,longitude]:[40.723036, -73.988783]
# 199 location[latitude,longitude]:[40.742832, -73.989064]
# 200 location[latitude,longitude]:[40.759825, -73.970231]
# 201 location[latitude,longitude]:[40.770567, -73.954641]
# 202 location[latitude,longitude]:[40.743565, -73.988827]
# 203 location[latitude,longitude]:[40.761372, -73.982602]
# 204 location[latitude,longitude]:[40.725012, -73.995492]
# 205 location[latitude,longitude]:[40.751251, -73.975745]
# 206 location[latitude,longitude]:[40.742522, -73.993292]
# 207 location[latitude,longitude]:[40.762107, -73.98479]
# 208 location[latitude,longitude]:[40.787171, -73.953967]
# 209 location[latitude,longitude]:[40.739887, -74.004942]
# 210 location[latitude,longitude]:[40.775297, -73.982005]
# 211 location[latitude,longitude]:[40.743232, -73.983751]
# 212 location[latitude,longitude]:[40.757386, -73.987253]
# 213 location[latitude,longitude]:[40.749027, -73.98395]
# 214 location[latitude,longitude]:[40.752385, -73.978314]
# 215 location[latitude,longitude]:[40.721988, -73.986383]
# 216 location[latitude,longitude]:[40.742422, -73.991082]
# 217 location[latitude,longitude]:[40.735396, -73.993911]
# 218 location[latitude,longitude]:[40.749873, -73.991593]
# 219 location[latitude,longitude]:[40.779447, -73.962047]
# 220 location[latitude,longitude]:[40.730843, -74.00677]
# 221 location[latitude,longitude]:[40.750116, -73.987503]
# 222 location[latitude,longitude]:[40.701734, -74.011263]
# 223 location[latitude,longitude]:[40.72635, -73.977049]
# 224 location[latitude,longitude]:[40.688702, -73.98921]
# 225 location[latitude,longitude]:[40.771385, -73.96467]
# 226 location[latitude,longitude]:[40.715884, -73.959979]
# 227 location[latitude,longitude]:[40.790046, -73.975066]
# 228 location[latitude,longitude]:[40.76418, -73.97822]
# 229 location[latitude,longitude]:[40.76041, -73.987652]
# 230 location[latitude,longitude]:[40.745647, -73.978275]
# 231 location[latitude,longitude]:[40.793261, -73.940565]
# 232 location[latitude,longitude]:[40.762111, -73.968438]
# 233 location[latitude,longitude]:[40.74733, -73.9969]
# 234 location[latitude,longitude]:[40.74886, -73.988666]
# 235 location[latitude,longitude]:[40.730145, -73.986395]
# 236 location[latitude,longitude]:[40.75318, -73.973152]
# 237 location[latitude,longitude]:[40.829557, -73.837699]
# 238 location[latitude,longitude]:[40.743102, -73.973988]
# 239 location[latitude,longitude]:[40.750445, -73.98674]
# 240 location[latitude,longitude]:[40.743475, -73.923155]
# 241 location[latitude,longitude]:[40.762752, -73.993035]
# 242 location[latitude,longitude]:[40.765577, -73.979713]
# 243 location[latitude,longitude]:[40.750027, -73.89876]
# 244 location[latitude,longitude]:[40.751947, -73.986142]
# 245 location[latitude,longitude]:[40.71972, -74.008841]
# 246 location[latitude,longitude]:[40.78079, -73.946522]
# 247 location[latitude,longitude]:[40.751607, -73.993449]
# 248 location[latitude,longitude]:[40.745595, -73.988398]
# 249 location[latitude,longitude]:[40.72245, -73.98729]
# 250 location[latitude,longitude]:[40.702557, -73.93467]
# 251 location[latitude,longitude]:[40.734659, -73.98004]
# 252 location[latitude,longitude]:[40.764774, -73.992049]
# 253 location[latitude,longitude]:[40.723516, -73.985065]
# 254 location[latitude,longitude]:[40.781072, -73.983538]
# 255 location[latitude,longitude]:[40.793005, -73.973026]
# 256 location[latitude,longitude]:[40.721025, -73.993857]
# 257 location[latitude,longitude]:[40.768497, -73.899785]
# 258 location[latitude,longitude]:[40.80726, -73.954179]
# 259 location[latitude,longitude]:[40.773715, -73.963908]
# 260 location[latitude,longitude]:[40.780082, -73.956843]
# 261 location[latitude,longitude]:[40.741824, -73.982933]
# 262 location[latitude,longitude]:[40.742112, -74.004672]
# 263 location[latitude,longitude]:[40.725925, -74.007585]
# 264 location[latitude,longitude]:[40.645718, -73.776765]
# 265 location[latitude,longitude]:[40.718398, -73.994967]
# 266 location[latitude,longitude]:[0.0, 0.0]
# 267 location[latitude,longitude]:[40.736343, -73.99289]
# 268 location[latitude,longitude]:[40.753827, -73.994472]
# 269 location[latitude,longitude]:[40.750693, -73.971834]
# 270 location[latitude,longitude]:[40.745964, -73.991152]
# 271 location[latitude,longitude]:[40.740482, -74.004042]
# 272 location[latitude,longitude]:[0.0, 0.0]
# 273 location[latitude,longitude]:[40.803842, -73.966812]
# 274 location[latitude,longitude]:[40.797632, -73.969822]
# 275 location[latitude,longitude]:[40.645322, -73.776652]
# 276 location[latitude,longitude]:[40.749207, -74.003233]
# 277 location[latitude,longitude]:[40.765548, -73.983683]
# 278 location[latitude,longitude]:[40.760289, -73.931531]
# 279 location[latitude,longitude]:[40.778967, -73.981767]
# 280 location[latitude,longitude]:[40.7582, -73.973285]
# 281 location[latitude,longitude]:[40.730709, -73.990504]
# 282 location[latitude,longitude]:[40.7456, -73.97814]
# 283 location[latitude,longitude]:[40.719471, -73.999779]
# 284 location[latitude,longitude]:[40.75619, -73.974282]
# 285 location[latitude,longitude]:[40.639542, -73.967915]
# 286 location[latitude,longitude]:[40.78366, -73.97427]
# 287 location[latitude,longitude]:[40.7464, -73.97771]
# 288 location[latitude,longitude]:[40.727475, -73.98533]
# 289 location[latitude,longitude]:[40.735015, -74.006024]
# 290 location[latitude,longitude]:[0.0, 0.0]
# 291 location[latitude,longitude]:[0.0, 0.0]
# 292 location[latitude,longitude]:[40.754176, -74.04442]
# 293 location[latitude,longitude]:[40.740112, -73.994987]
# 294 location[latitude,longitude]:[40.719972, -73.987553]
# 295 location[latitude,longitude]:[40.70517, -74.006987]
# 296 location[latitude,longitude]:[40.789142, -73.970472]
# 297 location[latitude,longitude]:[40.749115, -73.984182]
# 298 location[latitude,longitude]:[40.76443, -73.992037]
# 299 location[latitude,longitude]:[40.756477, -73.990472]
# 300 location[latitude,longitude]:[40.746142, -73.984852]
# 301 location[latitude,longitude]:[40.747856, -73.989088]
# 302 location[latitude,longitude]:[40.772615, -73.964789]
# 303 location[latitude,longitude]:[40.761912, -73.975275]
# 304 location[latitude,longitude]:[40.740991, -74.005581]
# 305 location[latitude,longitude]:[40.764115, -73.97707]
# 306 location[latitude,longitude]:[40.728808, -73.987538]
# 307 location[latitude,longitude]:[40.725511, -73.991953]
# 308 location[latitude,longitude]:[40.768967, -73.954822]
# 309 location[latitude,longitude]:[40.75652, -73.973926]
# 310 location[latitude,longitude]:[40.751217, -73.970895]
# 311 location[latitude,longitude]:[40.779557, -73.977187]
# 312 location[latitude,longitude]:[40.771472, -73.8755]
# 313 location[latitude,longitude]:[40.73832, -73.9918]
# 314 location[latitude,longitude]:[40.643172, -73.789035]
# 315 location[latitude,longitude]:[40.769387, -73.953623]
# 316 location[latitude,longitude]:[40.731752, -74.000932]
# 317 location[latitude,longitude]:[40.745874, -73.991095]
# 318 location[latitude,longitude]:[40.767867, -73.963893]
# 319 location[latitude,longitude]:[40.766245, -73.98354]
# 320 location[latitude,longitude]:[40.753485, -73.97311]
# 321 location[latitude,longitude]:[40.726597, -73.986165]
# 322 location[latitude,longitude]:[40.7446, -73.985232]
# 323 location[latitude,longitude]:[40.756806, -73.969385]
# 324 location[latitude,longitude]:[40.783447, -73.947283]
# 325 location[latitude,longitude]:[40.758985, -73.989435]
# 326 location[latitude,longitude]:[40.645316, -73.776808]
# 327 location[latitude,longitude]:[40.762868, -73.983233]
# 328 location[latitude,longitude]:[40.761322, -73.975755]
# 329 location[latitude,longitude]:[40.771097, -73.865913]
# 330 location[latitude,longitude]:[40.760195, -73.967307]
# 331 location[latitude,longitude]:[40.73286, -74.00007]
# 332 location[latitude,longitude]:[40.75952, -73.985488]
# 333 location[latitude,longitude]:[40.821517, -73.954177]
# 334 location[latitude,longitude]:[40.734922, -73.990548]
# 335 location[latitude,longitude]:[40.757594, -73.989531]
# 336 location[latitude,longitude]:[40.748042, -73.880385]
# 337 location[latitude,longitude]:[40.74957, -73.992772]
# 338 location[latitude,longitude]:[40.759663, -73.981141]
# 339 location[latitude,longitude]:[40.756397, -73.966882]
# 340 location[latitude,longitude]:[40.68078, -73.967735]
# 341 location[latitude,longitude]:[40.749994, -73.994031]
# 342 location[latitude,longitude]:[40.801351, -73.961519]
# 343 location[latitude,longitude]:[40.766223, -73.981952]
# 344 location[latitude,longitude]:[40.740045, -73.982178]
# 345 location[latitude,longitude]:[40.801657, -73.934415]
# 346 location[latitude,longitude]:[40.738722, -73.987027]
# 347 location[latitude,longitude]:[40.742172, -74.00809]
# 348 location[latitude,longitude]:[40.775633, -73.98233]
# 349 location[latitude,longitude]:[40.792377, -73.96788]
# 350 location[latitude,longitude]:[40.659956, -73.99842]
# 351 location[latitude,longitude]:[40.7655, -73.97585]
# 352 location[latitude,longitude]:[40.737997, -73.992069]
# 353 location[latitude,longitude]:[40.711467, -73.945825]
# 354 location[latitude,longitude]:[0.0, 0.0]
# 355 location[latitude,longitude]:[40.710822, -74.015592]
# 356 location[latitude,longitude]:[40.763597, -73.97968]
# 357 location[latitude,longitude]:[40.744277, -73.973007]
# 358 location[latitude,longitude]:[40.774152, -73.873092]
# 359 location[latitude,longitude]:[40.773736, -73.959905]
# 360 location[latitude,longitude]:[40.740018, -74.005399]
# 361 location[latitude,longitude]:[40.750094, -73.979116]
# 362 location[latitude,longitude]:[40.741317, -73.983402]
# 363 location[latitude,longitude]:[40.75885, -73.965817]
# 364 location[latitude,longitude]:[40.687077, -73.990203]
# 365 location[latitude,longitude]:[40.76705, -73.979222]
# 366 location[latitude,longitude]:[40.72257, -73.997073]
# 367 location[latitude,longitude]:[40.77958, -73.957862]
# 368 location[latitude,longitude]:[40.7385, -73.9853]
# 369 location[latitude,longitude]:[40.770377, -73.982127]
# 370 location[latitude,longitude]:[40.75906, -73.983681]
# 371 location[latitude,longitude]:[40.689827, -73.99235]
# 372 location[latitude,longitude]:[40.766367, -73.952442]
# 373 location[latitude,longitude]:[40.717302, -73.99898]
# 374 location[latitude,longitude]:[40.642817, -73.788912]
# 375 location[latitude,longitude]:[40.766804, -73.969071]
# 376 location[latitude,longitude]:[40.762317, -73.98593]
# 377 location[latitude,longitude]:[40.734099, -73.999288]
# 378 location[latitude,longitude]:[40.770737, -73.957142]
# 379 location[latitude,longitude]:[40.724919, -73.998967]
# 380 location[latitude,longitude]:[40.729687, -73.998358]
# 381 location[latitude,longitude]:[40.744083, -73.985687]
# 382 location[latitude,longitude]:[40.726413, -73.977196]
# 383 location[latitude,longitude]:[40.794009, -73.966721]
# 384 location[latitude,longitude]:[40.74589, -73.994388]
# 385 location[latitude,longitude]:[40.75284, -73.989232]
# 386 location[latitude,longitude]:[40.777652, -73.959298]
# 387 location[latitude,longitude]:[40.726935, -73.991668]
# 388 location[latitude,longitude]:[40.74969, -73.97751]
# 389 location[latitude,longitude]:[40.709355, -74.016717]
# 390 location[latitude,longitude]:[40.750099, -73.99125]
# 391 location[latitude,longitude]:[40.777513, -73.948801]
# 392 location[latitude,longitude]:[40.64534, -73.77668]
# 393 location[latitude,longitude]:[40.794572, -73.97205]
# 394 location[latitude,longitude]:[40.76084, -73.971439]
# 395 location[latitude,longitude]:[40.758902, -73.979668]
# 396 location[latitude,longitude]:[40.756082, -73.976395]
# 397 location[latitude,longitude]:[40.746631, -73.9819]
# 398 location[latitude,longitude]:[40.787612, -73.977033]
# 399 location[latitude,longitude]:[40.748875, -73.982345]
# 400 location[latitude,longitude]:[0.0, 0.0]
# 401 location[latitude,longitude]:[40.734924, -73.989973]
# 402 location[latitude,longitude]:[40.755682, -73.979288]
# 403 location[latitude,longitude]:[40.757465, -73.963752]
# 404 location[latitude,longitude]:[40.751163, -73.994115]
# 405 location[latitude,longitude]:[40.754707, -73.986173]
# 406 location[latitude,longitude]:[40.768512, -73.965495]
# 407 location[latitude,longitude]:[40.770792, -73.961915]
# 408 location[latitude,longitude]:[40.780672, -73.952653]
# 409 location[latitude,longitude]:[40.733568, -73.995547]
# 410 location[latitude,longitude]:[40.74998, -73.99179]
# 411 location[latitude,longitude]:[40.72235, -73.986202]
# 412 location[latitude,longitude]:[40.77081, -73.956903]
# 413 location[latitude,longitude]:[40.771152, -73.95672]
# 414 location[latitude,longitude]:[40.790777, -73.973482]
# 415 location[latitude,longitude]:[40.716232, -74.013591]
# 416 location[latitude,longitude]:[40.74277, -73.984523]
# 417 location[latitude,longitude]:[40.726791, -73.999842]
# 418 location[latitude,longitude]:[40.774935, -73.963839]
# 419 location[latitude,longitude]:[40.752832, -73.979423]
# 420 location[latitude,longitude]:[40.732783, -73.985831]
# 421 location[latitude,longitude]:[40.75176, -73.986138]
# 422 location[latitude,longitude]:[40.772827, -73.981567]
# 423 location[latitude,longitude]:[40.786305, -73.977741]
# 424 location[latitude,longitude]:[40.71986, -74.01021]
# 425 location[latitude,longitude]:[40.748193, -73.984715]
# 426 location[latitude,longitude]:[40.734642, -73.992515]
# 427 location[latitude,longitude]:[40.758495, -73.98159]
# 428 location[latitude,longitude]:[40.750711, -73.991913]
# 429 location[latitude,longitude]:[40.751085, -73.990382]
# 430 location[latitude,longitude]:[40.696647, -73.99152]
# 431 location[latitude,longitude]:[40.766092, -73.982632]
# 432 location[latitude,longitude]:[40.77293, -73.88525]
# 433 location[latitude,longitude]:[40.644032, -73.790294]
# 434 location[latitude,longitude]:[40.758261, -73.970859]
# 435 location[latitude,longitude]:[40.778392, -73.985658]
# 436 location[latitude,longitude]:[40.758372, -73.963047]
# 437 location[latitude,longitude]:[40.752788, -73.975128]
# 438 location[latitude,longitude]:[40.741972, -74.007642]
# 439 location[latitude,longitude]:[40.764972, -73.977855]
# 440 location[latitude,longitude]:[40.742227, -73.982747]
# 441 location[latitude,longitude]:[40.743594, -73.979374]
# 442 location[latitude,longitude]:[40.774852, -73.961215]
# 443 location[latitude,longitude]:[40.786657, -73.975743]
# 444 location[latitude,longitude]:[40.731236, -74.001455]
# 445 location[latitude,longitude]:[40.724197, -73.978797]
# 446 location[latitude,longitude]:[40.735687, -74.005065]
# 447 location[latitude,longitude]:[40.724007, -73.978812]
# 448 location[latitude,longitude]:[40.751962, -73.993918]
# 449 location[latitude,longitude]:[40.744422, -73.976127]
# 450 location[latitude,longitude]:[40.76944, -73.952025]
# 451 location[latitude,longitude]:[40.755972, -73.972347]
# 452 location[latitude,longitude]:[40.782482, -73.957812]
# 453 location[latitude,longitude]:[40.739142, -74.00807]
# 454 location[latitude,longitude]:[40.752412, -73.977267]
# 455 location[latitude,longitude]:[0.0, 0.0]
# 456 location[latitude,longitude]:[40.771168, -73.963929]
# 457 location[latitude,longitude]:[40.756005, -73.973294]
# 458 location[latitude,longitude]:[40.778415, -73.945392]
# 459 location[latitude,longitude]:[40.766653, -73.957138]
# 460 location[latitude,longitude]:[40.746032, -73.97976]
# 461 location[latitude,longitude]:[40.763352, -73.996385]
# 462 location[latitude,longitude]:[40.755782, -73.983322]
# 463 location[latitude,longitude]:[40.769837, -73.982025]
# 464 location[latitude,longitude]:[40.773009, -73.885269]
# 465 location[latitude,longitude]:[40.799458, -73.968139]
# 466 location[latitude,longitude]:[40.777555, -73.961237]
# 467 location[latitude,longitude]:[40.80409, -73.966942]
# 468 location[latitude,longitude]:[40.713948, -73.951672]
# 469 location[latitude,longitude]:[40.741453, -74.006441]
# 470 location[latitude,longitude]:[40.79858, -73.969018]
# 471 location[latitude,longitude]:[40.721519, -73.956165]
# 472 location[latitude,longitude]:[40.744341, -74.006568]
# 473 location[latitude,longitude]:[40.750106, -73.991395]
# 474 location[latitude,longitude]:[40.815817, -73.958397]
# 475 location[latitude,longitude]:[40.772255, -73.982507]
# 476 location[latitude,longitude]:[40.756412, -73.967363]
# 477 location[latitude,longitude]:[40.729556, -73.99331]
# 478 location[latitude,longitude]:[40.774627, -73.957909]
# 479 location[latitude,longitude]:[40.744418, -73.983521]
# 480 location[latitude,longitude]:[40.795953, -73.970739]
# 481 location[latitude,longitude]:[40.735785, -74.006038]
# 482 location[latitude,longitude]:[40.741275, -73.981362]
# 483 location[latitude,longitude]:[40.759037, -73.968693]
# 484 location[latitude,longitude]:[40.7642, -73.954807]
# 485 location[latitude,longitude]:[40.779383, -73.95955]
# 486 location[latitude,longitude]:[40.72638, -74.002]
# 487 location[latitude,longitude]:[40.716736, -73.997696]
# 488 location[latitude,longitude]:[40.751872, -73.987503]
# 489 location[latitude,longitude]:[40.774462, -73.988552]
# 490 location[latitude,longitude]:[40.748208, -74.005309]
# 491 location[latitude,longitude]:[40.756054, -74.005378]
# 492 location[latitude,longitude]:[40.759193, -73.97723]
# 493 location[latitude,longitude]:[40.7439, -73.999577]
# 494 location[latitude,longitude]:[40.712612, -73.95882]
# 495 location[latitude,longitude]:[40.751285, -73.9712]
# 496 location[latitude,longitude]:[40.75262, -73.98631]
# 497 location[latitude,longitude]:[40.728885, -74.000534]
# 498 location[latitude,longitude]:[40.753302, -73.979382]
# 499 location[latitude,longitude]:[40.759795, -73.968202]
# 500 location[latitude,longitude]:[40.727368, -74.0062]
# 501 location[latitude,longitude]:[40.7595, -73.96904]
# 502 location[latitude,longitude]:[40.751837, -73.970865]
# 503 location[latitude,longitude]:[40.742032, -73.97492]
# 504 location[latitude,longitude]:[40.755123, -73.97283]
# 505 location[latitude,longitude]:[40.726783, -73.980283]
# 506 location[latitude,longitude]:[40.768924, -73.952227]
# 507 location[latitude,longitude]:[40.748232, -73.988848]
# 508 location[latitude,longitude]:[40.70205, -74.011423]
# 509 location[latitude,longitude]:[40.763197, -73.989376]
# 510 location[latitude,longitude]:[40.720794, -74.008509]
# 511 location[latitude,longitude]:[40.760644, -73.984531]
# 512 location[latitude,longitude]:[40.743367, -73.98406]
# 513 location[latitude,longitude]:[40.749792, -74.00267]
# 514 location[latitude,longitude]:[40.754807, -73.97379]
# 515 location[latitude,longitude]:[40.64483, -73.781578]
# 516 location[latitude,longitude]:[40.767759, -73.989694]
# 517 location[latitude,longitude]:[40.762243, -73.96815]
# 518 location[latitude,longitude]:[40.730735, -73.992072]
# 519 location[latitude,longitude]:[40.738672, -73.999515]
# 520 location[latitude,longitude]:[40.774752, -73.980465]
# 521 location[latitude,longitude]:[40.777867, -73.945725]
# 522 location[latitude,longitude]:[40.742502, -74.00424]
# 523 location[latitude,longitude]:[40.76532, -73.97557]
# 524 location[latitude,longitude]:[40.722856, -73.979826]
# 525 location[latitude,longitude]:[40.777252, -73.982625]
# 526 location[latitude,longitude]:[40.740912, -73.985925]
# 527 location[latitude,longitude]:[40.798562, -73.969052]
# 528 location[latitude,longitude]:[40.71422, -74.013452]
# 529 location[latitude,longitude]:[40.748567, -73.972642]
# 530 location[latitude,longitude]:[40.757222, -73.985682]
# 531 location[latitude,longitude]:[40.751325, -73.993982]
# 532 location[latitude,longitude]:[40.729357, -73.991875]
# 533 location[latitude,longitude]:[40.767302, -73.9646]
# 534 location[latitude,longitude]:[40.793391, -73.967215]
# 535 location[latitude,longitude]:[40.642527, -73.791427]
# 536 location[latitude,longitude]:[40.758769, -73.992404]
# 537 location[latitude,longitude]:[40.72184, -73.993307]
# 538 location[latitude,longitude]:[40.721116, -74.004308]
# 539 location[latitude,longitude]:[40.75085, -74.00562]
# 540 location[latitude,longitude]:[40.701535, -74.012503]
# 541 location[latitude,longitude]:[40.76495, -73.968502]
# 542 location[latitude,longitude]:[0.0, 0.0]
# 543 location[latitude,longitude]:[40.74892, -73.97797]
# 544 location[latitude,longitude]:[40.77908, -73.98498]
# 545 location[latitude,longitude]:[40.646587, -73.78582]
# 546 location[latitude,longitude]:[40.739812, -74.00549]
# 547 location[latitude,longitude]:[40.728841, -73.99404]
# 548 location[latitude,longitude]:[40.752327, -73.97917]
# 549 location[latitude,longitude]:[40.732893, -73.974918]
# 550 location[latitude,longitude]:[40.769041, -73.988708]
# 551 location[latitude,longitude]:[40.782595, -73.953385]
# 552 location[latitude,longitude]:[40.744757, -73.984962]
# 553 location[latitude,longitude]:[40.752422, -73.98375]
# 554 location[latitude,longitude]:[40.760963, -73.975273]
# 555 location[latitude,longitude]:[40.68118, -73.980602]
# 556 location[latitude,longitude]:[40.758312, -73.97752]
# 557 location[latitude,longitude]:[40.71897, -73.997061]
# 558 location[latitude,longitude]:[40.723912, -73.991242]
# 559 location[latitude,longitude]:[40.756415, -73.975227]
# 560 location[latitude,longitude]:[40.751115, -73.994153]
# 561 location[latitude,longitude]:[40.785935, -73.979897]
# 562 location[latitude,longitude]:[40.760434, -74.002849]
# 563 location[latitude,longitude]:[40.71597, -74.015138]
# 564 location[latitude,longitude]:[40.76767, -73.96166]
# 565 location[latitude,longitude]:[40.771907, -73.95626]
# 566 location[latitude,longitude]:[40.778537, -73.981967]
# 567 location[latitude,longitude]:[40.73111, -74.00658]
# 568 location[latitude,longitude]:[40.755756, -73.884413]
# 569 location[latitude,longitude]:[40.791595, -73.968651]
# 570 location[latitude,longitude]:[40.750117, -74.002532]
# 571 location[latitude,longitude]:[40.71242, -74.00953]
# 572 location[latitude,longitude]:[40.761311, -73.972672]
# 573 location[latitude,longitude]:[40.71592, -74.015208]
# 574 location[latitude,longitude]:[40.712097, -73.94075]
# 575 location[latitude,longitude]:[40.729574, -73.991874]
# 576 location[latitude,longitude]:[40.75377, -73.969407]
# 577 location[latitude,longitude]:[40.72269, -73.9992]
# 578 location[latitude,longitude]:[40.722982, -73.982842]
# 579 location[latitude,longitude]:[40.773595, -73.870591]
# 580 location[latitude,longitude]:[40.767875, -73.98311]
# 581 location[latitude,longitude]:[40.768197, -73.952871]
# 582 location[latitude,longitude]:[40.745547, -73.998795]
# 583 location[latitude,longitude]:[40.768712, -73.963437]
# 584 location[latitude,longitude]:[40.757889, -73.968702]
# 585 location[latitude,longitude]:[40.72067, -74.009983]
# 586 location[latitude,longitude]:[40.763362, -73.971497]
# 587 location[latitude,longitude]:[40.75185, -73.97495]
# 588 location[latitude,longitude]:[40.73385, -74.0027]
# 589 location[latitude,longitude]:[40.768718, -73.96833]
# 590 location[latitude,longitude]:[40.787222, -73.971638]
# 591 location[latitude,longitude]:[40.782367, -73.97884]
# 592 location[latitude,longitude]:[40.751801, -73.933138]
# 593 location[latitude,longitude]:[40.756307, -73.991625]
# 594 location[latitude,longitude]:[40.755034, -73.974168]
# 595 location[latitude,longitude]:[40.712003, -73.945566]
# 596 location[latitude,longitude]:[40.750283, -73.994667]
# 597 location[latitude,longitude]:[40.740555, -73.994539]
# 598 location[latitude,longitude]:[40.798792, -73.963192]
# 599 location[latitude,longitude]:[40.715947, -74.016737]
# 600 location[latitude,longitude]:[40.70746, -74.004712]
# 601 location[latitude,longitude]:[40.76306, -73.996785]
# 602 location[latitude,longitude]:[40.707022, -74.013361]
# 603 location[latitude,longitude]:[40.760955, -73.969252]
# 604 location[latitude,longitude]:[40.758719, -74.000013]
# 605 location[latitude,longitude]:[40.763425, -73.989107]
# 606 location[latitude,longitude]:[40.743667, -73.983815]
# 607 location[latitude,longitude]:[40.743297, -73.98832]
# 608 location[latitude,longitude]:[40.748887, -73.992042]
# 609 location[latitude,longitude]:[40.74506, -73.99125]
# 610 location[latitude,longitude]:[40.783298, -73.955095]
# 611 location[latitude,longitude]:[40.79338, -73.967217]
# 612 location[latitude,longitude]:[40.759725, -73.973278]
# 613 location[latitude,longitude]:[40.789342, -73.948455]
# 614 location[latitude,longitude]:[40.717302, -73.994352]
# 615 location[latitude,longitude]:[40.759305, -73.986923]
# 616 location[latitude,longitude]:[40.75966, -73.96785]
# 617 location[latitude,longitude]:[40.763645, -73.985125]
# 618 location[latitude,longitude]:[40.75375, -73.99242]
# 619 location[latitude,longitude]:[40.754554, -73.993513]
# 620 location[latitude,longitude]:[40.733659, -74.002772]
# 621 location[latitude,longitude]:[40.747263, -73.974266]
# 622 location[latitude,longitude]:[0.0, 0.0]
# 623 location[latitude,longitude]:[40.789094, -73.975968]
# 624 location[latitude,longitude]:[40.77409, -73.87317]
# 625 location[latitude,longitude]:[40.744275, -74.006706]
# 626 location[latitude,longitude]:[40.739702, -74.006372]
# 627 location[latitude,longitude]:[40.75873, -73.99349]
# 628 location[latitude,longitude]:[40.749452, -73.991202]
# 629 location[latitude,longitude]:[40.754753, -73.968547]
# 630 location[latitude,longitude]:[40.751248, -73.994112]
# 631 location[latitude,longitude]:[40.709411, -74.01484]
# 632 location[latitude,longitude]:[40.783943, -73.977602]
# 633 location[latitude,longitude]:[40.754177, -73.995672]
# 634 location[latitude,longitude]:[40.762551, -73.968469]
# 635 location[latitude,longitude]:[40.709595, -74.006713]
# 636 location[latitude,longitude]:[40.75531, -73.979295]
# 637 location[latitude,longitude]:[40.744349, -73.985564]
# 638 location[latitude,longitude]:[40.767895, -73.981112]
# 639 location[latitude,longitude]:[40.754248, -73.972058]
# 640 location[latitude,longitude]:[40.754852, -73.968343]
# 641 location[latitude,longitude]:[40.774487, -73.872417]
# 642 location[latitude,longitude]:[40.779426, -73.977379]
# 643 location[latitude,longitude]:[40.767777, -73.955538]
# 644 location[latitude,longitude]:[40.77365, -73.870572]
# 645 location[latitude,longitude]:[40.750417, -73.994658]
# 646 location[latitude,longitude]:[40.737117, -73.988687]
# 647 location[latitude,longitude]:[40.738447, -74.003779]
# 648 location[latitude,longitude]:[40.75681, -73.96498]
# 649 location[latitude,longitude]:[40.788362, -73.978052]
# 650 location[latitude,longitude]:[40.742219, -73.994123]
# 651 location[latitude,longitude]:[40.747881, -73.993024]
# 652 location[latitude,longitude]:[40.763835, -73.915012]
# 653 location[latitude,longitude]:[40.778885, -73.958245]
# 654 location[latitude,longitude]:[40.76556, -73.983765]
# 655 location[latitude,longitude]:[40.745032, -73.995287]
# 656 location[latitude,longitude]:[40.736197, -73.981978]
# 657 location[latitude,longitude]:[40.758157, -73.968752]
# 658 location[latitude,longitude]:[40.719997, -73.99825]
# 659 location[latitude,longitude]:[40.752447, -73.970462]
# 660 location[latitude,longitude]:[40.714814, -74.016124]
# 661 location[latitude,longitude]:[40.754756, -73.984038]
# 662 location[latitude,longitude]:[40.799892, -73.969787]
# 663 location[latitude,longitude]:[40.759859, -73.973301]
# 664 location[latitude,longitude]:[40.689592, -73.992087]
# 665 location[latitude,longitude]:[40.776253, -73.962066]
# 666 location[latitude,longitude]:[40.749577, -73.992082]
# 667 location[latitude,longitude]:[40.777566, -73.950919]
# 668 location[latitude,longitude]:[40.749747, -73.991562]
# 669 location[latitude,longitude]:[40.742145, -73.984962]
# 670 location[latitude,longitude]:[40.746859, -73.988366]
# 671 location[latitude,longitude]:[40.7699, -73.984203]
# 672 location[latitude,longitude]:[40.737429, -73.987573]
# 673 location[latitude,longitude]:[40.76952, -73.99197]
# 674 location[latitude,longitude]:[40.7169, -74.0127]
# 675 location[latitude,longitude]:[40.718208, -73.986443]
# 676 location[latitude,longitude]:[40.775985, -73.947142]
# 677 location[latitude,longitude]:[40.774893, -73.988128]
# 678 location[latitude,longitude]:[40.750512, -73.98313]
# 679 location[latitude,longitude]:[40.73824, -73.993005]
# 680 location[latitude,longitude]:[40.749935, -73.979155]
# 681 location[latitude,longitude]:[40.759445, -73.995501]
# 682 location[latitude,longitude]:[40.725862, -73.997705]
# 683 location[latitude,longitude]:[40.720402, -73.99803]
# 684 location[latitude,longitude]:[40.725668, -73.996852]
# 685 location[latitude,longitude]:[40.761712, -73.972542]
# 686 location[latitude,longitude]:[40.767342, -73.954357]
# 687 location[latitude,longitude]:[40.751985, -73.993582]
# 688 location[latitude,longitude]:[40.725807, -73.992454]
# 689 location[latitude,longitude]:[40.798907, -73.959587]
# 690 location[latitude,longitude]:[40.763502, -73.96952]
# 691 location[latitude,longitude]:[40.76514, -73.886932]
# 692 location[latitude,longitude]:[40.725613, -74.003947]
# 693 location[latitude,longitude]:[40.787654, -73.952104]
# 694 location[latitude,longitude]:[40.749559, -73.975903]
# 695 location[latitude,longitude]:[40.746946, -73.99348]
# 696 location[latitude,longitude]:[40.750173, -73.986297]
# 697 location[latitude,longitude]:[40.743896, -73.971551]
# 698 location[latitude,longitude]:[40.767159, -73.986233]
# 699 location[latitude,longitude]:[40.777596, -73.98351]
# 700 location[latitude,longitude]:[40.74933, -73.97076]
# 701 location[latitude,longitude]:[40.758162, -73.992067]
# 702 location[latitude,longitude]:[40.75726, -73.97158]
# 703 location[latitude,longitude]:[40.752815, -73.989645]
# 704 location[latitude,longitude]:[40.734912, -73.99062]
# 705 location[latitude,longitude]:[40.76102, -73.967407]
# 706 location[latitude,longitude]:[40.704517, -74.008685]
# 707 location[latitude,longitude]:[40.760057, -73.968163]
# 708 location[latitude,longitude]:[40.80307, -73.967911]
# 709 location[latitude,longitude]:[40.755706, -73.975209]
# 710 location[latitude,longitude]:[40.774172, -73.959412]
# 711 location[latitude,longitude]:[40.757185, -73.99723]
# 712 location[latitude,longitude]:[40.750685, -74.002108]
# 713 location[latitude,longitude]:[40.75321, -73.996418]
# 714 location[latitude,longitude]:[40.771724, -73.981772]
# 715 location[latitude,longitude]:[40.72224, -74.00319]
# 716 location[latitude,longitude]:[40.765242, -73.960702]
# 717 location[latitude,longitude]:[40.776315, -73.952995]
# 718 location[latitude,longitude]:[40.761082, -73.961535]
# 719 location[latitude,longitude]:[40.76559, -73.98198]
# 720 location[latitude,longitude]:[40.719963, -73.987997]
# 721 location[latitude,longitude]:[40.732639, -73.986721]
# 722 location[latitude,longitude]:[40.718726, -73.992612]
# 723 location[latitude,longitude]:[40.774015, -73.961737]
# 724 location[latitude,longitude]:[40.750555, -73.991287]
# 725 location[latitude,longitude]:[40.741115, -74.00577]
# 726 location[latitude,longitude]:[40.727002, -73.994739]
# 727 location[latitude,longitude]:[40.77177, -73.98188]
# 728 location[latitude,longitude]:[40.753392, -73.966885]
# 729 location[latitude,longitude]:[40.764207, -73.9772]
# 730 location[latitude,longitude]:[0.0, 0.0]
# 731 location[latitude,longitude]:[40.774341, -73.963669]
# 732 location[latitude,longitude]:[40.756705, -73.97462]
# 733 location[latitude,longitude]:[40.728314, -74.007189]
# 734 location[latitude,longitude]:[40.73845, -74.003702]
# 735 location[latitude,longitude]:[40.763247, -73.97241]
# 736 location[latitude,longitude]:[40.741825, -74.004707]
# 737 location[latitude,longitude]:[40.7649, -73.9612]
# 738 location[latitude,longitude]:[40.744682, -73.978817]
# 739 location[latitude,longitude]:[40.717487, -73.99113]
# 740 location[latitude,longitude]:[40.729872, -74.002195]
# 741 location[latitude,longitude]:[40.745205, -73.982578]
# 742 location[latitude,longitude]:[40.773118, -73.885322]
# 743 location[latitude,longitude]:[40.744085, -73.981935]
# 744 location[latitude,longitude]:[40.800642, -73.967692]
# 745 location[latitude,longitude]:[40.770492, -73.966807]
# 746 location[latitude,longitude]:[40.751325, -73.978132]
# 747 location[latitude,longitude]:[40.764456, -73.976194]
# 748 location[latitude,longitude]:[40.763968, -73.979264]
# 749 location[latitude,longitude]:[40.745711, -74.008496]
# 750 location[latitude,longitude]:[40.78232, -73.951423]
# 751 location[latitude,longitude]:[40.722958, -73.987498]
# 752 location[latitude,longitude]:[40.690387, -74.177668]
# 753 location[latitude,longitude]:[40.761305, -73.989083]
# 754 location[latitude,longitude]:[40.754549, -73.993151]
# 755 location[latitude,longitude]:[40.77408, -73.874527]
# 756 location[latitude,longitude]:[40.735602, -73.98864]
# 757 location[latitude,longitude]:[40.772117, -73.982692]
# 758 location[latitude,longitude]:[40.736892, -73.98462]
# 759 location[latitude,longitude]:[40.705808, -74.006866]
# 760 location[latitude,longitude]:[40.797627, -73.960347]
# 761 location[latitude,longitude]:[40.745217, -73.978587]
# 762 location[latitude,longitude]:[40.776247, -73.94696]
# 763 location[latitude,longitude]:[40.780255, -73.9876]
# 764 location[latitude,longitude]:[40.77277, -73.982488]
# 765 location[latitude,longitude]:[40.772207, -73.94992]
# 766 location[latitude,longitude]:[40.758277, -73.937715]
# 767 location[latitude,longitude]:[40.721757, -73.99204]
# 768 location[latitude,longitude]:[40.74909, -73.970552]
# 769 location[latitude,longitude]:[40.753807, -73.979327]
# 770 location[latitude,longitude]:[40.771288, -73.98333]
# 771 location[latitude,longitude]:[40.715183, -74.009752]
# 772 location[latitude,longitude]:[40.77827, -73.982238]
# 773 location[latitude,longitude]:[40.774696, -73.982317]
# 774 location[latitude,longitude]:[40.74408, -73.984265]
# 775 location[latitude,longitude]:[40.720975, -73.993653]
# 776 location[latitude,longitude]:[40.73918, -73.98305]
# 777 location[latitude,longitude]:[40.764142, -73.95442]
# 778 location[latitude,longitude]:[40.725785, -73.996472]
# 779 location[latitude,longitude]:[40.773538, -73.98794]
# 780 location[latitude,longitude]:[40.726065, -73.989278]
# 781 location[latitude,longitude]:[40.728097, -73.986215]
# 782 location[latitude,longitude]:[40.745012, -73.978387]
# 783 location[latitude,longitude]:[40.774312, -73.989205]
# 784 location[latitude,longitude]:[40.761926, -73.958256]
# 785 location[latitude,longitude]:[40.7297, -73.99328]
# 786 location[latitude,longitude]:[40.76393, -73.97328]
# 787 location[latitude,longitude]:[40.78277, -73.948383]
# 788 location[latitude,longitude]:[40.759347, -73.981522]
# 789 location[latitude,longitude]:[40.725635, -73.996771]
# 790 location[latitude,longitude]:[40.751109, -73.980176]
# 791 location[latitude,longitude]:[40.73672, -74.001152]
# 792 location[latitude,longitude]:[40.74207, -74.00089]
# 793 location[latitude,longitude]:[40.75857, -73.992855]
# 794 location[latitude,longitude]:[40.727227, -73.996435]
# 795 location[latitude,longitude]:[40.741078, -73.9899]
# 796 location[latitude,longitude]:[40.748019, -73.98097]
# 797 location[latitude,longitude]:[40.762081, -73.978908]
# 798 location[latitude,longitude]:[40.746683, -73.979712]
# 799 location[latitude,longitude]:[40.75576, -73.98858]
# 800 location[latitude,longitude]:[40.737382, -73.997073]
# 801 location[latitude,longitude]:[40.773777, -73.870957]
# 802 location[latitude,longitude]:[40.762767, -73.982293]
# 803 location[latitude,longitude]:[40.788335, -73.97625]
# 804 location[latitude,longitude]:[40.708292, -73.939932]
# 805 location[latitude,longitude]:[40.737012, -73.99704]
# 806 location[latitude,longitude]:[40.785612, -73.951147]
# 807 location[latitude,longitude]:[40.763332, -73.965163]
# 808 location[latitude,longitude]:[40.757283, -73.984915]
# 809 location[latitude,longitude]:[40.769862, -73.962567]
# 810 location[latitude,longitude]:[40.763994, -73.973275]
# 811 location[latitude,longitude]:[40.719707, -74.001687]
# 812 location[latitude,longitude]:[40.763028, -73.959639]
# 813 location[latitude,longitude]:[40.780782, -73.958628]
# 814 location[latitude,longitude]:[40.756066, -73.980939]
# 815 location[latitude,longitude]:[40.79712, -73.964465]
# 816 location[latitude,longitude]:[40.772652, -73.885138]
# 817 location[latitude,longitude]:[40.782582, -73.951088]
# 818 location[latitude,longitude]:[40.754822, -73.971017]
# 819 location[latitude,longitude]:[40.722532, -73.987428]
# 820 location[latitude,longitude]:[40.760442, -73.980648]
# 821 location[latitude,longitude]:[40.764282, -73.984948]
# 822 location[latitude,longitude]:[40.746333, -73.978038]
# 823 location[latitude,longitude]:[40.770377, -73.987478]
# 824 location[latitude,longitude]:[40.763152, -73.962962]
# 825 location[latitude,longitude]:[40.75781, -73.975233]
# 826 location[latitude,longitude]:[40.745593, -73.986817]
# 827 location[latitude,longitude]:[40.783545, -73.954963]
# 828 location[latitude,longitude]:[40.757605, -73.97543]
# 829 location[latitude,longitude]:[40.75899, -73.973248]
# 830 location[latitude,longitude]:[40.713662, -74.008577]
# 831 location[latitude,longitude]:[40.776252, -73.958072]
# 832 location[latitude,longitude]:[40.764, -73.97666]
# 833 location[latitude,longitude]:[40.74787, -74.003975]
# 834 location[latitude,longitude]:[40.748717, -73.992417]
# 835 location[latitude,longitude]:[40.771905, -73.965624]
# 836 location[latitude,longitude]:[40.783138, -73.947885]
# 837 location[latitude,longitude]:[40.75708, -73.96923]
# 838 location[latitude,longitude]:[40.848462, -73.937645]
# 839 location[latitude,longitude]:[40.744697, -73.98626]
# 840 location[latitude,longitude]:[40.768147, -73.968142]
# 841 location[latitude,longitude]:[40.741328, -73.989642]
# 842 location[latitude,longitude]:[40.77847, -73.98185]
# 843 location[latitude,longitude]:[40.782873, -73.948122]
# 844 location[latitude,longitude]:[40.78711, -73.954356]
# 845 location[latitude,longitude]:[40.762862, -73.985855]
# 846 location[latitude,longitude]:[40.78579, -73.976302]
# 847 location[latitude,longitude]:[40.782512, -73.95305]
# 848 location[latitude,longitude]:[40.771552, -73.953405]
# 849 location[latitude,longitude]:[40.759172, -73.968517]
# 850 location[latitude,longitude]:[40.740622, -74.007735]
# 851 location[latitude,longitude]:[40.750938, -73.974878]
# 852 location[latitude,longitude]:[40.77435, -73.963497]
# 853 location[latitude,longitude]:[40.77831, -73.9454]
# 854 location[latitude,longitude]:[40.760477, -73.998625]
# 855 location[latitude,longitude]:[40.77338, -73.954888]
# 856 location[latitude,longitude]:[40.760643, -73.962616]
# 857 location[latitude,longitude]:[40.68703, -73.98489]
# 858 location[latitude,longitude]:[40.77164, -73.98298]
# 859 location[latitude,longitude]:[40.764902, -73.97692]
# 860 location[latitude,longitude]:[40.767331, -73.962998]
# 861 location[latitude,longitude]:[40.77919, -73.954987]
# 862 location[latitude,longitude]:[40.763407, -73.974485]
# 863 location[latitude,longitude]:[40.751124, -73.975967]
# 864 location[latitude,longitude]:[40.73599, -74.000955]
# 865 location[latitude,longitude]:[40.761058, -73.985524]
# 866 location[latitude,longitude]:[40.745909, -73.998101]
# 867 location[latitude,longitude]:[40.744849, -73.991395]
# 868 location[latitude,longitude]:[40.750342, -73.994657]
# 869 location[latitude,longitude]:[40.763665, -73.986105]
# 870 location[latitude,longitude]:[40.765862, -73.9606]
# 871 location[latitude,longitude]:[40.75729, -73.98991]
# 872 location[latitude,longitude]:[40.763148, -73.979234]
# 873 location[latitude,longitude]:[40.70626, -74.004265]
# 874 location[latitude,longitude]:[40.782011, -73.956252]
# 875 location[latitude,longitude]:[40.671487, -73.984354]
# 876 location[latitude,longitude]:[40.753034, -73.989329]
# 877 location[latitude,longitude]:[40.744997, -73.981732]
# 878 location[latitude,longitude]:[40.721882, -73.989213]
# 879 location[latitude,longitude]:[40.752342, -73.974746]
# 880 location[latitude,longitude]:[40.709415, -74.008147]
# 881 location[latitude,longitude]:[40.755637, -73.96482]
# 882 location[latitude,longitude]:[40.780847, -73.981522]
# 883 location[latitude,longitude]:[40.73668, -73.995368]
# 884 location[latitude,longitude]:[40.707517, -74.004445]
# 885 location[latitude,longitude]:[40.73706, -73.99012]
# 886 location[latitude,longitude]:[40.769119, -73.987085]
# 887 location[latitude,longitude]:[40.750492, -73.99465]
# 888 location[latitude,longitude]:[40.779416, -73.957448]
# 889 location[latitude,longitude]:[40.779454, -73.961831]
# 890 location[latitude,longitude]:[40.773952, -73.871235]
# 891 location[latitude,longitude]:[40.756805, -73.990317]
# 892 location[latitude,longitude]:[40.766251, -73.98011]
# 893 location[latitude,longitude]:[40.747098, -73.98622]
# 894 location[latitude,longitude]:[40.774347, -73.963485]
# 895 location[latitude,longitude]:[40.73735, -73.988662]
# 896 location[latitude,longitude]:[40.755507, -73.976157]
# 897 location[latitude,longitude]:[0.0, 0.0]
# 898 location[latitude,longitude]:[40.77734, -73.978578]
# 899 location[latitude,longitude]:[40.730313, -74.00019]
# 900 location[latitude,longitude]:[40.770965, -73.964002]
# 901 location[latitude,longitude]:[40.747897, -74.003746]
# 902 location[latitude,longitude]:[40.743013, -73.992796]
# 903 location[latitude,longitude]:[40.757036, -73.976146]
# 904 location[latitude,longitude]:[40.75083, -73.990808]
# 905 location[latitude,longitude]:[40.747865, -73.99322]
# 906 location[latitude,longitude]:[40.758215, -73.937667]
# 907 location[latitude,longitude]:[40.750687, -73.943522]
# 908 location[latitude,longitude]:[40.734432, -73.99974]
# 909 location[latitude,longitude]:[40.766799, -73.983307]
# 910 location[latitude,longitude]:[40.752133, -74.004754]
# 911 location[latitude,longitude]:[40.719627, -74.00689]
# 912 location[latitude,longitude]:[40.77012, -73.86361]
# 913 location[latitude,longitude]:[40.753714, -73.992042]
# 914 location[latitude,longitude]:[40.779378, -73.97747]
# 915 location[latitude,longitude]:[40.764967, -73.989047]
# 916 location[latitude,longitude]:[40.724772, -73.990509]
# 917 location[latitude,longitude]:[40.734817, -73.990455]
# 918 location[latitude,longitude]:[40.751752, -73.990012]
# 919 location[latitude,longitude]:[40.756564, -73.994046]
# 920 location[latitude,longitude]:[40.742736, -74.000354]
# 921 location[latitude,longitude]:[0.0, 0.0]
# 922 location[latitude,longitude]:[40.741672, -74.004627]
# 923 location[latitude,longitude]:[40.72597, -73.99738]
# 924 location[latitude,longitude]:[40.743772, -73.992388]
# 925 location[latitude,longitude]:[40.71032, -74.009677]
# 926 location[latitude,longitude]:[40.710885, -74.010269]
# 927 location[latitude,longitude]:[40.768567, -73.969685]
# 928 location[latitude,longitude]:[40.755322, -73.987748]
# 929 location[latitude,longitude]:[40.750872, -73.993015]
# 930 location[latitude,longitude]:[40.691887, -73.982322]
# 931 location[latitude,longitude]:[40.753002, -73.996735]
# 932 location[latitude,longitude]:[40.765657, -73.970445]
# 933 location[latitude,longitude]:[40.718429, -73.987265]
# 934 location[latitude,longitude]:[40.75261, -73.978503]
# 935 location[latitude,longitude]:[40.774841, -73.963199]
# 936 location[latitude,longitude]:[40.820267, -73.955068]
# 937 location[latitude,longitude]:[40.749905, -73.995245]
# 938 location[latitude,longitude]:[40.790222, -73.976825]
# 939 location[latitude,longitude]:[40.751243, -73.993928]
# 940 location[latitude,longitude]:[40.769372, -73.984837]
# 941 location[latitude,longitude]:[40.802452, -73.9623]
# 942 location[latitude,longitude]:[40.740012, -73.99121]
# 943 location[latitude,longitude]:[40.724477, -73.98706]
# 944 location[latitude,longitude]:[40.649679, -73.804526]
# 945 location[latitude,longitude]:[40.763434, -73.965213]
# 946 location[latitude,longitude]:[40.813836, -73.936919]
# 947 location[latitude,longitude]:[40.748613, -73.983003]
# 948 location[latitude,longitude]:[40.756067, -73.990297]
# 949 location[latitude,longitude]:[40.751127, -73.993905]
# 950 location[latitude,longitude]:[40.757541, -73.974641]
# 951 location[latitude,longitude]:[40.783417, -73.951313]
# 952 location[latitude,longitude]:[40.755617, -73.962448]
# 953 location[latitude,longitude]:[40.770837, -73.991015]
# 954 location[latitude,longitude]:[40.770932, -73.86622]
# 955 location[latitude,longitude]:[40.742625, -73.995955]
# 956 location[latitude,longitude]:[40.767386, -73.98615]
# 957 location[latitude,longitude]:[40.729417, -73.98997]
# 958 location[latitude,longitude]:[0.0, 0.0]
# 959 location[latitude,longitude]:[40.76026, -73.97671]
# 960 location[latitude,longitude]:[40.748453, -73.973209]
# 961 location[latitude,longitude]:[40.763605, -73.98895]
# 962 location[latitude,longitude]:[40.735872, -74.006705]
# 963 location[latitude,longitude]:[40.761363, -73.969672]
# 964 location[latitude,longitude]:[40.661145, -73.997122]
# 965 location[latitude,longitude]:[40.748542, -73.987952]
# 966 location[latitude,longitude]:[40.781112, -73.954135]
# 967 location[latitude,longitude]:[40.762465, -73.957122]
# 968 location[latitude,longitude]:[40.74805, -74.00412]
# 969 location[latitude,longitude]:[40.780242, -73.959577]
# 970 location[latitude,longitude]:[40.764726, -73.976783]
# 971 location[latitude,longitude]:[40.733294, -74.002744]
# 972 location[latitude,longitude]:[40.74976, -73.993847]
# 973 location[latitude,longitude]:[40.753168, -73.969728]
# 974 location[latitude,longitude]:[40.764099, -73.973033]
# 975 location[latitude,longitude]:[40.796757, -73.970537]
# 976 location[latitude,longitude]:[40.765015, -73.976836]
# 977 location[latitude,longitude]:[40.722397, -73.988933]
# 978 location[latitude,longitude]:[40.784722, -73.958018]
# 979 location[latitude,longitude]:[40.734082, -74.006202]
# 980 location[latitude,longitude]:[40.74772, -73.98274]
# 981 location[latitude,longitude]:[40.774329, -73.988897]
# 982 location[latitude,longitude]:[40.742366, -73.99317]
# 983 location[latitude,longitude]:[40.739342, -74.001677]
# 984 location[latitude,longitude]:[40.756363, -73.985773]
# 985 location[latitude,longitude]:[40.738254, -73.983499]
# 986 location[latitude,longitude]:[40.735046, -73.990119]
# 987 location[latitude,longitude]:[40.755857, -73.997045]
# 988 location[latitude,longitude]:[40.772357, -73.960927]
# 989 location[latitude,longitude]:[40.775272, -73.95043]
# 990 location[latitude,longitude]:[40.763642, -73.988995]
# 991 location[latitude,longitude]:[40.768787, -73.862845]
# 992 location[latitude,longitude]:[40.772327, -73.952635]
# 993 location[latitude,longitude]:[40.750617, -73.97391]
# 994 location[latitude,longitude]:[40.74049, -73.998152]
# 995 location[latitude,longitude]:[40.759067, -73.977369]
# 996 location[latitude,longitude]:[40.762444, -73.98244]
# 997 location[latitude,longitude]:[40.774087, -73.874592]
# 998 location[latitude,longitude]:[40.781736, -73.981283]
# 999 location[latitude,longitude]:[40.757812, -73.989042]
# 1000 location[latitude,longitude]:[40.787172, -73.97763]

# %%
cleaned_trips[0:4]
# Out:
# [{'pickup_latitude': 40.64499,
#   'pickup_longitude': -73.78115,
#   'trip_distance': 18.38},
#  {'pickup_latitude': 40.766931,
#   'pickup_longitude': -73.982098,
#   'trip_distance': 1.3},
#  {'pickup_latitude': 40.77773,
#   'pickup_longitude': -73.951902,
#   'trip_distance': 4.5},
#  {'pickup_latitude': 40.795678,
#   'pickup_longitude': -73.971049,
#   'trip_distance': 2.4}]

# %%
trip_markers and len(trip_markers) # 1000
print(len(trip_markers))
list(map(lambda marker: marker.location, trip_markers[0:4]))
# [[40.64499, -73.78115],
#  [40.766931, -73.982098],
#  [40.77773, -73.951902],
#  [40.795678, -73.971049]]
# Out:
# 1000
# [[40.64499, -73.78115],
#  [40.766931, -73.982098],
#  [40.77773, -73.951902],
#  [40.795678, -73.971049]]

# %% [markdown]
# Ok, now that we have a function that creates locations, and a function that creates markers, it is time to write a function to plot a map.
#
# Write a function called `map_from` that, provided the first argument of a list location and second argument an integer representing the `zoom_start`, returns a `folium` map the corresponding location and `zoom_start` attributes.
#
# > Hint: The following is how to write a map with folium:
# > ```python
#     folium.Map(location=location, zoom_start=zoom_amount)
# > ```

# %%
def map_from(location, zoom_amount):
    location_map = folium.Map(location, zoom_start=zoom_amount)
    return location_map
    pass

# %%
times_square_map = map_from([40.7589, -73.9851], 15)
print(times_square_map.location)
times_square_map and times_square_map.location # [40.7589, -73.9851]
#times_square_map and times_square_map.zoom_start # 15
# Out:
# [40.7589, -73.9851]
# [40.7589, -73.9851]

# %%
times_square_marker and times_square_marker.add_to(times_square_map)
times_square_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Now that we have a marker and a map, now let's write a function that adds a lot of markers to a map.  This function should add each marker in the list to the map object then return the updated map object.

# %%
manhattan_map = map_from([40.7589, -73.9851], 13)

# %%
def add_markers(markers, map_obj):
    counter = 0
    for marker in markers:
        counter += 1
        #print("location:"+str(marker.location))
        location_map = map_from(marker.location, zoom_amount=15)
        if counter%25 == 0:
            print(str(counter)+" location:"+str(location_map.location))
        location_map.add_to(map_obj)
    return map_obj
    pass

# %%
map_with_markers = add_markers(trip_markers, manhattan_map)
# Out:
# 25 location:[40.754789, -73.973606]
# 50 location:[40.741249, -74.005201]
# 75 location:[40.750722, -73.968447]
# 100 location:[40.74964, -73.972212]
# 125 location:[40.767446, -73.984105]
# 150 location:[40.753632, -73.988899]
# 175 location:[40.75331, -73.968992]
# 200 location:[40.759825, -73.970231]
# 225 location:[40.771385, -73.96467]
# 250 location:[40.702557, -73.93467]
# 275 location:[40.645322, -73.776652]
# 300 location:[40.746142, -73.984852]
# 325 location:[40.758985, -73.989435]
# 350 location:[40.659956, -73.99842]
# 375 location:[40.766804, -73.969071]
# 400 location:[0.0, 0.0]
# 425 location:[40.748193, -73.984715]
# 450 location:[40.76944, -73.952025]
# 475 location:[40.772255, -73.982507]
# 500 location:[40.727368, -74.0062]
# 525 location:[40.777252, -73.982625]
# 550 location:[40.769041, -73.988708]
# 575 location:[40.729574, -73.991874]
# 600 location:[40.70746, -74.004712]
# 625 location:[40.744275, -74.006706]
# 650 location:[40.742219, -73.994123]
# 675 location:[40.718208, -73.986443]
# 700 location:[40.74933, -73.97076]
# 725 location:[40.741115, -74.00577]
# 750 location:[40.78232, -73.951423]
# 775 location:[40.720975, -73.993653]
# 800 location:[40.737382, -73.997073]
# 825 location:[40.75781, -73.975233]
# 850 location:[40.740622, -74.007735]
# 875 location:[40.671487, -73.984354]
# 900 location:[40.770965, -73.964002]
# 925 location:[40.71032, -74.009677]
# 950 location:[40.757541, -73.974641]
# 975 location:[40.796757, -73.970537]
# 1000 location:[40.787172, -73.97763]

# %%
map_with_markers

# %% [markdown]
# ### Using Nearest Neighbors

# %% [markdown]
# Ok, let's write a function that given a latitude and longitude will predict the distance for us.  We'll do this by first finding the nearest trips given a latitude and longitude.

# %% [markdown]
# Here we once again apply the nearest neighbors formula. As a first step, write a function named `distance_location` that calculates the distance in pickup location between two trips.

# %%
import math

def distance_location(selected_trip, neighbor_trip):
    return math.sqrt(pow(selected_trip['pickup_latitude']-neighbor_trip['pickup_latitude'],2)+pow(selected_trip['pickup_longitude']-neighbor_trip['pickup_longitude'],2))
    pass

# %%
first_trip = {'pickup_latitude': 40.64499, 'pickup_longitude': -73.78115, 'trip_distance': 18.38}
second_trip = {'pickup_latitude': 40.766931, 'pickup_longitude': -73.982098, 'trip_distance': 1.3}
distance_first_and_second = distance_location(first_trip, second_trip)

print(round(distance_first_and_second, 5))
distance_first_and_second and round(distance_first_and_second, 3) # 0.235

# %% [markdown]
# Ok, next write a function called `distance_between_neighbors` that adds a new key-value pair, called `distance_from_selected`, that calculates the distance of the `neighbor_trip` from the `selected_trip`.

# %%
def distance_between_neighbors(selected_trip, neighbor_trip):
    neighbor_trip_renew = dict()
    neighbor_trip_clone = neighbor_trip.copy()
    neighbor_trip_clone['distance_from_selected'] = distance_location(selected_trip, neighbor_trip)
    neighbor_trip_order = sorted(neighbor_trip_clone.keys(), key = lambda k:k.lower())
    for i in neighbor_trip_order:
        values = neighbor_trip_clone[i] # retrieve corresponding value to one given key from original dictionary
        #print(i+":"+str(values))
        #neighbor_trip_renew[i] = values        # method 1
        neighbor_trip_renew.update({i:values})  # method 2
        
    return neighbor_trip_renew
    pass

# %%
distance_between_neighbors(first_trip, second_trip)

# {'distance_from_selected': 0.23505256047318146,
#  'pickup_latitude': 40.766931,
#  'pickup_longitude': -73.982098,
#  'trip_distance': 1.3}
# Out:
# {'distance_from_selected': 0.23505256047318146,
#  'pickup_latitude': 40.766931,
#  'pickup_longitude': -73.982098,
#  'trip_distance': 1.3}

# %% [markdown]
# Ok, now our `neighbor_trip` has another attribute called `distance_from_selected`, that indicates the distance from the `neighbor_trip`'s pickup location from the `selected_trip`.

# %% [markdown]
# > ** Understand the data:** Our dictionary now has a few attributes, two of which say distance.  Let's make sure we understand the difference.
# > * **`distance_from_selected`:** This is our calculation of the distance of the neighbor's pickup location from the selected trip.
# > * **`trip_distance`:** This is the attribute we were provided initially.  It tells us the length of the neighbor's taxi trip from pickup to drop-off.

# %% [markdown]
# Next, write a function called `distance_all` that provided a list of neighbors, returns each of those neighbors with their respective `distance_from_selected` numbers.

# %%
def distance_all(selected_individual, neighbors):
    X=[]
    neighbors_clone = neighbors.copy()
    neighbors_clone = list(filter(lambda neighbor: selected_individual['pickup_latitude'] != neighbor['pickup_latitude'] and selected_individual['pickup_longitude'] != neighbor['pickup_longitude'],neighbors))
    neighbors_update = list(map(lambda neighbor:distance_between_neighbors(selected_individual, neighbor),neighbors_clone))
    #for neighbor in neighbors_update:
    #X.append(neighbor['distance_from_selected'])
    for neighbor in neighbors_update:
        #X.append({v for k,v in neighbor.items() if k == 'distance_from_selected'})
        for k,v in neighbor.items(): 
            if k == 'distance_from_selected':
                X.append(float(v)) 
    return X
    pass

distance_all(first_trip, cleaned_trips[0:4])
# Out:
# [0.23505256047318146, 0.2162779533470808, 0.24242215976473674]

# %%
cleaned_trips and distance_all(first_trip, cleaned_trips[0:4])
# Out:
# [0.23505256047318146, 0.2162779533470808, 0.24242215976473674]

# %% [markdown]
# Now write the nearest neighbors formula to calculate the distance of the `selected_trip` from all of the `cleaned_trips` in our dataset.  If no number is provided, it should return the top 3 neighbors.

# %%
def nearest_neighbors(selected_trip, trips, number = 3):
    trips_clone = trips.copy()
    trips_clone = list(filter(lambda trip:selected_trip['pickup_latitude'] != trip['pickup_latitude'] and selected_trip['pickup_longitude'] != trip['pickup_longitude'],trips))
    trips_update = list(map(lambda trip:distance_between_neighbors(selected_trip, trip),trips_clone))
    trips_order = sorted(trips_update,key = lambda i:i['distance_from_selected'])
    if (number == number or number == len(trips_order)):
        trips_select = trips_order[:number]
        
    return trips_select
    pass

# %%
new_trip = {'pickup_latitude': 40.64499,
'pickup_longitude': -73.78115,
'trip_distance': 18.38}

nearest_three_neighbors = nearest_neighbors(new_trip, cleaned_trips or [], number = 3)
nearest_three_neighbors
# [{'distance_from_selected': 0.0004569288784918792,
#   'pickup_latitude': 40.64483,
#   'pickup_longitude': -73.781578,
#   'trip_distance': 7.78},
#  {'distance_from_selected': 0.0011292165425673159,
#   'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'trip_distance': 12.7},
#  {'distance_from_selected': 0.0042359798158141185,
#   'pickup_latitude': 40.648509,
#   'pickup_longitude': -73.783508,
#   'trip_distance': 17.3}]
# Out:
# [{'distance_from_selected': 0.0004569288784918792,
#   'pickup_latitude': 40.64483,
#   'pickup_longitude': -73.781578,
#   'trip_distance': 7.78},
#  {'distance_from_selected': 0.0011292165425673159,
#   'pickup_latitude': 40.644657,
#   'pickup_longitude': -73.782229,
#   'trip_distance': 12.7},
#  {'distance_from_selected': 0.0042359798158141185,
#   'pickup_latitude': 40.648509,
#   'pickup_longitude': -73.783508,
#   'trip_distance': 17.3}]

# %% [markdown]
# Ok great! Now that we can provide a new trip location, and find the distances of the three nearest trips, we can take  calculate an estimate of the trip distance for that new trip location.
#
# We do so simply by calculating the average of it's nearest neighbors.

# %%
import statistics
def mean_distance(neighbors):
    nearest_distances = list(map(lambda neighbor: neighbor['trip_distance'], neighbors))
    return round(statistics.mean(nearest_distances), 3)

nearest_three_neighbors = nearest_neighbors(new_trip, cleaned_trips or [], number = 3)
distance_estimate_of_selected_trip = mean_distance(nearest_three_neighbors) # 12.593
distance_estimate_of_selected_trip
# Out:
# 12.593

# %% [markdown]
# ### Choosing the correct number of neighbors

# %% [markdown]
# Now, as we know from the last lesson, one tricky element is to determine how many neighbors to choose, our $k$ value,  before calculating the average.  We want to choose our value of $k$ such that it properly matches actual data, and so that it applies to new data.  There are fancy formulas to ensure that we **train** our algorithm so that our formula is optimized for all data, but here let's see different $k$ values manually.  This is the gist of choosing our $k$ value:
#
# * If we choose a $k$ value too low, our formula will be too heavily influenced by a single neighbor, whereas if our $k$ value is too high, we will be choosing so many neighbors that our nearest neighbors formula will not be adjust enough according to locations.
#
# Ok, let's experiment with this.

# %% [markdown]
# First, let's choose a midtown location, to see what the trip distance would be.  A Google search reveals the coordinates of 51st and 7th avenue to be the following.

# %%
midtown_trip = dict(pickup_latitude=40.761710, pickup_longitude=-73.982760)

# %%
seven_closest = nearest_neighbors(midtown_trip, cleaned_trips, number = 7)
seven_closest
# [{'trip_distance': 0.58,
#   'pickup_latitude': 40.761372,
#   'pickup_longitude': -73.982602,
#   'distance_from_selected': 0.00037310588309379025},
#  {'trip_distance': 0.8,
#   'pickup_latitude': 40.762444,
#   'pickup_longitude': -73.98244,
#   'distance_from_selected': 0.00080072217404248},
#  {'trip_distance': 1.4,
#   'pickup_latitude': 40.762767,
#   'pickup_longitude': -73.982293,
#   'distance_from_selected': 0.0011555682584735844},
#  {'trip_distance': 8.3,
#   'pickup_latitude': 40.762868,
#   'pickup_longitude': -73.983233,
#   'distance_from_selected': 0.0012508768924205918},
#  {'trip_distance': 1.26,
#   'pickup_latitude': 40.760057,
#   'pickup_longitude': -73.983502,
#   'distance_from_selected': 0.0018118976240381972},
#  {'trip_distance': 0.0,
#   'pickup_latitude': 40.760644,
#   'pickup_longitude': -73.984531,
#   'distance_from_selected': 0.002067074502774709},
#  {'trip_distance': 1.72,
#   'pickup_latitude': 40.762107,
#   'pickup_longitude': -73.98479,
#   'distance_from_selected': 0.0020684557041472677}]
# Out:
# [{'distance_from_selected': 0.00037310588309379025,
#   'pickup_latitude': 40.761372,
#   'pickup_longitude': -73.982602,
#   'trip_distance': 0.58},
#  {'distance_from_selected': 0.00080072217404248,
#   'pickup_latitude': 40.762444,
#   'pickup_longitude': -73.98244,
#   'trip_distance': 0.8},
#  {'distance_from_selected': 0.0011555682584735844,
#   'pickup_latitude': 40.762767,
#   'pickup_longitude': -73.982293,
#   'trip_distance': 1.4},
#  {'distance_from_selected': 0.0012508768924205918,
#   'pickup_latitude': 40.762868,
#   'pickup_longitude': -73.983233,
#   'trip_distance': 8.3},
#  {'distance_from_selected': 0.0018118976240381972,
#   'pickup_latitude': 40.760057,
#   'pickup_longitude': -73.983502,
#   'trip_distance': 1.26},
#  {'distance_from_selected': 0.002067074502774709,
#   'pickup_latitude': 40.760644,
#   'pickup_longitude': -73.984531,
#   'trip_distance': 0.0},
#  {'distance_from_selected': 0.0020684557041472677,
#   'pickup_latitude': 40.762107,
#   'pickup_longitude': -73.98479,
#   'trip_distance': 1.72}]

# %% [markdown]
# Looking at the `distance_from_selected` it appears that our our trips are still fairly close to our selected trip.  Notice that most of the data is within a distance of .002 away, so going to the top 7 nearest neighbors didn't seem to give us neighbors too far from each other, which is a good sign.
#
# Still, it's hard to know what distance in latitude and longitude really look like, so let's map the data.

# %%
midtown_location = location(midtown_trip) # [40.76171, -73.98276]
midtown_map = map_from(midtown_location, 16)
closest_markers = markers_from_trips(seven_closest)

add_markers(closest_markers, midtown_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ok.  These locations stay fairly close to our estimated location of 51st street and 7th Avenue.  So they could be a good estimate of a trip distance.

# %%
mean_distance(seven_closest) # 2.009
# Out:
# 2.009

# %% [markdown]
# Ok, now let's try a different location

# %%
charging_bull_closest = nearest_neighbors({'pickup_latitude': 40.7049, 'pickup_longitude': -74.0137}, cleaned_trips, number = 12)

# %%
mean_distance(charging_bull_closest) # 3.145
# Out:
# 3.145

# %% [markdown]
# Ok, so there appears to be a significant difference between choosing a location near Times Square versus choosing a location at Wall Street.

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, we used the nearest neighbors function to predict the length of a taxi ride.  To do so, we selected a location, then found a number of taxi rides closest to that location, and finally took the average trip lengths of the nearest taxi rides to find an estimate of the new ride's trip length.  You can see that even with just a little bit of math and programming we can begin to make meaningful predictions with data.
